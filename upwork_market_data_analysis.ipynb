# %% [markdown]
# # Upwork Market Data Analysis for Optimized Profile

# %% [markdown]
# ## Little Story
# I recently started on Upwork and invested over $200 in connects, but I wasn't seeing any success.
#
# Determined to figure out why, I realized that being new to the platform and lacking badges was a factor, but there wasn't much I could do about that, since I'm just stating. I then thought my proposals might be the issue and tried to improve them, but still had no luck.
#
# That’s when I decided to create a client account to get an insider’s perspective. By posting a job, I noticed something crucial: the **first two lines of a proposal are vital**. Clients see a list of proposals with only the first two lines visible, so **these lines need to be a compelling hook**.
#
# With this insight, I wondered if perhaps my profile wasn’t aligned with current market demands. This led me to undertake a market data analysis on Upwork. I began by gathering months' worth of RSS feeds containing job listings to understand better what clients are looking for today.

# %% [markdown]
# ## Objective
# The primary objective of this project is to analyze Upwork job listings to identify current market needs and optimize my profile to increase success rates. By leveraging advanced data extraction techniques and data visualization tools, the project aims to provide valuable insights into job market trends, required skills, and other critical factors influencing hiring decisions on Upwork.

# %% [markdown]
# ## Phases of the Project

# %% [markdown]
# ### 1. Data Collection
# - **Frequency**: Collect RSS feeds of job listings every two days. (When possible)
# - **Automation**: Develop a script to automate the download of RSS feeds and convert them into JSON format for easier handling.
# - **Storage**: Save the JSON files in a structured folder system.
#
# ### 2. Data Transformation (ETL Process)
# - **Extraction**: Extract relevant information from the job listings using advanced language models and tools such as ChatGPT API, Kor, and LangChain.
# - **Transformation**: Structure the unstructured data into a consistent format that includes key job details such as title, responsibilities, skills, qualifications, hourly rate, posting date, category, country, and additional skills.
# - **Loading**: Load the transformed data into a database or a structured file format suitable for analysis.
#
# ### 3. Data Analysis and Visualization
# - **Tool**: Use Power BI to create interactive dashboards.
# - **Metrics and Insights**:
#   - **Job Title**: Categorize and analyze the most common job titles.
#   - **Job Responsibilities**: Identify frequently listed tasks and duties.
#   - **Required Skills**: Determine the most in-demand skills and tools.
#   - **Preferred Qualifications**: Highlight advantageous qualifications and experiences.
#   - **Hourly Range**: Analyze the offered salary ranges.
#   - **Posted Date**: Track the volume of job postings over time.
#   - **Category**: Examine job categories and their distribution.
#   - **Country**: Map job listings by location.
#   - **Additional Skills**: Identify additional skills

# %% [markdown]
# ## Methodology

# %% [markdown]
# ### 1. Data Collection
# - Implement a Python script to automate the fetching of RSS feeds from Upwork every two days.
# - Convert the RSS feeds into JSON format for structured data handling.
# - Save the JSON files in an organized directory for subsequent processing.
#
# ### 2. Data Transformation
# - Use natural language processing (NLP) techniques and large language models (LLMs) like ChatGPT API to parse and extract detailed information from job descriptions.
# - Utilize Kor and LangChain for efficient data extraction and transformation.
# - Ensure the extracted data includes:
#   - Job Title
#   - Link to Job Listing
#   - Job Responsibilities
#   - Required Skills
#   - Preferred Qualifications
#   - Hourly Range
#   - Posted Date
#   - Category
#   - Country
#   - Additional Skills
#
# ### 3. Data Loading
# - Store the transformed data in a relational database or a structured data file (e.g., CSV, JSON) for analysis.
# - Ensure data integrity and consistency throughout the ETL process.
#
# ### 4. Data Analysis and Visualization
# - Import the transformed data into Power BI.
# - Create interactive and visually appealing dashboards that provide insights into the Upwork job market.
# - Develop visualizations that help identify trends and patterns in job listings, such as word clouds for job titles and skills, bar charts for job categories, and geographic maps for job locations.

# %% [markdown]
# ## Expected Outcomes
# - **Comprehensive Dashboard**: A Power BI dashboard offering a detailed analysis of Upwork job listings, showcasing critical insights such as in-demand skills, job categories, and salary ranges.
# - **Optimized Profile**: Enhanced understanding of market needs to tailor my profile more effectively, thereby increasing the chances of success on Upwork.
# - **Market Trends**: Identification of emerging trends and shifts in the job market, enabling proactive adjustments to job search strategies.

# %% [markdown]
# ## Tools and Technologies
# - **Data Collection and Transformation**: Python, RSS Feeds, JSON, ChatGPT API, Kor, LangChain.
# - **Data Visualization**: Power BI.
# - **Storage**: Relational Database or Structured Data Files (e.g., CSV, JSON).

# %% [markdown]
# ## Conclusion
# By systematically analyzing Upwork job listings through automated data collection, advanced NLP techniques, and comprehensive data visualization, this project aims to provide actionable insights for optimizing Power BI Dev profile. The resulting Power BI dashboard will serve as a powerful tool for understanding market demands and tailoring job search strategies to enhance success rates on Upwork.

# %%
#Imports:

#Standard
import pandas as pd
import os
import json
import requests
import time
from datetime import datetime

#Text helpers
#from bs4 import BeautifulSoup
import re
#from markdownify import markdownify as md

#KOR
from kor.extraction import create_extraction_chain
from kor.nodes import Object, Text, Number


#LangChain Models
from langchain.chat_models import ChatOpenAI
from langchain.llms import OpenAI
from langchain_community.llms import Ollama



#Token counting
from langchain.callbacks import get_openai_callback

def printOutput(output):
    print(json.dumps(output,sort_keys=True, indent=3))

# %%
#OpenAi Key:
openaikeyenv = "OpenAIKeyLougse1"
openaikey = os.getenv(openaikeyenv) #If you want to run the script, Change this line with your own APIKey

#Show your ApiKey:
#print(openaikey)

# %%
#Defining the LLMs That we will use:
llm = ChatOpenAI(
    model_name="gpt-3.5-turbo", #Cheaper but less reliable
    #model_name="gpt-4", #Cost more but more reliable
    #model_name="gpt-4o", #Best model 20/08/2024
    temperature = 0,
    max_tokens = 2000,
    openai_api_key = openaikey
)

llm_gpt4o = ChatOpenAI(
    #model_name="gpt-3.5-turbo", #Cheaper but less reliable
    #model_name="gpt-4", #Cost more but more reliable
    model_name="gpt-4o", #Best model 20/08/2024
    temperature = 0,
    max_tokens = 2000,
    openai_api_key = openaikey
)

# Use the "nuextract" model
llm_ollama_nuextract = Ollama(model="nuextract")

# Use the "nuextract" model
llm_ollama_llama31 = Ollama(model="nuextract")

# %%
#Defining paths:
pathenv = "DataScienceProjectsPath"
subpath = os.getenv(pathenv)
dubpath = r"20240517 UPWORK RSS Feed\1-Original Data"
dubpath2 = r"20240517 UPWORK RSS Feed\2-Prepared Data\RAwFiles"
#print(subpath)

fullpath = os.path.join(subpath,dubpath)
directory = os.path.join(subpath,dubpath2)
#print(fullpath)

# %%
files=os.listdir(directory)

# %%
files
# Out:
# ['20240513_RSS_PowerBI.json',
#  '20240514_RSS_PowerBI.json',
#  '20240516_RSS_PowerBI.json',
#  '20240517_RSS_PowerBI.json',
#  '20240520_RSS_PowerBI.json',
#  '20240522_RSS_PowerBI.json',
#  '20240524_RSS_PowerBI.json',
#  '20240526_RSS_PowerBI.json',
#  '20240528_RSS_PowerBI.json',
#  '20240529_RSS_PowerBI.json',
#  '20240530_RSS_PowerBI.json',
#  '20240601_RSS_PowerBI.json',
#  '20240603_RSS_PowerBI.json',
#  '20240605_RSS_PowerBI.json',
#  '20240607_RSS_PowerBI.json',
#  '20240613_RSS_PowerBI.json',
#  '20240615_RSS_PowerBI.json',
#  '20240619_RSS_PowerBI.json',
#  '20240621_RSS_PowerBI.json',
#  '20240623_RSS_PowerBI.json',
#  '20240625_RSS_PowerBI.json',
#  '20240627_RSS_PowerBI.json',
#  '20240629_RSS_PowerBI.json',
#  '20240701_RSS_PowerBI.json',
#  '20240703_RSS_PowerBI.json',
#  '20240705_RSS_PowerBI.json',
#  '20240707_RSS_PowerBI.json',
#  '20240709_RSS_PowerBI.json',
#  '20240711_RSS_PowerBI.json',
#  '20240713_RSS_PowerBI.json',
#  '20240715_RSS_PowerBI.json',
#  '20240717_RSS_PowerBI.json',
#  '20240718_RSS_PowerBI.json',
#  '20240720_RSS_PowerBI.json',
#  '20240726_RSS_PowerBI.json',
#  '20240730_RSS_PowerBI.json',
#  '20240807_RSS_PowerBI.json']

# %%
#print(os.path.join(directory,files[0]))
file1_path=os.path.join(directory,files[0])

# %%
#Opening and reading 1 file
with open(file=file1_path,mode="r") as file1:
    #print(file1.read())
    content=file1.read()
    json_file1 = json.loads(content)

# %%
json_file1
# Out:
# {'rss': {'@xmlns:content': 'http://purl.org/rss/1.0/modules/content/',
#   '@version': '2.0',
#   'channel': {'title': 'All jobs | upwork.com',
#    'link': 'https://www.upwork.com/ab/feed/jobs/rss?api_params=1&amp;orgUid=1729067928257851393&amp;paging=0-10&amp;q=Power%20Bi&amp;securityToken=d17308910f66b74d222ca66c907efa56c942739d41db7bba3da3ca225a9584b2edcab156ed12fcd81a0f94e952ea29d611248991196927c716632e2284293c57&amp;sort=recency&amp;userUid=1729067928257851392',
#    'description': 'All jobs as of May 13, 2024 12:22 UTC',
#    'language': 'en-us',
#    'pubDate': 'Mon, 13 May 2024 12:22:38 +0000',
#    'copyright': 'Â© 2003-2024 Upwork Corporation',
#    'docs': 'http://blogs.law.harvard.edu/tech/rss',
#    'generator': 'Upwork Corporation',
#    'managingEditor': 'rss@upwork.com (Upwork Corporation)',
#    'image': {'url': 'https://www.upwork.com/images/rss_logo.png',
#     'title': 'All jobs | upwork.com',
#     'link': 'https://www.upwork.com/ab/feed/jobs/rss?api_params=1&amp;orgUid=1729067928257851393&amp;paging=0-10&amp;q=Power%20Bi&amp;securityToken=d17308910f66b74d222ca66c907efa56c942739d41db7bba3da3ca225a9584b2edcab156ed12fcd81a0f94e952ea29d611248991196927c716632e2284293c57&amp;sort=recency&amp;userUid=1729067928257851392'},
#    'item': [{'title': 'Professional dashboard built in MicroStrategy - Upwork',
#      'link': 'https://www.upwork.com/jobs/Professional-dashboard-built-MicroStrategy_%7E01ec8934d454ff0ef3?source=rss',
#      'description': 'Hi<br /><br />\n I am looking for a professional dashboard built in MicroStrategy, using advanced visualizations and automation. The dataset is small&nbsp;&nbsp;(about 107 rows)and straight forward. Also please indicate how long will it take for you to do the job?<br /><br />\nThanks<br />\nCharu<br /><br /><br /><br /><b>Posted On</b>: May 13, 2024 09:46 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI Data Visualization,     Microsoft Power BI,     Dashboard,     Business Intelligence,     SQL,     Microsoft Power BI Development,     Database,     Microsoft Excel,     Data Mining,     BigQuery,     Data Visualization,     Analytics Dashboard,     Data Modeling,     Data Analytics    \n<br /><b>Skills</b>:        Microsoft Power BI Data Visualization,                     Microsoft Power BI,                     Dashboard,                     Business Intelligence,                     SQL,                     Microsoft Power BI Development,                     Database,                     Microsoft Excel,                     Data Mining,                     BigQuery,                     Data Visualization,                     Analytics Dashboard,                     Data Modeling,                     Data Analytics            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Professional-dashboard-built-MicroStrategy_%7E01ec8934d454ff0ef3?source=rss">click to apply</a>',
#      'content:encoded': 'Hi<br /><br />\n I am looking for a professional dashboard built in MicroStrategy, using advanced visualizations and automation. The dataset is small&nbsp;&nbsp;(about 107 rows)and straight forward. Also please indicate how long will it take for you to do the job?<br /><br />\nThanks<br />\nCharu<br /><br /><br /><br /><b>Posted On</b>: May 13, 2024 09:46 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI Data Visualization,     Microsoft Power BI,     Dashboard,     Business Intelligence,     SQL,     Microsoft Power BI Development,     Database,     Microsoft Excel,     Data Mining,     BigQuery,     Data Visualization,     Analytics Dashboard,     Data Modeling,     Data Analytics    \n<br /><b>Skills</b>:        Microsoft Power BI Data Visualization,                     Microsoft Power BI,                     Dashboard,                     Business Intelligence,                     SQL,                     Microsoft Power BI Development,                     Database,                     Microsoft Excel,                     Data Mining,                     BigQuery,                     Data Visualization,                     Analytics Dashboard,                     Data Modeling,                     Data Analytics            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Professional-dashboard-built-MicroStrategy_%7E01ec8934d454ff0ef3?source=rss">click to apply</a>',
#      'pubDate': 'Mon, 13 May 2024 09:46:45 +0000',
#      'guid': 'https://www.upwork.com/jobs/Professional-dashboard-built-MicroStrategy_%7E01ec8934d454ff0ef3?source=rss'},
#     {'title': 'Power BI Developer - Upwork',
#      'link': 'https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss',
#      'description': 'We are seeking a Power BI Developer to assist with our data visualization and reporting needs. The ideal candidate will have experience in creating interactive dashboards and reports using Power BI tools. Key responsibilities include: <br /><br />\n- Creating visually appealing and informative dashboards.<br />\n- Building data models and establishing connections to various data sources.<br />\n- Generating reports and insights that meet business requirements.<br /><br />\n Qualifications:<br />\n- Proficiency in Power BI Desktop, Power Query, DAX, and M languages<br />\n- Familiarity with SQL, data warehousing concepts, and ETL processes is a plus.<br />\n- Experience in data visualization principles and best practices.<br /><br /><b>Hourly Range</b>: $25.00-$60.00\n\n<br /><b>Posted On</b>: May 13, 2024 09:44 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Data Analysis Expressions,     Microsoft Power BI,     Data Visualization,     Business Intelligence,     Microsoft Power BI Development,     Power Query,     Microsoft SharePoint    \n<br /><b>Skills</b>:        Data Analysis Expressions,                     Microsoft Power BI,                     Data Visualization,                     Business Intelligence,                     Microsoft Power BI Development,                     Power Query,                     Microsoft SharePoint            <br /><b>Country</b>: Philippines\n<br /><a href="https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss">click to apply</a>',
#      'content:encoded': 'We are seeking a Power BI Developer to assist with our data visualization and reporting needs. The ideal candidate will have experience in creating interactive dashboards and reports using Power BI tools. Key responsibilities include: <br /><br />\n- Creating visually appealing and informative dashboards.<br />\n- Building data models and establishing connections to various data sources.<br />\n- Generating reports and insights that meet business requirements.<br /><br />\n Qualifications:<br />\n- Proficiency in Power BI Desktop, Power Query, DAX, and M languages<br />\n- Familiarity with SQL, data warehousing concepts, and ETL processes is a plus.<br />\n- Experience in data visualization principles and best practices.<br /><br /><b>Hourly Range</b>: $25.00-$60.00\n\n<br /><b>Posted On</b>: May 13, 2024 09:44 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Data Analysis Expressions,     Microsoft Power BI,     Data Visualization,     Business Intelligence,     Microsoft Power BI Development,     Power Query,     Microsoft SharePoint    \n<br /><b>Skills</b>:        Data Analysis Expressions,                     Microsoft Power BI,                     Data Visualization,                     Business Intelligence,                     Microsoft Power BI Development,                     Power Query,                     Microsoft SharePoint            <br /><b>Country</b>: Philippines\n<br /><a href="https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss">click to apply</a>',
#      'pubDate': 'Mon, 13 May 2024 09:44:11 +0000',
#      'guid': 'https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss'},
#     {'title': 'Sports Analytics Expert Needed - Upwork',
#      'link': 'https://www.upwork.com/jobs/Sports-Analytics-Expert-Needed_%7E01eee8d1e717ced124?source=rss',
#      'description': 'We are seeking a skilled sports analytics expert to analyze a comprehensive dataset of cricket player statistics. The goal is to derive actionable insights and identify the impact of various factors on the game, enabling data-driven decision-making to enhance team performance.<br /><br />\nResponsibilities:<br />\nConduct detailed analysis of key performance indicators (KPIs) such as batting average, strike rate, bowling economy, and fielding effectiveness.<br />\nIdentify performance trends and patterns over time, including player career progression and consistency.<br />\nPerform comparative analysis of player performance against different teams, in various formats (Test, ODI, T20), and under different conditions (home/away, pitch types, weather).<br />\nAnalyze player strengths and weaknesses, including performance against specific opponents and in high-pressure situations.<br />\nAssess match-winning performances and overall contribution to team success.<br />\nUse advanced analytical techniques such as cluster analysis, predictive modeling to uncover deeper insights.<br />\nCreate interactive dashboards and visualizations to present findings in an engaging and accessible manner.<br /><br />\nDeliverables:<br />\nComprehensive report detailing the analysis findings, including statistical summaries, visualizations, and key insights with codes.<br />\nInteractive dashboards using tools like Tableau or Power BI for dynamic data exploration.<br />\nRecommendations for optimizing player roles and strategies based on the analysis.<br />\nIdentification of potential areas for performance improvement and strategic adjustments.<br /><br /><br />\nQualifications:<br />\nProven experience in sports analytics, particularly with cricket datasets.<br />\nStrong understanding of cricket, including rules, player roles, and game dynamics.<br />\nProficiency in data analysis tools and programming languages such as R, Python, or SQL.<br />\nExperience with data visualization tools like Tableau, Power BI, or similar platforms.<br />\nAbility to communicate complex analytical findings in a clear and concise manner.<br />\nPassion for sports analytics and a keen eye for detail.<br /><br /><b>Hourly Range</b>: $5.00-$40.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:46 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:R,     Data Visualization,     Microsoft Excel,     Google Analytics,     Search Engine Optimization,     Data Analysis,     Machine Learning,     Analytics    \n<br /><b>Skills</b>:        R,                     Data Visualization,                     Microsoft Excel,                     Google Analytics,                     Search Engine Optimization,                     Data Analysis,                     Machine Learning,                     Analytics            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Sports-Analytics-Expert-Needed_%7E01eee8d1e717ced124?source=rss">click to apply</a>',
#      'content:encoded': 'We are seeking a skilled sports analytics expert to analyze a comprehensive dataset of cricket player statistics. The goal is to derive actionable insights and identify the impact of various factors on the game, enabling data-driven decision-making to enhance team performance.<br /><br />\nResponsibilities:<br />\nConduct detailed analysis of key performance indicators (KPIs) such as batting average, strike rate, bowling economy, and fielding effectiveness.<br />\nIdentify performance trends and patterns over time, including player career progression and consistency.<br />\nPerform comparative analysis of player performance against different teams, in various formats (Test, ODI, T20), and under different conditions (home/away, pitch types, weather).<br />\nAnalyze player strengths and weaknesses, including performance against specific opponents and in high-pressure situations.<br />\nAssess match-winning performances and overall contribution to team success.<br />\nUse advanced analytical techniques such as cluster analysis, predictive modeling to uncover deeper insights.<br />\nCreate interactive dashboards and visualizations to present findings in an engaging and accessible manner.<br /><br />\nDeliverables:<br />\nComprehensive report detailing the analysis findings, including statistical summaries, visualizations, and key insights with codes.<br />\nInteractive dashboards using tools like Tableau or Power BI for dynamic data exploration.<br />\nRecommendations for optimizing player roles and strategies based on the analysis.<br />\nIdentification of potential areas for performance improvement and strategic adjustments.<br /><br /><br />\nQualifications:<br />\nProven experience in sports analytics, particularly with cricket datasets.<br />\nStrong understanding of cricket, including rules, player roles, and game dynamics.<br />\nProficiency in data analysis tools and programming languages such as R, Python, or SQL.<br />\nExperience with data visualization tools like Tableau, Power BI, or similar platforms.<br />\nAbility to communicate complex analytical findings in a clear and concise manner.<br />\nPassion for sports analytics and a keen eye for detail.<br /><br /><b>Hourly Range</b>: $5.00-$40.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:46 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:R,     Data Visualization,     Microsoft Excel,     Google Analytics,     Search Engine Optimization,     Data Analysis,     Machine Learning,     Analytics    \n<br /><b>Skills</b>:        R,                     Data Visualization,                     Microsoft Excel,                     Google Analytics,                     Search Engine Optimization,                     Data Analysis,                     Machine Learning,                     Analytics            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Sports-Analytics-Expert-Needed_%7E01eee8d1e717ced124?source=rss">click to apply</a>',
#      'pubDate': 'Mon, 13 May 2024 08:46:15 +0000',
#      'guid': 'https://www.upwork.com/jobs/Sports-Analytics-Expert-Needed_%7E01eee8d1e717ced124?source=rss'},
#     {'title': 'Data analyst/BI expert to help automate a series of analytics reports - Upwork',
#      'link': 'https://www.upwork.com/jobs/Data-analyst-expert-help-automate-series-analytics-reports_%7E017e99068e70711d6b?source=rss',
#      'description': '<br />\nwrite a scope of work that is focused on data consumer behavior and other important key metrics that will enable the dealership to sell smarter to its customers. <br />\nSkills required are pyhthon, sql and powerbi<br />\nDeliverables:<br />\n&bull;\tDefined and prioritized KPIs for sales and marketing<br />\n&bull;\tCustomer segmentation insights and reports<br />\n&bull;\tRecommendations for targeted marketing campaigns across various channels<br />\n&bull;\tData-driven strategies for optimizing the sales process<br />\n&bull;\tOngoing reporting dashboards<br />\n&bull;\tFinal report with actionable recommendations<br /><br />\ncommunication will be via email and Microsoft teams<br /><br /><b>Budget</b>: $500\n<br /><b>Posted On</b>: May 13, 2024 09:27 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:SQL,     Microsoft Power BI,     Business Intelligence,     Python    \n<br /><b>Skills</b>:        SQL,                     Microsoft Power BI,                     Business Intelligence,                     Python            <br /><b>Country</b>: South Africa\n<br /><a href="https://www.upwork.com/jobs/Data-analyst-expert-help-automate-series-analytics-reports_%7E017e99068e70711d6b?source=rss">click to apply</a>',
#      'content:encoded': '<br />\nwrite a scope of work that is focused on data consumer behavior and other important key metrics that will enable the dealership to sell smarter to its customers. <br />\nSkills required are pyhthon, sql and powerbi<br />\nDeliverables:<br />\n&bull;\tDefined and prioritized KPIs for sales and marketing<br />\n&bull;\tCustomer segmentation insights and reports<br />\n&bull;\tRecommendations for targeted marketing campaigns across various channels<br />\n&bull;\tData-driven strategies for optimizing the sales process<br />\n&bull;\tOngoing reporting dashboards<br />\n&bull;\tFinal report with actionable recommendations<br /><br />\ncommunication will be via email and Microsoft teams<br /><br /><b>Budget</b>: $500\n<br /><b>Posted On</b>: May 13, 2024 09:27 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:SQL,     Microsoft Power BI,     Business Intelligence,     Python    \n<br /><b>Skills</b>:        SQL,                     Microsoft Power BI,                     Business Intelligence,                     Python            <br /><b>Country</b>: South Africa\n<br /><a href="https://www.upwork.com/jobs/Data-analyst-expert-help-automate-series-analytics-reports_%7E017e99068e70711d6b?source=rss">click to apply</a>',
#      'pubDate': 'Mon, 13 May 2024 09:27:40 +0000',
#      'guid': 'https://www.upwork.com/jobs/Data-analyst-expert-help-automate-series-analytics-reports_%7E017e99068e70711d6b?source=rss'},
#     {'title': 'Real Estate Listing and Transaction Database with Predictive Analytics - Upwork',
#      'link': 'https://www.upwork.com/jobs/Real-Estate-Listing-and-Transaction-Database-with-Predictive-Analytics_%7E01b4961d51a60e9f07?source=rss',
#      'description': 'We are seeking a skilled data engineer and data scientist to create a comprehensive real estate database that tracks listings and transactions on a weekly basis. The goal of this project is to develop a tool that can predict real estate price movements and identify underpriced properties using Microsoft Azure Machine Learning.<br /><br />\nResponsibilities:<br /><br />\n1. Design and create an SQL database to store real estate listings and transactions.<br /><br />\n2. Develop scripts to collect real estate data from various sources and update the database weekly.<br /><br />\n3. Implement data cleaning and deduplication processes to ensure data integrity and accuracy.<br /><br />\n4. Track changes in listings on a weekly basis and store historical data for analysis.<br /><br />\n5. Connect the database to Power BI to create interactive dashboards and visualizations for data analysis.<br /><br />\n6. Utilize Microsoft Azure Machine Learning to develop models for predicting real estate price movements and identifying underpriced properties.<br /><br />\n7. Provide functionality to export data from the SQL database to Excel for further analysis.<br /><br />\n8. Provide documentation and support for the database, analytics tools, and machine learning models.<br /><br />\nRequirements:<br /><br />\n1. Experience with SQL database design and management.<br /><br />\n2. Proficiency in data collection and web scraping using Python or other relevant tools.<br /><br />\n3. Knowledge of data cleaning, deduplication, and data transformation techniques.<br /><br />\n4. Familiarity with Power BI or similar data visualization tools.<br /><br />\n5. Experience with Microsoft Azure Machine Learning or similar cloud-based machine learning platforms.<br /><br />\n6. Strong problem-solving and analytical skills.<br /><br />\n7. Good communication skills and ability to work independently.<br /><br />\nDeliverables:<br /><br />\n1. A functional SQL database populated with real estate listings and transactions.<br /><br />\n2. Scripts to collect and update data weekly.<br /><br />\n3. Data cleaning and deduplication processes implemented within the database.<br /><br />\n4. Power BI dashboards and reports for data visualization and analysis.<br /><br />\n5. Machine learning models developed using Azure Machine Learning for predicting real estate price movements and identifying underpriced properties.<br /><br />\n6. Functionality to export data from the SQL database to Excel.<br />\nDocumentation for the database, data collection scripts, analytics components, and machine learning models.<br /><br />\nTimeline:<br /><br />\nThe project is expected to take approximately 4-6 weeks to complete, with regular progress updates throughout the duration of the project.<br /><br />\nBudget:<br /><br />\nThe budget for this project is set at $1,500, which includes the development of the database, data collection scripts, data cleaning processes, Power BI integration, and machine learning models using Microsoft Azure Machine Learning.<br /><br />\nIf you have the required skills and experience and can work within the specified budget and timeline, please submit your proposal, including a project plan and timeline. We look forward to working with a talented data engineer and data scientist to bring this project to life.<br /><br />\nPlease note that the ability to export data from the SQL database to Excel is considered part of the core functionality and does not need to be separately mentioned in the job description. It is assumed that the data engineer will provide this capability as part of the database development process.<br /><br /><b>Budget</b>: $1,500\n<br /><b>Posted On</b>: May 13, 2024 09:18 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:SQL,     Microsoft Power BI,     Data Entry,     Data Analysis,     Data Scraping,     Data Mining,     Python,     Microsoft Excel,     Microsoft Azure SQL Database,     Machine Lea ...
#      'content:encoded': 'We are seeking a skilled data engineer and data scientist to create a comprehensive real estate database that tracks listings and transactions on a weekly basis. The goal of this project is to develop a tool that can predict real estate price movements and identify underpriced properties using Microsoft Azure Machine Learning.<br /><br />\nResponsibilities:<br /><br />\n1. Design and create an SQL database to store real estate listings and transactions.<br /><br />\n2. Develop scripts to collect real estate data from various sources and update the database weekly.<br /><br />\n3. Implement data cleaning and deduplication processes to ensure data integrity and accuracy.<br /><br />\n4. Track changes in listings on a weekly basis and store historical data for analysis.<br /><br />\n5. Connect the database to Power BI to create interactive dashboards and visualizations for data analysis.<br /><br />\n6. Utilize Microsoft Azure Machine Learning to develop models for predicting real estate price movements and identifying underpriced properties.<br /><br />\n7. Provide functionality to export data from the SQL database to Excel for further analysis.<br /><br />\n8. Provide documentation and support for the database, analytics tools, and machine learning models.<br /><br />\nRequirements:<br /><br />\n1. Experience with SQL database design and management.<br /><br />\n2. Proficiency in data collection and web scraping using Python or other relevant tools.<br /><br />\n3. Knowledge of data cleaning, deduplication, and data transformation techniques.<br /><br />\n4. Familiarity with Power BI or similar data visualization tools.<br /><br />\n5. Experience with Microsoft Azure Machine Learning or similar cloud-based machine learning platforms.<br /><br />\n6. Strong problem-solving and analytical skills.<br /><br />\n7. Good communication skills and ability to work independently.<br /><br />\nDeliverables:<br /><br />\n1. A functional SQL database populated with real estate listings and transactions.<br /><br />\n2. Scripts to collect and update data weekly.<br /><br />\n3. Data cleaning and deduplication processes implemented within the database.<br /><br />\n4. Power BI dashboards and reports for data visualization and analysis.<br /><br />\n5. Machine learning models developed using Azure Machine Learning for predicting real estate price movements and identifying underpriced properties.<br /><br />\n6. Functionality to export data from the SQL database to Excel.<br />\nDocumentation for the database, data collection scripts, analytics components, and machine learning models.<br /><br />\nTimeline:<br /><br />\nThe project is expected to take approximately 4-6 weeks to complete, with regular progress updates throughout the duration of the project.<br /><br />\nBudget:<br /><br />\nThe budget for this project is set at $1,500, which includes the development of the database, data collection scripts, data cleaning processes, Power BI integration, and machine learning models using Microsoft Azure Machine Learning.<br /><br />\nIf you have the required skills and experience and can work within the specified budget and timeline, please submit your proposal, including a project plan and timeline. We look forward to working with a talented data engineer and data scientist to bring this project to life.<br /><br />\nPlease note that the ability to export data from the SQL database to Excel is considered part of the core functionality and does not need to be separately mentioned in the job description. It is assumed that the data engineer will provide this capability as part of the database development process.<br /><br /><b>Budget</b>: $1,500\n<br /><b>Posted On</b>: May 13, 2024 09:18 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:SQL,     Microsoft Power BI,     Data Entry,     Data Analysis,     Data Scraping,     Data Mining,     Python,     Microsoft Excel,     Microsoft Azure SQL Database,     Machine ...
#      'pubDate': 'Mon, 13 May 2024 09:18:18 +0000',
#      'guid': 'https://www.upwork.com/jobs/Real-Estate-Listing-and-Transaction-Database-with-Predictive-Analytics_%7E01b4961d51a60e9f07?source=rss'},
#     {'title': 'Ad-hoc PowerBI Support - Upwork',
#      'link': 'https://www.upwork.com/jobs/hoc-PowerBI-Support_%7E015ce72d94b930088d?source=rss',
#      'description': 'Need ad-hoc PowerBI support to develop visual reports.&nbsp;&nbsp;Datasource is MS Dataverse.&nbsp;&nbsp;Requirements typically involve connecting relationships between multiple tables and understand 1:N, different types of joins, etc.<br /><br /><b>Hourly Range</b>: $20.00-$25.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:56 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI    \n<br /><b>Skills</b>:        Microsoft Power BI            <br /><b>Country</b>: Singapore\n<br /><a href="https://www.upwork.com/jobs/hoc-PowerBI-Support_%7E015ce72d94b930088d?source=rss">click to apply</a>',
#      'content:encoded': 'Need ad-hoc PowerBI support to develop visual reports.&nbsp;&nbsp;Datasource is MS Dataverse.&nbsp;&nbsp;Requirements typically involve connecting relationships between multiple tables and understand 1:N, different types of joins, etc.<br /><br /><b>Hourly Range</b>: $20.00-$25.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:56 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI    \n<br /><b>Skills</b>:        Microsoft Power BI            <br /><b>Country</b>: Singapore\n<br /><a href="https://www.upwork.com/jobs/hoc-PowerBI-Support_%7E015ce72d94b930088d?source=rss">click to apply</a>',
#      'pubDate': 'Mon, 13 May 2024 08:56:54 +0000',
#      'guid': 'https://www.upwork.com/jobs/hoc-PowerBI-Support_%7E015ce72d94b930088d?source=rss'},
#     {'title': 'Ema - Upwork',
#      'link': 'https://www.upwork.com/jobs/Ema_%7E018ea49528c5bb0933?source=rss',
#      'description': 'Please refer to enclosed PDF<br />\nDetails requirement is in PDF<br />\nPlease let me can you handle it?<br />\nIf yes, what is the cost and need how many days to deliver?<br /><br /><br /><b>Posted On</b>: May 13, 2024 08:42 UTC<br /><b>Category</b>: Scripting &amp; Automation<br /><b>Skills</b>:Microsoft Power BI,     Data Analysis Expressions,     Data Analysis,     Microsoft Power BI Data Visualization,     Laravel,     PHP,     HTML5,     MQL 4,     MetaTrader 4,     Forex Trading,     MQL 5,     MetaTrader 5,     Microsoft Power BI Development,     Search Engine Optimization,     Microsoft Visual C++    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Data Analysis Expressions,                     Data Analysis,                     Microsoft Power BI Data Visualization,                     Laravel,                     PHP,                     HTML5,                     MQL 4,                     MetaTrader 4,                     Forex Trading,                     MQL 5,                     MetaTrader 5,                     Microsoft Power BI Development,                     Search Engine Optimization,                     Microsoft Visual C++            <br /><b>Country</b>: Malaysia\n<br /><a href="https://www.upwork.com/jobs/Ema_%7E018ea49528c5bb0933?source=rss">click to apply</a>',
#      'content:encoded': 'Please refer to enclosed PDF<br />\nDetails requirement is in PDF<br />\nPlease let me can you handle it?<br />\nIf yes, what is the cost and need how many days to deliver?<br /><br /><br /><b>Posted On</b>: May 13, 2024 08:42 UTC<br /><b>Category</b>: Scripting &amp; Automation<br /><b>Skills</b>:Microsoft Power BI,     Data Analysis Expressions,     Data Analysis,     Microsoft Power BI Data Visualization,     Laravel,     PHP,     HTML5,     MQL 4,     MetaTrader 4,     Forex Trading,     MQL 5,     MetaTrader 5,     Microsoft Power BI Development,     Search Engine Optimization,     Microsoft Visual C++    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Data Analysis Expressions,                     Data Analysis,                     Microsoft Power BI Data Visualization,                     Laravel,                     PHP,                     HTML5,                     MQL 4,                     MetaTrader 4,                     Forex Trading,                     MQL 5,                     MetaTrader 5,                     Microsoft Power BI Development,                     Search Engine Optimization,                     Microsoft Visual C++            <br /><b>Country</b>: Malaysia\n<br /><a href="https://www.upwork.com/jobs/Ema_%7E018ea49528c5bb0933?source=rss">click to apply</a>',
#      'pubDate': 'Mon, 13 May 2024 08:42:05 +0000',
#      'guid': 'https://www.upwork.com/jobs/Ema_%7E018ea49528c5bb0933?source=rss'},
#     {'title': 'Customer Management Solution and PowerBI Reporting - Upwork',
#      'link': 'https://www.upwork.com/jobs/Customer-Management-Solution-and-PowerBI-Reporting_%7E014e5020598d3d582b?source=rss',
#      'description': 'We are seeking a skilled freelancer to develop a customer management solution and create PowerBI reports based on the datasets we provide on a weekly basis. The ideal candidate will have experience in both customer management systems and PowerBI reporting. This project requires the ability to integrate and manipulate data from Excel into a user-friendly customer management solution, as well as the creation of visually appealing PowerBI reports that provide valuable insights. <br /><br />\n&nbsp;&nbsp;Skills required:<br />\n&nbsp;&nbsp;- Customer management system development<br />\n&nbsp;&nbsp;- PowerBI reporting<br />\n&nbsp;&nbsp;- Data integration and manipulation<br />\n&nbsp;&nbsp;- Excel proficiency<br /><br />\n&nbsp;&nbsp;This is a medium-sized project expected to last between 1 to 3 months. We are looking for an intermediate-level freelancer who can confidently handle the requirements and deliver quality results within the given timeframe. <br /><br /><b>Hourly Range</b>: $5.00-$45.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:39 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     Business Intelligence,     Data Analysis,     Microsoft Excel    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Business Intelligence,                     Data Analysis,                     Microsoft Excel            <br /><b>Country</b>: Australia\n<br /><a href="https://www.upwork.com/jobs/Customer-Management-Solution-and-PowerBI-Reporting_%7E014e5020598d3d582b?source=rss">click to apply</a>',
#      'content:encoded': 'We are seeking a skilled freelancer to develop a customer management solution and create PowerBI reports based on the datasets we provide on a weekly basis. The ideal candidate will have experience in both customer management systems and PowerBI reporting. This project requires the ability to integrate and manipulate data from Excel into a user-friendly customer management solution, as well as the creation of visually appealing PowerBI reports that provide valuable insights. <br /><br />\n&nbsp;&nbsp;Skills required:<br />\n&nbsp;&nbsp;- Customer management system development<br />\n&nbsp;&nbsp;- PowerBI reporting<br />\n&nbsp;&nbsp;- Data integration and manipulation<br />\n&nbsp;&nbsp;- Excel proficiency<br /><br />\n&nbsp;&nbsp;This is a medium-sized project expected to last between 1 to 3 months. We are looking for an intermediate-level freelancer who can confidently handle the requirements and deliver quality results within the given timeframe. <br /><br /><b>Hourly Range</b>: $5.00-$45.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:39 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     Business Intelligence,     Data Analysis,     Microsoft Excel    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Business Intelligence,                     Data Analysis,                     Microsoft Excel            <br /><b>Country</b>: Australia\n<br /><a href="https://www.upwork.com/jobs/Customer-Management-Solution-and-PowerBI-Reporting_%7E014e5020598d3d582b?source=rss">click to apply</a>',
#      'pubDate': 'Mon, 13 May 2024 08:39:10 +0000',
#      'guid': 'https://www.upwork.com/jobs/Customer-Management-Solution-and-PowerBI-Reporting_%7E014e5020598d3d582b?source=rss'},
#     {'title': 'Trigger URL in PowerBi - Upwork',
#      'link': 'https://www.upwork.com/jobs/Trigger-URL-PowerBi_%7E0112add0c6294cb28a?source=rss',
#      'description': 'Hi,<br /><br />\nWe have a function stored on our Azure platform that is connected to a SQL Server table that holds a unique url that when entered into a browser changes another value on the same table to show that record has been seen and actioned by the user.<br /><br />\nWe need to be able to trigger this url in a PowerBi table so we can update the tracking value in our table.&nbsp;&nbsp;The issue is that by default PowerBi opens a browser window.&nbsp;&nbsp;<br /><br />\nWe need someone to help us overcome this so when the your is selected the value changes without opening a browser. We are happy to use Power Automate to achieve this, but need a detailed answer on what it requires us to do.<br /><br />\nWe can send over the PBIX file upon initial messaging.<br /><br />\nWe need someone immediately available and who has a feedback score of higher than 95%<br /><br />\nThanks<br /><br />\nJon&nbsp;&nbsp;<br /><br /><b>Hourly Range</b>: $20.00-$45.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:32 UTC<br /><b>Category</b>: Scripting &amp; Automation<br /><b>Skills</b>:API Integration,     Microsoft Power BI,     Power Query    \n<br /><b>Skills</b>:        API Integration,                     Microsoft Power BI,                     Power Query            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Trigger-URL-PowerBi_%7E0112add0c6294cb28a?source=rss">click to apply</a>',
#      'content:encoded': 'Hi,<br /><br />\nWe have a function stored on our Azure platform that is connected to a SQL Server table that holds a unique url that when entered into a browser changes another value on the same table to show that record has been seen and actioned by the user.<br /><br />\nWe need to be able to trigger this url in a PowerBi table so we can update the tracking value in our table.&nbsp;&nbsp;The issue is that by default PowerBi opens a browser window.&nbsp;&nbsp;<br /><br />\nWe need someone to help us overcome this so when the your is selected the value changes without opening a browser. We are happy to use Power Automate to achieve this, but need a detailed answer on what it requires us to do.<br /><br />\nWe can send over the PBIX file upon initial messaging.<br /><br />\nWe need someone immediately available and who has a feedback score of higher than 95%<br /><br />\nThanks<br /><br />\nJon&nbsp;&nbsp;<br /><br /><b>Hourly Range</b>: $20.00-$45.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:32 UTC<br /><b>Category</b>: Scripting &amp; Automation<br /><b>Skills</b>:API Integration,     Microsoft Power BI,     Power Query    \n<br /><b>Skills</b>:        API Integration,                     Microsoft Power BI,                     Power Query            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Trigger-URL-PowerBi_%7E0112add0c6294cb28a?source=rss">click to apply</a>',
#      'pubDate': 'Mon, 13 May 2024 08:32:14 +0000',
#      'guid': 'https://www.upwork.com/jobs/Trigger-URL-PowerBi_%7E0112add0c6294cb28a?source=rss'},
#     {'title': 'Automate salary/wages and costing sheets - Upwork',
#      'link': 'https://www.upwork.com/jobs/Automate-salary-wages-and-costing-sheets_%7E01261e12a504f06051?source=rss',
#      'description': 'We need to automate salary/wages and costing sheets in Excel by our desire. Could you accomplish it<br /><br /><br /><br /><b>Posted On</b>: May 13, 2024 07:47 UTC<br /><b>Category</b>: Machine Learning<br /><b>Skills</b>:Data Science,     Computer Vision,     Microsoft Excel,     Python,     SciPy,     Data Visualization,     Microsoft Power BI,     SQL,     Machine Learning,     Deep Learning,     Neural Network,     Data Extraction,     Cloud Architecture,     Data Analysis,     API    \n<br /><b>Skills</b>:        Data Science,                     Computer Vision,                     Microsoft Excel,                     Python,                     SciPy,                     Data Visualization,                     Microsoft Power BI,                     SQL,                     Machine Learning,                     Deep Learning,                     Neural Network,                     Data Extraction,                     Cloud Architecture,                     Data Analysis,                     API            <br /><b>Country</b>: India\n<br /><a href="https://www.upwork.com/jobs/Automate-salary-wages-and-costing-sheets_%7E01261e12a504f06051?source=rss">click to apply</a>',
#      'content:encoded': 'We need to automate salary/wages and costing sheets in Excel by our desire. Could you accomplish it<br /><br /><br /><br /><b>Posted On</b>: May 13, 2024 07:47 UTC<br /><b>Category</b>: Machine Learning<br /><b>Skills</b>:Data Science,     Computer Vision,     Microsoft Excel,     Python,     SciPy,     Data Visualization,     Microsoft Power BI,     SQL,     Machine Learning,     Deep Learning,     Neural Network,     Data Extraction,     Cloud Architecture,     Data Analysis,     API    \n<br /><b>Skills</b>:        Data Science,                     Computer Vision,                     Microsoft Excel,                     Python,                     SciPy,                     Data Visualization,                     Microsoft Power BI,                     SQL,                     Machine Learning,                     Deep Learning,                     Neural Network,                     Data Extraction,                     Cloud Architecture,                     Data Analysis,                     API            <br /><b>Country</b>: India\n<br /><a href="https://www.upwork.com/jobs/Automate-salary-wages-and-costing-sheets_%7E01261e12a504f06051?source=rss">click to apply</a>',
#      'pubDate': 'Mon, 13 May 2024 07:47:37 +0000',
#      'guid': 'https://www.upwork.com/jobs/Automate-salary-wages-and-costing-sheets_%7E01261e12a504f06051?source=rss'},
#     {'title': 'PowerBI Developer for Dashboards - Upwork',
#      'link': 'https://www.upwork.com/jobs/PowerBI-Developer-for-Dashboards_%7E01db52a9ad0587d3ad?source=rss',
#      'description': 'We are seeking a skilled PowerBI developer to create interactive dashboards for our organization. The ideal candidate will have a strong background in data visualization and be proficient in using PowerBI to provide meaningful insights. As a PowerBI developer, you will collaborate with our team to understand our data requirements and design visually appealing dashboards that effectively communicate key metrics and trends. This role requires excellent problem-solving skills and the ability to work independently. <br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;Responsibilities:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Develop interactive dashboards using PowerBI<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Analyze and visualize data to identify trends and patterns<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Collaborate with stakeholders to understand data requirements<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Optimize dashboards for performance and user experience<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Troubleshoot and resolve issues with existing dashboards<br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;Required Skills:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Minimum 3-4 years of experience in PowerBi Dashboard development<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Proficiency in PowerBI and related tools<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Strong data visualization skills<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Experience in designing and developing interactive dashboards<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Knowledge of data modeling and database concepts<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Excellent problem-solving and analytical abilities<br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;We are looking for a medium-sized team to work on this project, with a duration of 15 - 30 days. The ideal candidate should have an advanced level of expertise in PowerBI development.<br /><br /><br /><b>Posted On</b>: May 13, 2024 07:45 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     Data Visualization,     Data Analysis,     Business Intelligence    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Data Visualization,                     Data Analysis,                     Business Intelligence            <br /><b>Country</b>: India\n<br /><a href="https://www.upwork.com/jobs/PowerBI-Developer-for-Dashboards_%7E01db52a9ad0587d3ad?source=rss">click to apply</a>',
#      'content:encoded': 'We are seeking a skilled PowerBI developer to create interactive dashboards for our organization. The ideal candidate will have a strong background in data visualization and be proficient in using PowerBI to provide meaningful insights. As a PowerBI developer, you will collaborate with our team to understand our data requirements and design visually appealing dashboards that effectively communicate key metrics and trends. This role requires excellent problem-solving skills and the ability to work independently. <br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;Responsibilities:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Develop interactive dashboards using PowerBI<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Analyze and visualize data to identify trends and patterns<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Collaborate with stakeholders to understand data requirements<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Optimize dashboards for performance and user experience<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Troubleshoot and resolve issues with existing dashboards<br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;Required Skills:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Minimum 3-4 years of experience in PowerBi Dashboard development<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Proficiency in PowerBI and related tools<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Strong data visualization skills<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Experience in designing and developing interactive dashboards<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Knowledge of data modeling and database concepts<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Excellent problem-solving and analytical abilities<br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;We are looking for a medium-sized team to work on this project, with a duration of 15 - 30 days. The ideal candidate should have an advanced level of expertise in PowerBI development.<br /><br /><br /><b>Posted On</b>: May 13, 2024 07:45 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     Data Visualization,     Data Analysis,     Business Intelligence    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Data Visualization,                     Data Analysis,                     Business Intelligence            <br /><b>Country</b>: India\n<br /><a href="https://www.upwork.com/jobs/PowerBI-Developer-for-Dashboards_%7E01db52a9ad0587d3ad?source=rss">click to apply</a>',
#      'pubDate': 'Mon, 13 May 2024 07:45:42 +0000',
#      'guid': 'https://www.upwork.com/jobs/PowerBI-Developer-for-Dashboards_%7E01db52a9ad0587d3ad?source=rss'},
#     {'title': 'Power BI Developer - Upwork',
#      'link': 'https://www.upwork.com/jobs/Power-Developer_%7E01ca09bd805598add1?source=rss',
#      'description': 'We are seeking an experienced Power BI Developer to join our team. As a Power BI Developer, you will be responsible for designing, developing, and implementing Power BI solutions. You will work closely with stakeholders to gather requirements, analyze data, and create visualizations and reports. The ideal candidate should have a strong background in data analysis and visualization, with proficiency in Power BI and SQL. Excellent problem-solving and communication skills are essential. <br /><br />\nCustom Financial &amp;amp; KPI reports for 2 organisations. Mainly information from Xero but there will be additional data sources to track KPIs from Google My Business, Streak. I have an idea on the reports required but need to outsource the expertise in getting these developed.<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br /><br />\nResponsibilities:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Design, develop, and maintain Power BI dashboards and reports<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Collaborate with stakeholders to gather requirements and identify data sources<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Analyze complex datasets to create meaningful visualizations and insights<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Optimize Power BI solutions for performance and usability<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Troubleshoot and resolve issues with existing Power BI models and reports<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br /><br />\nRequirements:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Proven experience as a Power BI Developer or similar role<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Proficiency in Power BI, SQL, and data modeling<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Strong analytical and problem-solving skills<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Excellent communication and collaboration abilities<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Attention to detail and ability to meet deadlines<br /><br /><br /><b>Posted On</b>: May 13, 2024 05:53 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     Data Visualization,     Data Analysis,     Business Intelligence    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Data Visualization,                     Data Analysis,                     Business Intelligence            <br /><b>Country</b>: Australia\n<br /><a href="https://www.upwork.com/jobs/Power-Developer_%7E01ca09bd805598add1?source=rss">click to apply</a>',
# ...
#      'content:encoded': 'Looking for a Power BI and SAP SAC expert to support pre-sales activities on a remote, as-needed basis. The role involves preparing presentations, system demos, and providing expert insights to prospective customers.<br /><br />\nResponsibilities:<br />\n- Create and present PowerPoint presentations.<br />\n- Conduct system and capability demos.<br />\n- Serve as a subject matter expert during customer interactions.<br /><br />\nRequirements:<br />\n- Proven experience with Power BI and SAP SAC.<br />\n- Strong presentation and demonstration skills.<br />\n- Excellent communication abilities.<br /><br />\nJob Type: Remote, freelance<br /><br /><b>Hourly Range</b>: $5.00-$20.00\n\n<br /><b>Posted On</b>: May 12, 2024 15:55 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     SAP,     Data Visualization,     Business Intelligence,     Data Modeling,     Data Analysis,     Microsoft Excel,     ETL    \n<br /><b>Skills</b>:        Microsoft Power BI,                     SAP,                     Data Visualization,                     Business Intelligence,                     Data Modeling,                     Data Analysis,                     Microsoft Excel,                     ETL            <br /><b>Country</b>: United Arab Emirates\n<br /><a href="https://www.upwork.com/jobs/Remote-Power-amp-SAP-SAC-Expert_%7E0154f93ba5573aeaaa?source=rss">click to apply</a>',
#      'pubDate': 'Sun, 12 May 2024 15:55:05 +0000',
#      'guid': 'https://www.upwork.com/jobs/Remote-Power-amp-SAP-SAC-Expert_%7E0154f93ba5573aeaaa?source=rss'},
#     {'title': 'Data Analyst/English Business - Upwork',
#      'link': 'https://www.upwork.com/jobs/Data-Analyst-English-Business_%7E01e739a8f4ebd29158?source=rss',
#      'description': 'We are seeking a skilled Data Analyst with a strong command of English for our business. As a Data Analyst, you will be responsible for collecting, analyzing, and interpreting complex data sets to provide valuable insights and recommendations. The ideal candidate should have a solid understanding of statistical methodologies, data visualization, and data mining techniques. <br /><br />\n&nbsp;&nbsp;&nbsp;Responsibilities:<br />\n&nbsp;&nbsp;&nbsp;- Collect and clean data from various sources<br />\n&nbsp;&nbsp;&nbsp;- Perform statistical analysis and generate reports<br />\n&nbsp;&nbsp;&nbsp;- Develop and maintain databases<br />\n&nbsp;&nbsp;&nbsp;- Create data visualizations and dashboards<br />\n&nbsp;&nbsp;&nbsp;- Identify trends and patterns in data<br /><br />\n&nbsp;&nbsp;&nbsp;Requirements:<br />\n&nbsp;&nbsp;&nbsp;- Proven experience as a Data Analyst or in a similar role<br />\n&nbsp;&nbsp;&nbsp;- Strong analytical skills and attention to detail<br />\n&nbsp;&nbsp;&nbsp;- Proficient in SQL and data visualization tools (e.g., Tableau, Power BI)<br />\n&nbsp;&nbsp;&nbsp;- Excellent English communication skills<br /><br />\n&nbsp;&nbsp;&nbsp;This is a medium-sized project with a duration of 1 to 3 months. We are looking for an intermediate-level Data Analyst who can work independently and deliver high-quality results. If you are passionate about data analysis and have a strong business acumen, we would love to hear from you!<br /><br /><b>Hourly Range</b>: $17.00-$50.00\n\n<br /><b>Posted On</b>: May 12, 2024 12:41 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:Microsoft Excel,     English,     Data Entry    \n<br /><b>Skills</b>:        Microsoft Excel,                     English,                     Data Entry            <br /><b>Country</b>: France\n<br /><a href="https://www.upwork.com/jobs/Data-Analyst-English-Business_%7E01e739a8f4ebd29158?source=rss">click to apply</a>',
#      'content:encoded': 'We are seeking a skilled Data Analyst with a strong command of English for our business. As a Data Analyst, you will be responsible for collecting, analyzing, and interpreting complex data sets to provide valuable insights and recommendations. The ideal candidate should have a solid understanding of statistical methodologies, data visualization, and data mining techniques. <br /><br />\n&nbsp;&nbsp;&nbsp;Responsibilities:<br />\n&nbsp;&nbsp;&nbsp;- Collect and clean data from various sources<br />\n&nbsp;&nbsp;&nbsp;- Perform statistical analysis and generate reports<br />\n&nbsp;&nbsp;&nbsp;- Develop and maintain databases<br />\n&nbsp;&nbsp;&nbsp;- Create data visualizations and dashboards<br />\n&nbsp;&nbsp;&nbsp;- Identify trends and patterns in data<br /><br />\n&nbsp;&nbsp;&nbsp;Requirements:<br />\n&nbsp;&nbsp;&nbsp;- Proven experience as a Data Analyst or in a similar role<br />\n&nbsp;&nbsp;&nbsp;- Strong analytical skills and attention to detail<br />\n&nbsp;&nbsp;&nbsp;- Proficient in SQL and data visualization tools (e.g., Tableau, Power BI)<br />\n&nbsp;&nbsp;&nbsp;- Excellent English communication skills<br /><br />\n&nbsp;&nbsp;&nbsp;This is a medium-sized project with a duration of 1 to 3 months. We are looking for an intermediate-level Data Analyst who can work independently and deliver high-quality results. If you are passionate about data analysis and have a strong business acumen, we would love to hear from you!<br /><br /><b>Hourly Range</b>: $17.00-$50.00\n\n<br /><b>Posted On</b>: May 12, 2024 12:41 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:Microsoft Excel,     English,     Data Entry    \n<br /><b>Skills</b>:        Microsoft Excel,                     English,                     Data Entry            <br /><b>Country</b>: France\n<br /><a href="https://www.upwork.com/jobs/Data-Analyst-English-Business_%7E01e739a8f4ebd29158?source=rss">click to apply</a>',
#      'pubDate': 'Sun, 12 May 2024 12:41:52 +0000',
#      'guid': 'https://www.upwork.com/jobs/Data-Analyst-English-Business_%7E01e739a8f4ebd29158?source=rss'},
#     {'title': 'Seeking freelance sports statistician, ideally with knowledge of NFL/MLB  - Upwork',
#      'link': 'https://www.upwork.com/jobs/Seeking-freelance-sports-statistician-ideally-with-knowledge-NFL-MLB_%7E01e15b42ace6635baa?source=rss',
#      'description': 'We are seeking someone who would be able to generate some statistics for us. We are looking for a sports statistician that we could hire for this this, ideally with knowledge of the NFL, although we could also do baseball/MLB too. We need someone to crunch the data and identify and rank the teams in different sports that &ldquo;peak too soon&rdquo; &ndash; and also maybe the ones that &ldquo;stay strong&rdquo; and/or &ldquo;finish strong&rdquo;. We could define &ldquo;peaking too soon&rdquo; to mean either consistently peaking too early in the game or peaking too soon in a season &ndash; or some combination of both. <br /><br />\nLet me know if this is something you could help us with! <br /><br /><br /><b>Posted On</b>: May 12, 2024 11:13 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:Data Science,     Visualization,     Microsoft Power BI Data Visualization,     Data Analytics,     Analytics,     Analytical Presentation,     Data Analysis,     R,     Microsoft Excel,     Microsoft Power BI,     Microsoft PowerPoint,     Python    \n<br /><b>Skills</b>:        Data Science,                     Visualization,                     Microsoft Power BI Data Visualization,                     Data Analytics,                     Analytics,                     Analytical Presentation,                     Data Analysis,                     R,                     Microsoft Excel,                     Microsoft Power BI,                     Microsoft PowerPoint,                     Python            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Seeking-freelance-sports-statistician-ideally-with-knowledge-NFL-MLB_%7E01e15b42ace6635baa?source=rss">click to apply</a>',
#      'content:encoded': 'We are seeking someone who would be able to generate some statistics for us. We are looking for a sports statistician that we could hire for this this, ideally with knowledge of the NFL, although we could also do baseball/MLB too. We need someone to crunch the data and identify and rank the teams in different sports that &ldquo;peak too soon&rdquo; &ndash; and also maybe the ones that &ldquo;stay strong&rdquo; and/or &ldquo;finish strong&rdquo;. We could define &ldquo;peaking too soon&rdquo; to mean either consistently peaking too early in the game or peaking too soon in a season &ndash; or some combination of both. <br /><br />\nLet me know if this is something you could help us with! <br /><br /><br /><b>Posted On</b>: May 12, 2024 11:13 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:Data Science,     Visualization,     Microsoft Power BI Data Visualization,     Data Analytics,     Analytics,     Analytical Presentation,     Data Analysis,     R,     Microsoft Excel,     Microsoft Power BI,     Microsoft PowerPoint,     Python    \n<br /><b>Skills</b>:        Data Science,                     Visualization,                     Microsoft Power BI Data Visualization,                     Data Analytics,                     Analytics,                     Analytical Presentation,                     Data Analysis,                     R,                     Microsoft Excel,                     Microsoft Power BI,                     Microsoft PowerPoint,                     Python            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Seeking-freelance-sports-statistician-ideally-with-knowledge-NFL-MLB_%7E01e15b42ace6635baa?source=rss">click to apply</a>',
#      'pubDate': 'Sun, 12 May 2024 11:13:35 +0000',
#      'guid': 'https://www.upwork.com/jobs/Seeking-freelance-sports-statistician-ideally-with-knowledge-NFL-MLB_%7E01e15b42ace6635baa?source=rss'},
#     {'title': 'Power BI Expert Needed for Data Scraping - Upwork',
#      'link': 'https://www.upwork.com/jobs/Power-Expert-Needed-for-Data-Scraping_%7E01e0a2091f6c4ac120?source=rss',
#      'description': 'Extract Specific contact information (name, address, phone number &amp;amp; email address) from a power BI website. Create a Dynamic Excel Spreadsheet that can be refreshed when needed.&nbsp;&nbsp;<br />\nI created a ppt that explains in more detail the objective and were to get the infomation. <br />\nFor someone profecient with Power BI, it should be easy to &amp;quot;Get Data&amp;quot; then clean up the spreadsheet to meet minimum requirements. <br /><br /><br /><br /><b>Budget</b>: $50\n<br /><b>Posted On</b>: May 12, 2024 09:16 UTC<br /><b>Category</b>: Data Extraction<br /><b>Skills</b>:Microsoft Power BI,     Microsoft Excel,     Data Scraping,     Data Mining    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Microsoft Excel,                     Data Scraping,                     Data Mining            <br /><b>Country</b>: United States\n<br /><a href="https://www.upwork.com/jobs/Power-Expert-Needed-for-Data-Scraping_%7E01e0a2091f6c4ac120?source=rss">click to apply</a>',
#      'content:encoded': 'Extract Specific contact information (name, address, phone number &amp;amp; email address) from a power BI website. Create a Dynamic Excel Spreadsheet that can be refreshed when needed.&nbsp;&nbsp;<br />\nI created a ppt that explains in more detail the objective and were to get the infomation. <br />\nFor someone profecient with Power BI, it should be easy to &amp;quot;Get Data&amp;quot; then clean up the spreadsheet to meet minimum requirements. <br /><br /><br /><br /><b>Budget</b>: $50\n<br /><b>Posted On</b>: May 12, 2024 09:16 UTC<br /><b>Category</b>: Data Extraction<br /><b>Skills</b>:Microsoft Power BI,     Microsoft Excel,     Data Scraping,     Data Mining    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Microsoft Excel,                     Data Scraping,                     Data Mining            <br /><b>Country</b>: United States\n<br /><a href="https://www.upwork.com/jobs/Power-Expert-Needed-for-Data-Scraping_%7E01e0a2091f6c4ac120?source=rss">click to apply</a>',
#      'pubDate': 'Sun, 12 May 2024 09:16:33 +0000',
#      'guid': 'https://www.upwork.com/jobs/Power-Expert-Needed-for-Data-Scraping_%7E01e0a2091f6c4ac120?source=rss'},
#     {'title': 'Build a recruitment excel tracker and KPI analytics  - Upwork',
#      'link': 'https://www.upwork.com/jobs/Build-recruitment-excel-tracker-and-KPI-analytics_%7E01ec3a2a8d0d7cb198?source=rss',
#      'description': 'Hi, I work as a recruiter for a tech company and looking for someone to help me build a good excel tracker with analytics I can use to track recruitment activity at the company. <br /><br />\nI have already created a draft version on excel to give you an idea of the information I need captured. I need someone to take the draft and create a better version that is easily customisable, where all the data flows through seamlessly across each tabs with a main dashboard that summarises the key recruitment KPI&#039;s.<br /><br />\nThe purpose of the tracker is capture information such as the below (these are some of them)<br /><br />\n- Total open vacancies <br />\n- Total offers made in March 2024 <br />\n- Total offers made in Q1 2024<br />\n- Offer acceptance %<br />\n- Time to hire %<br />\n- Average source of hire (did hires come through Linkedin, careers page, job advert etc)<br />\n- Total hires made in each global office by month, by quarter, by year<br /><br /><br /><b>Posted On</b>: May 12, 2024 09:16 UTC<br /><b>Category</b>: Recruiting &amp; Talent Sourcing<br /><b>Skills</b>:Microsoft Excel,     Data Visualization,     Analytics,     Microsoft Power BI,     Tableau    \n<br /><b>Skills</b>:        Microsoft Excel,                     Data Visualization,                     Analytics,                     Microsoft Power BI,                     Tableau            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Build-recruitment-excel-tracker-and-KPI-analytics_%7E01ec3a2a8d0d7cb198?source=rss">click to apply</a>',
#      'content:encoded': 'Hi, I work as a recruiter for a tech company and looking for someone to help me build a good excel tracker with analytics I can use to track recruitment activity at the company. <br /><br />\nI have already created a draft version on excel to give you an idea of the information I need captured. I need someone to take the draft and create a better version that is easily customisable, where all the data flows through seamlessly across each tabs with a main dashboard that summarises the key recruitment KPI&#039;s.<br /><br />\nThe purpose of the tracker is capture information such as the below (these are some of them)<br /><br />\n- Total open vacancies <br />\n- Total offers made in March 2024 <br />\n- Total offers made in Q1 2024<br />\n- Offer acceptance %<br />\n- Time to hire %<br />\n- Average source of hire (did hires come through Linkedin, careers page, job advert etc)<br />\n- Total hires made in each global office by month, by quarter, by year<br /><br /><br /><b>Posted On</b>: May 12, 2024 09:16 UTC<br /><b>Category</b>: Recruiting &amp; Talent Sourcing<br /><b>Skills</b>:Microsoft Excel,     Data Visualization,     Analytics,     Microsoft Power BI,     Tableau    \n<br /><b>Skills</b>:        Microsoft Excel,                     Data Visualization,                     Analytics,                     Microsoft Power BI,                     Tableau            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Build-recruitment-excel-tracker-and-KPI-analytics_%7E01ec3a2a8d0d7cb198?source=rss">click to apply</a>',
#      'pubDate': 'Sun, 12 May 2024 09:16:23 +0000',
#      'guid': 'https://www.upwork.com/jobs/Build-recruitment-excel-tracker-and-KPI-analytics_%7E01ec3a2a8d0d7cb198?source=rss'}]}}}

# %%
#Getting the number of job descriptions in the first file
jobs_lenght = len(json_file1["rss"]['channel']['item'])
print(jobs_lenght)
# Out:
# 30

# %%
#Data template: (PSEUDOCODE)
#for file in files:
    #file_name = file + "processed"
    #output["jobs"]=[{}] #optional?
    #output["title"] = json_file1["rss"]['channel']["title"]
    #output["link"] = json_file1["rss"]['channel']["link"]
    #output["language"] = json_file1["rss"]['channel']["language"]
    #output["pubDate"] = json_file1["rss"]['channel']["pubdate"]
    #for description in descriptions (len(json_file1["rss"]['channel']['item'])) #list of descriptions
        #to delete #output["jobs"][n][""] = json_file1["rss"]['channel']['item'][n] # should i use append? .append() # I need specific things here
        #job = {}
        #job["title"] = output["jobs"][n]["title"]
        #job["link"] = output["jobs"][n]["link"]
        #job["description"] = output["jobs"][n]["content:encoded"]
        #job["pubDate"] = output["jobs"][n]["pubDate"]
        #output["jobs"].append(job) # should i use append? .append() # Ineed specific things here
    #with open(file_path, 'wb') as file:
        #file.write(output)
    #print(f"Json file processed successfully and saved as {file_name}.")

# %%
#1 output exemple
output_test={
    "title":"All jobs | upwork.com",
    "link":"https://www.upwork.com/ab/feed/jobs/rss?api_params=1&amp;orgUid=1729067928257851393&amp;paging=0-10&amp;q=Power%20Bi&amp;securityToken=d17308910f66b74d222ca66c907efa56c942739d41db7bba3da3ca225a9584b2edcab156ed12fcd81a0f94e952ea29d611248991196927c716632e2284293c57&amp;sort=recency&amp;userUid=1729067928257851392",
    "description":"All jobs as of May 13, 2024 12:22 UTC",
    "language":"en-us",
    "pubDate":"Mon, 13 May 2024 12:22:38 +0000",
    "jobs":[
            {
               "title":"Professional dashboard built in MicroStrategy - Upwork",
               "link":"https://www.upwork.com/jobs/Professional-dashboard-built-MicroStrategy_%7E01ec8934d454ff0ef3?source=rss",
               #Replace old "description" with "content:encoded"
               #content:encoded------------------------------------------------------
               "description":"Hi<br /><br />\n I am looking for a professional dashboard built in MicroStrategy, using advanced visualizations and automation. The dataset is small&nbsp;&nbsp;(about 107 rows)and straight forward. Also please indicate how long will it take for you to do the job?<br /><br />\nThanks<br />\nCharu<br /><br /><br /><br /><b>Posted On</b>: May 13, 2024 09:46 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI Data Visualization,     Microsoft Power BI,     Dashboard,     Business Intelligence,     SQL,     Microsoft Power BI Development,     Database,     Microsoft Excel,     Data Mining,     BigQuery,     Data Visualization,     Analytics Dashboard,     Data Modeling,     Data Analytics    \n<br /><b>Skills</b>:        Microsoft Power BI Data Visualization,                     Microsoft Power BI,                     Dashboard,                     Business Intelligence,                     SQL,                     Microsoft Power BI Development,                     Database,                     Microsoft Excel,                     Data Mining,                     BigQuery,                     Data Visualization,                     Analytics Dashboard,                     Data Modeling,                     Data Analytics            <br /><b>Country</b>: United Kingdom\n<br /><a href=\"https://www.upwork.com/jobs/Professional-dashboard-built-MicroStrategy_%7E01ec8934d454ff0ef3?source=rss\">click to apply</a>",
               #---------------------------------------------------------------------
               "pubDate":"Mon, 13 May 2024 09:46:45 +0000"
            },
            {
               "title":"Power BI Developer - Upwork",
               "link":"https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss",
               #to delete------------------------------------------------------
               "description":"We are seeking a Power BI Developer to assist with our data visualization and reporting needs. The ideal candidate will have experience in creating interactive dashboards and reports using Power BI tools. Key responsibilities include: <br /><br />\n- Creating visually appealing and informative dashboards.<br />\n- Building data models and establishing connections to various data sources.<br />\n- Generating reports and insights that meet business requirements.<br /><br />\n Qualifications:<br />\n- Proficiency in Power BI Desktop, Power Query, DAX, and M languages<br />\n- Familiarity with SQL, data warehousing concepts, and ETL processes is a plus.<br />\n- Experience in data visualization principles and best practices.<br /><br /><b>Hourly Range</b>: $25.00-$60.00\n\n<br /><b>Posted On</b>: May 13, 2024 09:44 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Data Analysis Expressions,     Microsoft Power BI,     Data Visualization,     Business Intelligence,     Microsoft Power BI Development,     Power Query,     Microsoft SharePoint    \n<br /><b>Skills</b>:        Data Analysis Expressions,                     Microsoft Power BI,                     Data Visualization,                     Business Intelligence,                     Microsoft Power BI Development,                     Power Query,                     Microsoft SharePoint            <br /><b>Country</b>: Philippines\n<br /><a href=\"https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss\">click to apply</a>",
               #--------------------------------------------------------------
               "content:encoded":"We are seeking a Power BI Developer to assist with our data visualization and reporting needs. The ideal candidate will have experience in creating interactive dashboards and reports using Power BI tools. Key responsibilities include: <br /><br />\n- Creating visually appealing and informative dashboards.<br />\n- Building data models and establishing connections to various data sources.<br />\n- Generating reports and insights that meet business requirements.<br /><br />\n Qualifications:<br />\n- Proficiency in Power BI Desktop, Power Query, DAX, and M languages<br />\n- Familiarity with SQL, data warehousing concepts, and ETL processes is a plus.<br />\n- Experience in data visualization principles and best practices.<br /><br /><b>Hourly Range</b>: $25.00-$60.00\n\n<br /><b>Posted On</b>: May 13, 2024 09:44 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Data Analysis Expressions,     Microsoft Power BI,     Data Visualization,     Business Intelligence,     Microsoft Power BI Development,     Power Query,     Microsoft SharePoint    \n<br /><b>Skills</b>:        Data Analysis Expressions,                     Microsoft Power BI,                     Data Visualization,                     Business Intelligence,                     Microsoft Power BI Development,                     Power Query,                     Microsoft SharePoint            <br /><b>Country</b>: Philippines\n<br /><a href=\"https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss\">click to apply</a>",
               "pubDate":"Mon, 13 May 2024 09:44:11 +0000",
               #to delete------------------------------------------------------
               "guid":"https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss"
               #--------------------------------------------------------------
            },
            #[...]
            ]
        }

# %%
#Here we will define the function that will clean the descriptions (HTML + /n)

#REGEX 
#balises <.*?>
#\\n

#compile once only
#CLEANR = re.compile('<.*?>') # All HTML tags (not special cases)
CLEANR = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});') # All HTML content (including special cases)
CLEANS = re.compile('\\n') #get rid of all \n

def cleanhtml(raw_html):
  nohtml = re.sub(CLEANR, '', raw_html) #remove HTML
  no_slashn = re.sub(CLEANS, '', nohtml) #remove \n
  cleantext = " ".join(no_slashn.split()) #remove extra spaces
  return cleantext

# %%
#Testing cleanhtml() function
description = output_test["jobs"][0]['description']

job_1_cleaned = cleanhtml(description)

print(job_1_cleaned)
# Out:
# Hi I am looking for a professional dashboard built in MicroStrategy, using advanced visualizations and automation. The dataset is small(about 107 rows)and straight forward. Also please indicate how long will it take for you to do the job?ThanksCharuPosted On: May 13, 2024 09:46 UTCCategory: Data VisualizationSkills:Microsoft Power BI Data Visualization, Microsoft Power BI, Dashboard, Business Intelligence, SQL, Microsoft Power BI Development, Database, Microsoft Excel, Data Mining, BigQuery, Data Visualization, Analytics Dashboard, Data Modeling, Data Analytics Skills: Microsoft Power BI Data Visualization, Microsoft Power BI, Dashboard, Business Intelligence, SQL, Microsoft Power BI Development, Database, Microsoft Excel, Data Mining, BigQuery, Data Visualization, Analytics Dashboard, Data Modeling, Data Analytics Country: United Kingdomclick to apply

# %%
output_test = json_file1["rss"]['channel']['item']
jobs_lenght = len(output_test)
print(jobs_lenght)
output_test
# Out:
# 30
# [{'title': 'Professional dashboard built in MicroStrategy - Upwork',
#   'link': 'https://www.upwork.com/jobs/Professional-dashboard-built-MicroStrategy_%7E01ec8934d454ff0ef3?source=rss',
#   'description': 'Hi<br /><br />\n I am looking for a professional dashboard built in MicroStrategy, using advanced visualizations and automation. The dataset is small&nbsp;&nbsp;(about 107 rows)and straight forward. Also please indicate how long will it take for you to do the job?<br /><br />\nThanks<br />\nCharu<br /><br /><br /><br /><b>Posted On</b>: May 13, 2024 09:46 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI Data Visualization,     Microsoft Power BI,     Dashboard,     Business Intelligence,     SQL,     Microsoft Power BI Development,     Database,     Microsoft Excel,     Data Mining,     BigQuery,     Data Visualization,     Analytics Dashboard,     Data Modeling,     Data Analytics    \n<br /><b>Skills</b>:        Microsoft Power BI Data Visualization,                     Microsoft Power BI,                     Dashboard,                     Business Intelligence,                     SQL,                     Microsoft Power BI Development,                     Database,                     Microsoft Excel,                     Data Mining,                     BigQuery,                     Data Visualization,                     Analytics Dashboard,                     Data Modeling,                     Data Analytics            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Professional-dashboard-built-MicroStrategy_%7E01ec8934d454ff0ef3?source=rss">click to apply</a>',
#   'content:encoded': 'Hi<br /><br />\n I am looking for a professional dashboard built in MicroStrategy, using advanced visualizations and automation. The dataset is small&nbsp;&nbsp;(about 107 rows)and straight forward. Also please indicate how long will it take for you to do the job?<br /><br />\nThanks<br />\nCharu<br /><br /><br /><br /><b>Posted On</b>: May 13, 2024 09:46 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI Data Visualization,     Microsoft Power BI,     Dashboard,     Business Intelligence,     SQL,     Microsoft Power BI Development,     Database,     Microsoft Excel,     Data Mining,     BigQuery,     Data Visualization,     Analytics Dashboard,     Data Modeling,     Data Analytics    \n<br /><b>Skills</b>:        Microsoft Power BI Data Visualization,                     Microsoft Power BI,                     Dashboard,                     Business Intelligence,                     SQL,                     Microsoft Power BI Development,                     Database,                     Microsoft Excel,                     Data Mining,                     BigQuery,                     Data Visualization,                     Analytics Dashboard,                     Data Modeling,                     Data Analytics            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Professional-dashboard-built-MicroStrategy_%7E01ec8934d454ff0ef3?source=rss">click to apply</a>',
#   'pubDate': 'Mon, 13 May 2024 09:46:45 +0000',
#   'guid': 'https://www.upwork.com/jobs/Professional-dashboard-built-MicroStrategy_%7E01ec8934d454ff0ef3?source=rss'},
#  {'title': 'Power BI Developer - Upwork',
#   'link': 'https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss',
#   'description': 'We are seeking a Power BI Developer to assist with our data visualization and reporting needs. The ideal candidate will have experience in creating interactive dashboards and reports using Power BI tools. Key responsibilities include: <br /><br />\n- Creating visually appealing and informative dashboards.<br />\n- Building data models and establishing connections to various data sources.<br />\n- Generating reports and insights that meet business requirements.<br /><br />\n Qualifications:<br />\n- Proficiency in Power BI Desktop, Power Query, DAX, and M languages<br />\n- Familiarity with SQL, data warehousing concepts, and ETL processes is a plus.<br />\n- Experience in data visualization principles and best practices.<br /><br /><b>Hourly Range</b>: $25.00-$60.00\n\n<br /><b>Posted On</b>: May 13, 2024 09:44 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Data Analysis Expressions,     Microsoft Power BI,     Data Visualization,     Business Intelligence,     Microsoft Power BI Development,     Power Query,     Microsoft SharePoint    \n<br /><b>Skills</b>:        Data Analysis Expressions,                     Microsoft Power BI,                     Data Visualization,                     Business Intelligence,                     Microsoft Power BI Development,                     Power Query,                     Microsoft SharePoint            <br /><b>Country</b>: Philippines\n<br /><a href="https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss">click to apply</a>',
#   'content:encoded': 'We are seeking a Power BI Developer to assist with our data visualization and reporting needs. The ideal candidate will have experience in creating interactive dashboards and reports using Power BI tools. Key responsibilities include: <br /><br />\n- Creating visually appealing and informative dashboards.<br />\n- Building data models and establishing connections to various data sources.<br />\n- Generating reports and insights that meet business requirements.<br /><br />\n Qualifications:<br />\n- Proficiency in Power BI Desktop, Power Query, DAX, and M languages<br />\n- Familiarity with SQL, data warehousing concepts, and ETL processes is a plus.<br />\n- Experience in data visualization principles and best practices.<br /><br /><b>Hourly Range</b>: $25.00-$60.00\n\n<br /><b>Posted On</b>: May 13, 2024 09:44 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Data Analysis Expressions,     Microsoft Power BI,     Data Visualization,     Business Intelligence,     Microsoft Power BI Development,     Power Query,     Microsoft SharePoint    \n<br /><b>Skills</b>:        Data Analysis Expressions,                     Microsoft Power BI,                     Data Visualization,                     Business Intelligence,                     Microsoft Power BI Development,                     Power Query,                     Microsoft SharePoint            <br /><b>Country</b>: Philippines\n<br /><a href="https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss">click to apply</a>',
#   'pubDate': 'Mon, 13 May 2024 09:44:11 +0000',
#   'guid': 'https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss'},
#  {'title': 'Sports Analytics Expert Needed - Upwork',
#   'link': 'https://www.upwork.com/jobs/Sports-Analytics-Expert-Needed_%7E01eee8d1e717ced124?source=rss',
#   'description': 'We are seeking a skilled sports analytics expert to analyze a comprehensive dataset of cricket player statistics. The goal is to derive actionable insights and identify the impact of various factors on the game, enabling data-driven decision-making to enhance team performance.<br /><br />\nResponsibilities:<br />\nConduct detailed analysis of key performance indicators (KPIs) such as batting average, strike rate, bowling economy, and fielding effectiveness.<br />\nIdentify performance trends and patterns over time, including player career progression and consistency.<br />\nPerform comparative analysis of player performance against different teams, in various formats (Test, ODI, T20), and under different conditions (home/away, pitch types, weather).<br />\nAnalyze player strengths and weaknesses, including performance against specific opponents and in high-pressure situations.<br />\nAssess match-winning performances and overall contribution to team success.<br />\nUse advanced analytical techniques such as cluster analysis, predictive modeling to uncover deeper insights.<br />\nCreate interactive dashboards and visualizations to present findings in an engaging and accessible manner.<br /><br />\nDeliverables:<br />\nComprehensive report detailing the analysis findings, including statistical summaries, visualizations, and key insights with codes.<br />\nInteractive dashboards using tools like Tableau or Power BI for dynamic data exploration.<br />\nRecommendations for optimizing player roles and strategies based on the analysis.<br />\nIdentification of potential areas for performance improvement and strategic adjustments.<br /><br /><br />\nQualifications:<br />\nProven experience in sports analytics, particularly with cricket datasets.<br />\nStrong understanding of cricket, including rules, player roles, and game dynamics.<br />\nProficiency in data analysis tools and programming languages such as R, Python, or SQL.<br />\nExperience with data visualization tools like Tableau, Power BI, or similar platforms.<br />\nAbility to communicate complex analytical findings in a clear and concise manner.<br />\nPassion for sports analytics and a keen eye for detail.<br /><br /><b>Hourly Range</b>: $5.00-$40.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:46 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:R,     Data Visualization,     Microsoft Excel,     Google Analytics,     Search Engine Optimization,     Data Analysis,     Machine Learning,     Analytics    \n<br /><b>Skills</b>:        R,                     Data Visualization,                     Microsoft Excel,                     Google Analytics,                     Search Engine Optimization,                     Data Analysis,                     Machine Learning,                     Analytics            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Sports-Analytics-Expert-Needed_%7E01eee8d1e717ced124?source=rss">click to apply</a>',
#   'content:encoded': 'We are seeking a skilled sports analytics expert to analyze a comprehensive dataset of cricket player statistics. The goal is to derive actionable insights and identify the impact of various factors on the game, enabling data-driven decision-making to enhance team performance.<br /><br />\nResponsibilities:<br />\nConduct detailed analysis of key performance indicators (KPIs) such as batting average, strike rate, bowling economy, and fielding effectiveness.<br />\nIdentify performance trends and patterns over time, including player career progression and consistency.<br />\nPerform comparative analysis of player performance against different teams, in various formats (Test, ODI, T20), and under different conditions (home/away, pitch types, weather).<br />\nAnalyze player strengths and weaknesses, including performance against specific opponents and in high-pressure situations.<br />\nAssess match-winning performances and overall contribution to team success.<br />\nUse advanced analytical techniques such as cluster analysis, predictive modeling to uncover deeper insights.<br />\nCreate interactive dashboards and visualizations to present findings in an engaging and accessible manner.<br /><br />\nDeliverables:<br />\nComprehensive report detailing the analysis findings, including statistical summaries, visualizations, and key insights with codes.<br />\nInteractive dashboards using tools like Tableau or Power BI for dynamic data exploration.<br />\nRecommendations for optimizing player roles and strategies based on the analysis.<br />\nIdentification of potential areas for performance improvement and strategic adjustments.<br /><br /><br />\nQualifications:<br />\nProven experience in sports analytics, particularly with cricket datasets.<br />\nStrong understanding of cricket, including rules, player roles, and game dynamics.<br />\nProficiency in data analysis tools and programming languages such as R, Python, or SQL.<br />\nExperience with data visualization tools like Tableau, Power BI, or similar platforms.<br />\nAbility to communicate complex analytical findings in a clear and concise manner.<br />\nPassion for sports analytics and a keen eye for detail.<br /><br /><b>Hourly Range</b>: $5.00-$40.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:46 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:R,     Data Visualization,     Microsoft Excel,     Google Analytics,     Search Engine Optimization,     Data Analysis,     Machine Learning,     Analytics    \n<br /><b>Skills</b>:        R,                     Data Visualization,                     Microsoft Excel,                     Google Analytics,                     Search Engine Optimization,                     Data Analysis,                     Machine Learning,                     Analytics            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Sports-Analytics-Expert-Needed_%7E01eee8d1e717ced124?source=rss">click to apply</a>',
#   'pubDate': 'Mon, 13 May 2024 08:46:15 +0000',
#   'guid': 'https://www.upwork.com/jobs/Sports-Analytics-Expert-Needed_%7E01eee8d1e717ced124?source=rss'},
#  {'title': 'Data analyst/BI expert to help automate a series of analytics reports - Upwork',
#   'link': 'https://www.upwork.com/jobs/Data-analyst-expert-help-automate-series-analytics-reports_%7E017e99068e70711d6b?source=rss',
#   'description': '<br />\nwrite a scope of work that is focused on data consumer behavior and other important key metrics that will enable the dealership to sell smarter to its customers. <br />\nSkills required are pyhthon, sql and powerbi<br />\nDeliverables:<br />\n&bull;\tDefined and prioritized KPIs for sales and marketing<br />\n&bull;\tCustomer segmentation insights and reports<br />\n&bull;\tRecommendations for targeted marketing campaigns across various channels<br />\n&bull;\tData-driven strategies for optimizing the sales process<br />\n&bull;\tOngoing reporting dashboards<br />\n&bull;\tFinal report with actionable recommendations<br /><br />\ncommunication will be via email and Microsoft teams<br /><br /><b>Budget</b>: $500\n<br /><b>Posted On</b>: May 13, 2024 09:27 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:SQL,     Microsoft Power BI,     Business Intelligence,     Python    \n<br /><b>Skills</b>:        SQL,                     Microsoft Power BI,                     Business Intelligence,                     Python            <br /><b>Country</b>: South Africa\n<br /><a href="https://www.upwork.com/jobs/Data-analyst-expert-help-automate-series-analytics-reports_%7E017e99068e70711d6b?source=rss">click to apply</a>',
#   'content:encoded': '<br />\nwrite a scope of work that is focused on data consumer behavior and other important key metrics that will enable the dealership to sell smarter to its customers. <br />\nSkills required are pyhthon, sql and powerbi<br />\nDeliverables:<br />\n&bull;\tDefined and prioritized KPIs for sales and marketing<br />\n&bull;\tCustomer segmentation insights and reports<br />\n&bull;\tRecommendations for targeted marketing campaigns across various channels<br />\n&bull;\tData-driven strategies for optimizing the sales process<br />\n&bull;\tOngoing reporting dashboards<br />\n&bull;\tFinal report with actionable recommendations<br /><br />\ncommunication will be via email and Microsoft teams<br /><br /><b>Budget</b>: $500\n<br /><b>Posted On</b>: May 13, 2024 09:27 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:SQL,     Microsoft Power BI,     Business Intelligence,     Python    \n<br /><b>Skills</b>:        SQL,                     Microsoft Power BI,                     Business Intelligence,                     Python            <br /><b>Country</b>: South Africa\n<br /><a href="https://www.upwork.com/jobs/Data-analyst-expert-help-automate-series-analytics-reports_%7E017e99068e70711d6b?source=rss">click to apply</a>',
#   'pubDate': 'Mon, 13 May 2024 09:27:40 +0000',
#   'guid': 'https://www.upwork.com/jobs/Data-analyst-expert-help-automate-series-analytics-reports_%7E017e99068e70711d6b?source=rss'},
#  {'title': 'Real Estate Listing and Transaction Database with Predictive Analytics - Upwork',
#   'link': 'https://www.upwork.com/jobs/Real-Estate-Listing-and-Transaction-Database-with-Predictive-Analytics_%7E01b4961d51a60e9f07?source=rss',
#   'description': 'We are seeking a skilled data engineer and data scientist to create a comprehensive real estate database that tracks listings and transactions on a weekly basis. The goal of this project is to develop a tool that can predict real estate price movements and identify underpriced properties using Microsoft Azure Machine Learning.<br /><br />\nResponsibilities:<br /><br />\n1. Design and create an SQL database to store real estate listings and transactions.<br /><br />\n2. Develop scripts to collect real estate data from various sources and update the database weekly.<br /><br />\n3. Implement data cleaning and deduplication processes to ensure data integrity and accuracy.<br /><br />\n4. Track changes in listings on a weekly basis and store historical data for analysis.<br /><br />\n5. Connect the database to Power BI to create interactive dashboards and visualizations for data analysis.<br /><br />\n6. Utilize Microsoft Azure Machine Learning to develop models for predicting real estate price movements and identifying underpriced properties.<br /><br />\n7. Provide functionality to export data from the SQL database to Excel for further analysis.<br /><br />\n8. Provide documentation and support for the database, analytics tools, and machine learning models.<br /><br />\nRequirements:<br /><br />\n1. Experience with SQL database design and management.<br /><br />\n2. Proficiency in data collection and web scraping using Python or other relevant tools.<br /><br />\n3. Knowledge of data cleaning, deduplication, and data transformation techniques.<br /><br />\n4. Familiarity with Power BI or similar data visualization tools.<br /><br />\n5. Experience with Microsoft Azure Machine Learning or similar cloud-based machine learning platforms.<br /><br />\n6. Strong problem-solving and analytical skills.<br /><br />\n7. Good communication skills and ability to work independently.<br /><br />\nDeliverables:<br /><br />\n1. A functional SQL database populated with real estate listings and transactions.<br /><br />\n2. Scripts to collect and update data weekly.<br /><br />\n3. Data cleaning and deduplication processes implemented within the database.<br /><br />\n4. Power BI dashboards and reports for data visualization and analysis.<br /><br />\n5. Machine learning models developed using Azure Machine Learning for predicting real estate price movements and identifying underpriced properties.<br /><br />\n6. Functionality to export data from the SQL database to Excel.<br />\nDocumentation for the database, data collection scripts, analytics components, and machine learning models.<br /><br />\nTimeline:<br /><br />\nThe project is expected to take approximately 4-6 weeks to complete, with regular progress updates throughout the duration of the project.<br /><br />\nBudget:<br /><br />\nThe budget for this project is set at $1,500, which includes the development of the database, data collection scripts, data cleaning processes, Power BI integration, and machine learning models using Microsoft Azure Machine Learning.<br /><br />\nIf you have the required skills and experience and can work within the specified budget and timeline, please submit your proposal, including a project plan and timeline. We look forward to working with a talented data engineer and data scientist to bring this project to life.<br /><br />\nPlease note that the ability to export data from the SQL database to Excel is considered part of the core functionality and does not need to be separately mentioned in the job description. It is assumed that the data engineer will provide this capability as part of the database development process.<br /><br /><b>Budget</b>: $1,500\n<br /><b>Posted On</b>: May 13, 2024 09:18 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:SQL,     Microsoft Power BI,     Data Entry,     Data Analysis,     Data Scraping,     Data Mining,     Python,     Microsoft Excel,     Microsoft Azure SQL Database,     Machine Learni ...
#   'content:encoded': 'We are seeking a skilled data engineer and data scientist to create a comprehensive real estate database that tracks listings and transactions on a weekly basis. The goal of this project is to develop a tool that can predict real estate price movements and identify underpriced properties using Microsoft Azure Machine Learning.<br /><br />\nResponsibilities:<br /><br />\n1. Design and create an SQL database to store real estate listings and transactions.<br /><br />\n2. Develop scripts to collect real estate data from various sources and update the database weekly.<br /><br />\n3. Implement data cleaning and deduplication processes to ensure data integrity and accuracy.<br /><br />\n4. Track changes in listings on a weekly basis and store historical data for analysis.<br /><br />\n5. Connect the database to Power BI to create interactive dashboards and visualizations for data analysis.<br /><br />\n6. Utilize Microsoft Azure Machine Learning to develop models for predicting real estate price movements and identifying underpriced properties.<br /><br />\n7. Provide functionality to export data from the SQL database to Excel for further analysis.<br /><br />\n8. Provide documentation and support for the database, analytics tools, and machine learning models.<br /><br />\nRequirements:<br /><br />\n1. Experience with SQL database design and management.<br /><br />\n2. Proficiency in data collection and web scraping using Python or other relevant tools.<br /><br />\n3. Knowledge of data cleaning, deduplication, and data transformation techniques.<br /><br />\n4. Familiarity with Power BI or similar data visualization tools.<br /><br />\n5. Experience with Microsoft Azure Machine Learning or similar cloud-based machine learning platforms.<br /><br />\n6. Strong problem-solving and analytical skills.<br /><br />\n7. Good communication skills and ability to work independently.<br /><br />\nDeliverables:<br /><br />\n1. A functional SQL database populated with real estate listings and transactions.<br /><br />\n2. Scripts to collect and update data weekly.<br /><br />\n3. Data cleaning and deduplication processes implemented within the database.<br /><br />\n4. Power BI dashboards and reports for data visualization and analysis.<br /><br />\n5. Machine learning models developed using Azure Machine Learning for predicting real estate price movements and identifying underpriced properties.<br /><br />\n6. Functionality to export data from the SQL database to Excel.<br />\nDocumentation for the database, data collection scripts, analytics components, and machine learning models.<br /><br />\nTimeline:<br /><br />\nThe project is expected to take approximately 4-6 weeks to complete, with regular progress updates throughout the duration of the project.<br /><br />\nBudget:<br /><br />\nThe budget for this project is set at $1,500, which includes the development of the database, data collection scripts, data cleaning processes, Power BI integration, and machine learning models using Microsoft Azure Machine Learning.<br /><br />\nIf you have the required skills and experience and can work within the specified budget and timeline, please submit your proposal, including a project plan and timeline. We look forward to working with a talented data engineer and data scientist to bring this project to life.<br /><br />\nPlease note that the ability to export data from the SQL database to Excel is considered part of the core functionality and does not need to be separately mentioned in the job description. It is assumed that the data engineer will provide this capability as part of the database development process.<br /><br /><b>Budget</b>: $1,500\n<br /><b>Posted On</b>: May 13, 2024 09:18 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:SQL,     Microsoft Power BI,     Data Entry,     Data Analysis,     Data Scraping,     Data Mining,     Python,     Microsoft Excel,     Microsoft Azure SQL Database,     Machine Le ...
#   'pubDate': 'Mon, 13 May 2024 09:18:18 +0000',
#   'guid': 'https://www.upwork.com/jobs/Real-Estate-Listing-and-Transaction-Database-with-Predictive-Analytics_%7E01b4961d51a60e9f07?source=rss'},
#  {'title': 'Ad-hoc PowerBI Support - Upwork',
#   'link': 'https://www.upwork.com/jobs/hoc-PowerBI-Support_%7E015ce72d94b930088d?source=rss',
#   'description': 'Need ad-hoc PowerBI support to develop visual reports.&nbsp;&nbsp;Datasource is MS Dataverse.&nbsp;&nbsp;Requirements typically involve connecting relationships between multiple tables and understand 1:N, different types of joins, etc.<br /><br /><b>Hourly Range</b>: $20.00-$25.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:56 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI    \n<br /><b>Skills</b>:        Microsoft Power BI            <br /><b>Country</b>: Singapore\n<br /><a href="https://www.upwork.com/jobs/hoc-PowerBI-Support_%7E015ce72d94b930088d?source=rss">click to apply</a>',
#   'content:encoded': 'Need ad-hoc PowerBI support to develop visual reports.&nbsp;&nbsp;Datasource is MS Dataverse.&nbsp;&nbsp;Requirements typically involve connecting relationships between multiple tables and understand 1:N, different types of joins, etc.<br /><br /><b>Hourly Range</b>: $20.00-$25.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:56 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI    \n<br /><b>Skills</b>:        Microsoft Power BI            <br /><b>Country</b>: Singapore\n<br /><a href="https://www.upwork.com/jobs/hoc-PowerBI-Support_%7E015ce72d94b930088d?source=rss">click to apply</a>',
#   'pubDate': 'Mon, 13 May 2024 08:56:54 +0000',
#   'guid': 'https://www.upwork.com/jobs/hoc-PowerBI-Support_%7E015ce72d94b930088d?source=rss'},
#  {'title': 'Ema - Upwork',
#   'link': 'https://www.upwork.com/jobs/Ema_%7E018ea49528c5bb0933?source=rss',
#   'description': 'Please refer to enclosed PDF<br />\nDetails requirement is in PDF<br />\nPlease let me can you handle it?<br />\nIf yes, what is the cost and need how many days to deliver?<br /><br /><br /><b>Posted On</b>: May 13, 2024 08:42 UTC<br /><b>Category</b>: Scripting &amp; Automation<br /><b>Skills</b>:Microsoft Power BI,     Data Analysis Expressions,     Data Analysis,     Microsoft Power BI Data Visualization,     Laravel,     PHP,     HTML5,     MQL 4,     MetaTrader 4,     Forex Trading,     MQL 5,     MetaTrader 5,     Microsoft Power BI Development,     Search Engine Optimization,     Microsoft Visual C++    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Data Analysis Expressions,                     Data Analysis,                     Microsoft Power BI Data Visualization,                     Laravel,                     PHP,                     HTML5,                     MQL 4,                     MetaTrader 4,                     Forex Trading,                     MQL 5,                     MetaTrader 5,                     Microsoft Power BI Development,                     Search Engine Optimization,                     Microsoft Visual C++            <br /><b>Country</b>: Malaysia\n<br /><a href="https://www.upwork.com/jobs/Ema_%7E018ea49528c5bb0933?source=rss">click to apply</a>',
#   'content:encoded': 'Please refer to enclosed PDF<br />\nDetails requirement is in PDF<br />\nPlease let me can you handle it?<br />\nIf yes, what is the cost and need how many days to deliver?<br /><br /><br /><b>Posted On</b>: May 13, 2024 08:42 UTC<br /><b>Category</b>: Scripting &amp; Automation<br /><b>Skills</b>:Microsoft Power BI,     Data Analysis Expressions,     Data Analysis,     Microsoft Power BI Data Visualization,     Laravel,     PHP,     HTML5,     MQL 4,     MetaTrader 4,     Forex Trading,     MQL 5,     MetaTrader 5,     Microsoft Power BI Development,     Search Engine Optimization,     Microsoft Visual C++    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Data Analysis Expressions,                     Data Analysis,                     Microsoft Power BI Data Visualization,                     Laravel,                     PHP,                     HTML5,                     MQL 4,                     MetaTrader 4,                     Forex Trading,                     MQL 5,                     MetaTrader 5,                     Microsoft Power BI Development,                     Search Engine Optimization,                     Microsoft Visual C++            <br /><b>Country</b>: Malaysia\n<br /><a href="https://www.upwork.com/jobs/Ema_%7E018ea49528c5bb0933?source=rss">click to apply</a>',
#   'pubDate': 'Mon, 13 May 2024 08:42:05 +0000',
#   'guid': 'https://www.upwork.com/jobs/Ema_%7E018ea49528c5bb0933?source=rss'},
#  {'title': 'Customer Management Solution and PowerBI Reporting - Upwork',
#   'link': 'https://www.upwork.com/jobs/Customer-Management-Solution-and-PowerBI-Reporting_%7E014e5020598d3d582b?source=rss',
#   'description': 'We are seeking a skilled freelancer to develop a customer management solution and create PowerBI reports based on the datasets we provide on a weekly basis. The ideal candidate will have experience in both customer management systems and PowerBI reporting. This project requires the ability to integrate and manipulate data from Excel into a user-friendly customer management solution, as well as the creation of visually appealing PowerBI reports that provide valuable insights. <br /><br />\n&nbsp;&nbsp;Skills required:<br />\n&nbsp;&nbsp;- Customer management system development<br />\n&nbsp;&nbsp;- PowerBI reporting<br />\n&nbsp;&nbsp;- Data integration and manipulation<br />\n&nbsp;&nbsp;- Excel proficiency<br /><br />\n&nbsp;&nbsp;This is a medium-sized project expected to last between 1 to 3 months. We are looking for an intermediate-level freelancer who can confidently handle the requirements and deliver quality results within the given timeframe. <br /><br /><b>Hourly Range</b>: $5.00-$45.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:39 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     Business Intelligence,     Data Analysis,     Microsoft Excel    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Business Intelligence,                     Data Analysis,                     Microsoft Excel            <br /><b>Country</b>: Australia\n<br /><a href="https://www.upwork.com/jobs/Customer-Management-Solution-and-PowerBI-Reporting_%7E014e5020598d3d582b?source=rss">click to apply</a>',
#   'content:encoded': 'We are seeking a skilled freelancer to develop a customer management solution and create PowerBI reports based on the datasets we provide on a weekly basis. The ideal candidate will have experience in both customer management systems and PowerBI reporting. This project requires the ability to integrate and manipulate data from Excel into a user-friendly customer management solution, as well as the creation of visually appealing PowerBI reports that provide valuable insights. <br /><br />\n&nbsp;&nbsp;Skills required:<br />\n&nbsp;&nbsp;- Customer management system development<br />\n&nbsp;&nbsp;- PowerBI reporting<br />\n&nbsp;&nbsp;- Data integration and manipulation<br />\n&nbsp;&nbsp;- Excel proficiency<br /><br />\n&nbsp;&nbsp;This is a medium-sized project expected to last between 1 to 3 months. We are looking for an intermediate-level freelancer who can confidently handle the requirements and deliver quality results within the given timeframe. <br /><br /><b>Hourly Range</b>: $5.00-$45.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:39 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     Business Intelligence,     Data Analysis,     Microsoft Excel    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Business Intelligence,                     Data Analysis,                     Microsoft Excel            <br /><b>Country</b>: Australia\n<br /><a href="https://www.upwork.com/jobs/Customer-Management-Solution-and-PowerBI-Reporting_%7E014e5020598d3d582b?source=rss">click to apply</a>',
#   'pubDate': 'Mon, 13 May 2024 08:39:10 +0000',
#   'guid': 'https://www.upwork.com/jobs/Customer-Management-Solution-and-PowerBI-Reporting_%7E014e5020598d3d582b?source=rss'},
#  {'title': 'Trigger URL in PowerBi - Upwork',
#   'link': 'https://www.upwork.com/jobs/Trigger-URL-PowerBi_%7E0112add0c6294cb28a?source=rss',
#   'description': 'Hi,<br /><br />\nWe have a function stored on our Azure platform that is connected to a SQL Server table that holds a unique url that when entered into a browser changes another value on the same table to show that record has been seen and actioned by the user.<br /><br />\nWe need to be able to trigger this url in a PowerBi table so we can update the tracking value in our table.&nbsp;&nbsp;The issue is that by default PowerBi opens a browser window.&nbsp;&nbsp;<br /><br />\nWe need someone to help us overcome this so when the your is selected the value changes without opening a browser. We are happy to use Power Automate to achieve this, but need a detailed answer on what it requires us to do.<br /><br />\nWe can send over the PBIX file upon initial messaging.<br /><br />\nWe need someone immediately available and who has a feedback score of higher than 95%<br /><br />\nThanks<br /><br />\nJon&nbsp;&nbsp;<br /><br /><b>Hourly Range</b>: $20.00-$45.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:32 UTC<br /><b>Category</b>: Scripting &amp; Automation<br /><b>Skills</b>:API Integration,     Microsoft Power BI,     Power Query    \n<br /><b>Skills</b>:        API Integration,                     Microsoft Power BI,                     Power Query            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Trigger-URL-PowerBi_%7E0112add0c6294cb28a?source=rss">click to apply</a>',
#   'content:encoded': 'Hi,<br /><br />\nWe have a function stored on our Azure platform that is connected to a SQL Server table that holds a unique url that when entered into a browser changes another value on the same table to show that record has been seen and actioned by the user.<br /><br />\nWe need to be able to trigger this url in a PowerBi table so we can update the tracking value in our table.&nbsp;&nbsp;The issue is that by default PowerBi opens a browser window.&nbsp;&nbsp;<br /><br />\nWe need someone to help us overcome this so when the your is selected the value changes without opening a browser. We are happy to use Power Automate to achieve this, but need a detailed answer on what it requires us to do.<br /><br />\nWe can send over the PBIX file upon initial messaging.<br /><br />\nWe need someone immediately available and who has a feedback score of higher than 95%<br /><br />\nThanks<br /><br />\nJon&nbsp;&nbsp;<br /><br /><b>Hourly Range</b>: $20.00-$45.00\n\n<br /><b>Posted On</b>: May 13, 2024 08:32 UTC<br /><b>Category</b>: Scripting &amp; Automation<br /><b>Skills</b>:API Integration,     Microsoft Power BI,     Power Query    \n<br /><b>Skills</b>:        API Integration,                     Microsoft Power BI,                     Power Query            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Trigger-URL-PowerBi_%7E0112add0c6294cb28a?source=rss">click to apply</a>',
#   'pubDate': 'Mon, 13 May 2024 08:32:14 +0000',
#   'guid': 'https://www.upwork.com/jobs/Trigger-URL-PowerBi_%7E0112add0c6294cb28a?source=rss'},
#  {'title': 'Automate salary/wages and costing sheets - Upwork',
#   'link': 'https://www.upwork.com/jobs/Automate-salary-wages-and-costing-sheets_%7E01261e12a504f06051?source=rss',
#   'description': 'We need to automate salary/wages and costing sheets in Excel by our desire. Could you accomplish it<br /><br /><br /><br /><b>Posted On</b>: May 13, 2024 07:47 UTC<br /><b>Category</b>: Machine Learning<br /><b>Skills</b>:Data Science,     Computer Vision,     Microsoft Excel,     Python,     SciPy,     Data Visualization,     Microsoft Power BI,     SQL,     Machine Learning,     Deep Learning,     Neural Network,     Data Extraction,     Cloud Architecture,     Data Analysis,     API    \n<br /><b>Skills</b>:        Data Science,                     Computer Vision,                     Microsoft Excel,                     Python,                     SciPy,                     Data Visualization,                     Microsoft Power BI,                     SQL,                     Machine Learning,                     Deep Learning,                     Neural Network,                     Data Extraction,                     Cloud Architecture,                     Data Analysis,                     API            <br /><b>Country</b>: India\n<br /><a href="https://www.upwork.com/jobs/Automate-salary-wages-and-costing-sheets_%7E01261e12a504f06051?source=rss">click to apply</a>',
#   'content:encoded': 'We need to automate salary/wages and costing sheets in Excel by our desire. Could you accomplish it<br /><br /><br /><br /><b>Posted On</b>: May 13, 2024 07:47 UTC<br /><b>Category</b>: Machine Learning<br /><b>Skills</b>:Data Science,     Computer Vision,     Microsoft Excel,     Python,     SciPy,     Data Visualization,     Microsoft Power BI,     SQL,     Machine Learning,     Deep Learning,     Neural Network,     Data Extraction,     Cloud Architecture,     Data Analysis,     API    \n<br /><b>Skills</b>:        Data Science,                     Computer Vision,                     Microsoft Excel,                     Python,                     SciPy,                     Data Visualization,                     Microsoft Power BI,                     SQL,                     Machine Learning,                     Deep Learning,                     Neural Network,                     Data Extraction,                     Cloud Architecture,                     Data Analysis,                     API            <br /><b>Country</b>: India\n<br /><a href="https://www.upwork.com/jobs/Automate-salary-wages-and-costing-sheets_%7E01261e12a504f06051?source=rss">click to apply</a>',
#   'pubDate': 'Mon, 13 May 2024 07:47:37 +0000',
#   'guid': 'https://www.upwork.com/jobs/Automate-salary-wages-and-costing-sheets_%7E01261e12a504f06051?source=rss'},
#  {'title': 'PowerBI Developer for Dashboards - Upwork',
#   'link': 'https://www.upwork.com/jobs/PowerBI-Developer-for-Dashboards_%7E01db52a9ad0587d3ad?source=rss',
#   'description': 'We are seeking a skilled PowerBI developer to create interactive dashboards for our organization. The ideal candidate will have a strong background in data visualization and be proficient in using PowerBI to provide meaningful insights. As a PowerBI developer, you will collaborate with our team to understand our data requirements and design visually appealing dashboards that effectively communicate key metrics and trends. This role requires excellent problem-solving skills and the ability to work independently. <br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;Responsibilities:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Develop interactive dashboards using PowerBI<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Analyze and visualize data to identify trends and patterns<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Collaborate with stakeholders to understand data requirements<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Optimize dashboards for performance and user experience<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Troubleshoot and resolve issues with existing dashboards<br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;Required Skills:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Minimum 3-4 years of experience in PowerBi Dashboard development<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Proficiency in PowerBI and related tools<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Strong data visualization skills<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Experience in designing and developing interactive dashboards<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Knowledge of data modeling and database concepts<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Excellent problem-solving and analytical abilities<br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;We are looking for a medium-sized team to work on this project, with a duration of 15 - 30 days. The ideal candidate should have an advanced level of expertise in PowerBI development.<br /><br /><br /><b>Posted On</b>: May 13, 2024 07:45 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     Data Visualization,     Data Analysis,     Business Intelligence    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Data Visualization,                     Data Analysis,                     Business Intelligence            <br /><b>Country</b>: India\n<br /><a href="https://www.upwork.com/jobs/PowerBI-Developer-for-Dashboards_%7E01db52a9ad0587d3ad?source=rss">click to apply</a>',
#   'content:encoded': 'We are seeking a skilled PowerBI developer to create interactive dashboards for our organization. The ideal candidate will have a strong background in data visualization and be proficient in using PowerBI to provide meaningful insights. As a PowerBI developer, you will collaborate with our team to understand our data requirements and design visually appealing dashboards that effectively communicate key metrics and trends. This role requires excellent problem-solving skills and the ability to work independently. <br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;Responsibilities:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Develop interactive dashboards using PowerBI<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Analyze and visualize data to identify trends and patterns<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Collaborate with stakeholders to understand data requirements<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Optimize dashboards for performance and user experience<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Troubleshoot and resolve issues with existing dashboards<br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;Required Skills:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Minimum 3-4 years of experience in PowerBi Dashboard development<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Proficiency in PowerBI and related tools<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Strong data visualization skills<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Experience in designing and developing interactive dashboards<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Knowledge of data modeling and database concepts<br />\n&nbsp;&nbsp;&nbsp;&nbsp;- Excellent problem-solving and analytical abilities<br /><br />\n&nbsp;&nbsp;&nbsp;&nbsp;We are looking for a medium-sized team to work on this project, with a duration of 15 - 30 days. The ideal candidate should have an advanced level of expertise in PowerBI development.<br /><br /><br /><b>Posted On</b>: May 13, 2024 07:45 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     Data Visualization,     Data Analysis,     Business Intelligence    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Data Visualization,                     Data Analysis,                     Business Intelligence            <br /><b>Country</b>: India\n<br /><a href="https://www.upwork.com/jobs/PowerBI-Developer-for-Dashboards_%7E01db52a9ad0587d3ad?source=rss">click to apply</a>',
#   'pubDate': 'Mon, 13 May 2024 07:45:42 +0000',
#   'guid': 'https://www.upwork.com/jobs/PowerBI-Developer-for-Dashboards_%7E01db52a9ad0587d3ad?source=rss'},
#  {'title': 'Power BI Developer - Upwork',
#   'link': 'https://www.upwork.com/jobs/Power-Developer_%7E01ca09bd805598add1?source=rss',
#   'description': 'We are seeking an experienced Power BI Developer to join our team. As a Power BI Developer, you will be responsible for designing, developing, and implementing Power BI solutions. You will work closely with stakeholders to gather requirements, analyze data, and create visualizations and reports. The ideal candidate should have a strong background in data analysis and visualization, with proficiency in Power BI and SQL. Excellent problem-solving and communication skills are essential. <br /><br />\nCustom Financial &amp;amp; KPI reports for 2 organisations. Mainly information from Xero but there will be additional data sources to track KPIs from Google My Business, Streak. I have an idea on the reports required but need to outsource the expertise in getting these developed.<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br /><br />\nResponsibilities:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Design, develop, and maintain Power BI dashboards and reports<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Collaborate with stakeholders to gather requirements and identify data sources<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Analyze complex datasets to create meaningful visualizations and insights<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Optimize Power BI solutions for performance and usability<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Troubleshoot and resolve issues with existing Power BI models and reports<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br /><br />\nRequirements:<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Proven experience as a Power BI Developer or similar role<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Proficiency in Power BI, SQL, and data modeling<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Strong analytical and problem-solving skills<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Excellent communication and collaboration abilities<br />\n&nbsp;&nbsp;&nbsp;&nbsp;<br />\n- Attention to detail and ability to meet deadlines<br /><br /><br /><b>Posted On</b>: May 13, 2024 05:53 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     Data Visualization,     Data Analysis,     Business Intelligence    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Data Visualization,                     Data Analysis,                     Business Intelligence            <br /><b>Country</b>: Australia\n<br /><a href="https://www.upwork.com/jobs/Power-Developer_%7E01ca09bd805598add1?source=rss">click to apply</a>',
# ...
#   'content:encoded': 'Looking for a Power BI and SAP SAC expert to support pre-sales activities on a remote, as-needed basis. The role involves preparing presentations, system demos, and providing expert insights to prospective customers.<br /><br />\nResponsibilities:<br />\n- Create and present PowerPoint presentations.<br />\n- Conduct system and capability demos.<br />\n- Serve as a subject matter expert during customer interactions.<br /><br />\nRequirements:<br />\n- Proven experience with Power BI and SAP SAC.<br />\n- Strong presentation and demonstration skills.<br />\n- Excellent communication abilities.<br /><br />\nJob Type: Remote, freelance<br /><br /><b>Hourly Range</b>: $5.00-$20.00\n\n<br /><b>Posted On</b>: May 12, 2024 15:55 UTC<br /><b>Category</b>: Data Visualization<br /><b>Skills</b>:Microsoft Power BI,     SAP,     Data Visualization,     Business Intelligence,     Data Modeling,     Data Analysis,     Microsoft Excel,     ETL    \n<br /><b>Skills</b>:        Microsoft Power BI,                     SAP,                     Data Visualization,                     Business Intelligence,                     Data Modeling,                     Data Analysis,                     Microsoft Excel,                     ETL            <br /><b>Country</b>: United Arab Emirates\n<br /><a href="https://www.upwork.com/jobs/Remote-Power-amp-SAP-SAC-Expert_%7E0154f93ba5573aeaaa?source=rss">click to apply</a>',
#   'pubDate': 'Sun, 12 May 2024 15:55:05 +0000',
#   'guid': 'https://www.upwork.com/jobs/Remote-Power-amp-SAP-SAC-Expert_%7E0154f93ba5573aeaaa?source=rss'},
#  {'title': 'Data Analyst/English Business - Upwork',
#   'link': 'https://www.upwork.com/jobs/Data-Analyst-English-Business_%7E01e739a8f4ebd29158?source=rss',
#   'description': 'We are seeking a skilled Data Analyst with a strong command of English for our business. As a Data Analyst, you will be responsible for collecting, analyzing, and interpreting complex data sets to provide valuable insights and recommendations. The ideal candidate should have a solid understanding of statistical methodologies, data visualization, and data mining techniques. <br /><br />\n&nbsp;&nbsp;&nbsp;Responsibilities:<br />\n&nbsp;&nbsp;&nbsp;- Collect and clean data from various sources<br />\n&nbsp;&nbsp;&nbsp;- Perform statistical analysis and generate reports<br />\n&nbsp;&nbsp;&nbsp;- Develop and maintain databases<br />\n&nbsp;&nbsp;&nbsp;- Create data visualizations and dashboards<br />\n&nbsp;&nbsp;&nbsp;- Identify trends and patterns in data<br /><br />\n&nbsp;&nbsp;&nbsp;Requirements:<br />\n&nbsp;&nbsp;&nbsp;- Proven experience as a Data Analyst or in a similar role<br />\n&nbsp;&nbsp;&nbsp;- Strong analytical skills and attention to detail<br />\n&nbsp;&nbsp;&nbsp;- Proficient in SQL and data visualization tools (e.g., Tableau, Power BI)<br />\n&nbsp;&nbsp;&nbsp;- Excellent English communication skills<br /><br />\n&nbsp;&nbsp;&nbsp;This is a medium-sized project with a duration of 1 to 3 months. We are looking for an intermediate-level Data Analyst who can work independently and deliver high-quality results. If you are passionate about data analysis and have a strong business acumen, we would love to hear from you!<br /><br /><b>Hourly Range</b>: $17.00-$50.00\n\n<br /><b>Posted On</b>: May 12, 2024 12:41 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:Microsoft Excel,     English,     Data Entry    \n<br /><b>Skills</b>:        Microsoft Excel,                     English,                     Data Entry            <br /><b>Country</b>: France\n<br /><a href="https://www.upwork.com/jobs/Data-Analyst-English-Business_%7E01e739a8f4ebd29158?source=rss">click to apply</a>',
#   'content:encoded': 'We are seeking a skilled Data Analyst with a strong command of English for our business. As a Data Analyst, you will be responsible for collecting, analyzing, and interpreting complex data sets to provide valuable insights and recommendations. The ideal candidate should have a solid understanding of statistical methodologies, data visualization, and data mining techniques. <br /><br />\n&nbsp;&nbsp;&nbsp;Responsibilities:<br />\n&nbsp;&nbsp;&nbsp;- Collect and clean data from various sources<br />\n&nbsp;&nbsp;&nbsp;- Perform statistical analysis and generate reports<br />\n&nbsp;&nbsp;&nbsp;- Develop and maintain databases<br />\n&nbsp;&nbsp;&nbsp;- Create data visualizations and dashboards<br />\n&nbsp;&nbsp;&nbsp;- Identify trends and patterns in data<br /><br />\n&nbsp;&nbsp;&nbsp;Requirements:<br />\n&nbsp;&nbsp;&nbsp;- Proven experience as a Data Analyst or in a similar role<br />\n&nbsp;&nbsp;&nbsp;- Strong analytical skills and attention to detail<br />\n&nbsp;&nbsp;&nbsp;- Proficient in SQL and data visualization tools (e.g., Tableau, Power BI)<br />\n&nbsp;&nbsp;&nbsp;- Excellent English communication skills<br /><br />\n&nbsp;&nbsp;&nbsp;This is a medium-sized project with a duration of 1 to 3 months. We are looking for an intermediate-level Data Analyst who can work independently and deliver high-quality results. If you are passionate about data analysis and have a strong business acumen, we would love to hear from you!<br /><br /><b>Hourly Range</b>: $17.00-$50.00\n\n<br /><b>Posted On</b>: May 12, 2024 12:41 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:Microsoft Excel,     English,     Data Entry    \n<br /><b>Skills</b>:        Microsoft Excel,                     English,                     Data Entry            <br /><b>Country</b>: France\n<br /><a href="https://www.upwork.com/jobs/Data-Analyst-English-Business_%7E01e739a8f4ebd29158?source=rss">click to apply</a>',
#   'pubDate': 'Sun, 12 May 2024 12:41:52 +0000',
#   'guid': 'https://www.upwork.com/jobs/Data-Analyst-English-Business_%7E01e739a8f4ebd29158?source=rss'},
#  {'title': 'Seeking freelance sports statistician, ideally with knowledge of NFL/MLB  - Upwork',
#   'link': 'https://www.upwork.com/jobs/Seeking-freelance-sports-statistician-ideally-with-knowledge-NFL-MLB_%7E01e15b42ace6635baa?source=rss',
#   'description': 'We are seeking someone who would be able to generate some statistics for us. We are looking for a sports statistician that we could hire for this this, ideally with knowledge of the NFL, although we could also do baseball/MLB too. We need someone to crunch the data and identify and rank the teams in different sports that &ldquo;peak too soon&rdquo; &ndash; and also maybe the ones that &ldquo;stay strong&rdquo; and/or &ldquo;finish strong&rdquo;. We could define &ldquo;peaking too soon&rdquo; to mean either consistently peaking too early in the game or peaking too soon in a season &ndash; or some combination of both. <br /><br />\nLet me know if this is something you could help us with! <br /><br /><br /><b>Posted On</b>: May 12, 2024 11:13 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:Data Science,     Visualization,     Microsoft Power BI Data Visualization,     Data Analytics,     Analytics,     Analytical Presentation,     Data Analysis,     R,     Microsoft Excel,     Microsoft Power BI,     Microsoft PowerPoint,     Python    \n<br /><b>Skills</b>:        Data Science,                     Visualization,                     Microsoft Power BI Data Visualization,                     Data Analytics,                     Analytics,                     Analytical Presentation,                     Data Analysis,                     R,                     Microsoft Excel,                     Microsoft Power BI,                     Microsoft PowerPoint,                     Python            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Seeking-freelance-sports-statistician-ideally-with-knowledge-NFL-MLB_%7E01e15b42ace6635baa?source=rss">click to apply</a>',
#   'content:encoded': 'We are seeking someone who would be able to generate some statistics for us. We are looking for a sports statistician that we could hire for this this, ideally with knowledge of the NFL, although we could also do baseball/MLB too. We need someone to crunch the data and identify and rank the teams in different sports that &ldquo;peak too soon&rdquo; &ndash; and also maybe the ones that &ldquo;stay strong&rdquo; and/or &ldquo;finish strong&rdquo;. We could define &ldquo;peaking too soon&rdquo; to mean either consistently peaking too early in the game or peaking too soon in a season &ndash; or some combination of both. <br /><br />\nLet me know if this is something you could help us with! <br /><br /><br /><b>Posted On</b>: May 12, 2024 11:13 UTC<br /><b>Category</b>: Data Analytics<br /><b>Skills</b>:Data Science,     Visualization,     Microsoft Power BI Data Visualization,     Data Analytics,     Analytics,     Analytical Presentation,     Data Analysis,     R,     Microsoft Excel,     Microsoft Power BI,     Microsoft PowerPoint,     Python    \n<br /><b>Skills</b>:        Data Science,                     Visualization,                     Microsoft Power BI Data Visualization,                     Data Analytics,                     Analytics,                     Analytical Presentation,                     Data Analysis,                     R,                     Microsoft Excel,                     Microsoft Power BI,                     Microsoft PowerPoint,                     Python            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Seeking-freelance-sports-statistician-ideally-with-knowledge-NFL-MLB_%7E01e15b42ace6635baa?source=rss">click to apply</a>',
#   'pubDate': 'Sun, 12 May 2024 11:13:35 +0000',
#   'guid': 'https://www.upwork.com/jobs/Seeking-freelance-sports-statistician-ideally-with-knowledge-NFL-MLB_%7E01e15b42ace6635baa?source=rss'},
#  {'title': 'Power BI Expert Needed for Data Scraping - Upwork',
#   'link': 'https://www.upwork.com/jobs/Power-Expert-Needed-for-Data-Scraping_%7E01e0a2091f6c4ac120?source=rss',
#   'description': 'Extract Specific contact information (name, address, phone number &amp;amp; email address) from a power BI website. Create a Dynamic Excel Spreadsheet that can be refreshed when needed.&nbsp;&nbsp;<br />\nI created a ppt that explains in more detail the objective and were to get the infomation. <br />\nFor someone profecient with Power BI, it should be easy to &amp;quot;Get Data&amp;quot; then clean up the spreadsheet to meet minimum requirements. <br /><br /><br /><br /><b>Budget</b>: $50\n<br /><b>Posted On</b>: May 12, 2024 09:16 UTC<br /><b>Category</b>: Data Extraction<br /><b>Skills</b>:Microsoft Power BI,     Microsoft Excel,     Data Scraping,     Data Mining    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Microsoft Excel,                     Data Scraping,                     Data Mining            <br /><b>Country</b>: United States\n<br /><a href="https://www.upwork.com/jobs/Power-Expert-Needed-for-Data-Scraping_%7E01e0a2091f6c4ac120?source=rss">click to apply</a>',
#   'content:encoded': 'Extract Specific contact information (name, address, phone number &amp;amp; email address) from a power BI website. Create a Dynamic Excel Spreadsheet that can be refreshed when needed.&nbsp;&nbsp;<br />\nI created a ppt that explains in more detail the objective and were to get the infomation. <br />\nFor someone profecient with Power BI, it should be easy to &amp;quot;Get Data&amp;quot; then clean up the spreadsheet to meet minimum requirements. <br /><br /><br /><br /><b>Budget</b>: $50\n<br /><b>Posted On</b>: May 12, 2024 09:16 UTC<br /><b>Category</b>: Data Extraction<br /><b>Skills</b>:Microsoft Power BI,     Microsoft Excel,     Data Scraping,     Data Mining    \n<br /><b>Skills</b>:        Microsoft Power BI,                     Microsoft Excel,                     Data Scraping,                     Data Mining            <br /><b>Country</b>: United States\n<br /><a href="https://www.upwork.com/jobs/Power-Expert-Needed-for-Data-Scraping_%7E01e0a2091f6c4ac120?source=rss">click to apply</a>',
#   'pubDate': 'Sun, 12 May 2024 09:16:33 +0000',
#   'guid': 'https://www.upwork.com/jobs/Power-Expert-Needed-for-Data-Scraping_%7E01e0a2091f6c4ac120?source=rss'},
#  {'title': 'Build a recruitment excel tracker and KPI analytics  - Upwork',
#   'link': 'https://www.upwork.com/jobs/Build-recruitment-excel-tracker-and-KPI-analytics_%7E01ec3a2a8d0d7cb198?source=rss',
#   'description': 'Hi, I work as a recruiter for a tech company and looking for someone to help me build a good excel tracker with analytics I can use to track recruitment activity at the company. <br /><br />\nI have already created a draft version on excel to give you an idea of the information I need captured. I need someone to take the draft and create a better version that is easily customisable, where all the data flows through seamlessly across each tabs with a main dashboard that summarises the key recruitment KPI&#039;s.<br /><br />\nThe purpose of the tracker is capture information such as the below (these are some of them)<br /><br />\n- Total open vacancies <br />\n- Total offers made in March 2024 <br />\n- Total offers made in Q1 2024<br />\n- Offer acceptance %<br />\n- Time to hire %<br />\n- Average source of hire (did hires come through Linkedin, careers page, job advert etc)<br />\n- Total hires made in each global office by month, by quarter, by year<br /><br /><br /><b>Posted On</b>: May 12, 2024 09:16 UTC<br /><b>Category</b>: Recruiting &amp; Talent Sourcing<br /><b>Skills</b>:Microsoft Excel,     Data Visualization,     Analytics,     Microsoft Power BI,     Tableau    \n<br /><b>Skills</b>:        Microsoft Excel,                     Data Visualization,                     Analytics,                     Microsoft Power BI,                     Tableau            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Build-recruitment-excel-tracker-and-KPI-analytics_%7E01ec3a2a8d0d7cb198?source=rss">click to apply</a>',
#   'content:encoded': 'Hi, I work as a recruiter for a tech company and looking for someone to help me build a good excel tracker with analytics I can use to track recruitment activity at the company. <br /><br />\nI have already created a draft version on excel to give you an idea of the information I need captured. I need someone to take the draft and create a better version that is easily customisable, where all the data flows through seamlessly across each tabs with a main dashboard that summarises the key recruitment KPI&#039;s.<br /><br />\nThe purpose of the tracker is capture information such as the below (these are some of them)<br /><br />\n- Total open vacancies <br />\n- Total offers made in March 2024 <br />\n- Total offers made in Q1 2024<br />\n- Offer acceptance %<br />\n- Time to hire %<br />\n- Average source of hire (did hires come through Linkedin, careers page, job advert etc)<br />\n- Total hires made in each global office by month, by quarter, by year<br /><br /><br /><b>Posted On</b>: May 12, 2024 09:16 UTC<br /><b>Category</b>: Recruiting &amp; Talent Sourcing<br /><b>Skills</b>:Microsoft Excel,     Data Visualization,     Analytics,     Microsoft Power BI,     Tableau    \n<br /><b>Skills</b>:        Microsoft Excel,                     Data Visualization,                     Analytics,                     Microsoft Power BI,                     Tableau            <br /><b>Country</b>: United Kingdom\n<br /><a href="https://www.upwork.com/jobs/Build-recruitment-excel-tracker-and-KPI-analytics_%7E01ec3a2a8d0d7cb198?source=rss">click to apply</a>',
#   'pubDate': 'Sun, 12 May 2024 09:16:23 +0000',
#   'guid': 'https://www.upwork.com/jobs/Build-recruitment-excel-tracker-and-KPI-analytics_%7E01ec3a2a8d0d7cb198?source=rss'}]

# %%
#Lets clean all the descriptions
jobs_cleaned = []

for i in range(0,jobs_lenght):
    description = output_test[i]['description']
    job_cleaned = cleanhtml(description)
    jobs_cleaned.append(job_cleaned)

jobs_cleaned
# Out:
# ['Hi I am looking for a professional dashboard built in MicroStrategy, using advanced visualizations and automation. The dataset is small(about 107 rows)and straight forward. Also please indicate how long will it take for you to do the job?ThanksCharuPosted On: May 13, 2024 09:46 UTCCategory: Data VisualizationSkills:Microsoft Power BI Data Visualization, Microsoft Power BI, Dashboard, Business Intelligence, SQL, Microsoft Power BI Development, Database, Microsoft Excel, Data Mining, BigQuery, Data Visualization, Analytics Dashboard, Data Modeling, Data Analytics Skills: Microsoft Power BI Data Visualization, Microsoft Power BI, Dashboard, Business Intelligence, SQL, Microsoft Power BI Development, Database, Microsoft Excel, Data Mining, BigQuery, Data Visualization, Analytics Dashboard, Data Modeling, Data Analytics Country: United Kingdomclick to apply',
#  'We are seeking a Power BI Developer to assist with our data visualization and reporting needs. The ideal candidate will have experience in creating interactive dashboards and reports using Power BI tools. Key responsibilities include: - Creating visually appealing and informative dashboards.- Building data models and establishing connections to various data sources.- Generating reports and insights that meet business requirements. Qualifications:- Proficiency in Power BI Desktop, Power Query, DAX, and M languages- Familiarity with SQL, data warehousing concepts, and ETL processes is a plus.- Experience in data visualization principles and best practices.Hourly Range: $25.00-$60.00Posted On: May 13, 2024 09:44 UTCCategory: Data VisualizationSkills:Data Analysis Expressions, Microsoft Power BI, Data Visualization, Business Intelligence, Microsoft Power BI Development, Power Query, Microsoft SharePoint Skills: Data Analysis Expressions, Microsoft Power BI, Data Visualization, Business Intelligence, Microsoft Power BI Development, Power Query, Microsoft SharePoint Country: Philippinesclick to apply',
#  'We are seeking a skilled sports analytics expert to analyze a comprehensive dataset of cricket player statistics. The goal is to derive actionable insights and identify the impact of various factors on the game, enabling data-driven decision-making to enhance team performance.Responsibilities:Conduct detailed analysis of key performance indicators (KPIs) such as batting average, strike rate, bowling economy, and fielding effectiveness.Identify performance trends and patterns over time, including player career progression and consistency.Perform comparative analysis of player performance against different teams, in various formats (Test, ODI, T20), and under different conditions (home/away, pitch types, weather).Analyze player strengths and weaknesses, including performance against specific opponents and in high-pressure situations.Assess match-winning performances and overall contribution to team success.Use advanced analytical techniques such as cluster analysis, predictive modeling to uncover deeper insights.Create interactive dashboards and visualizations to present findings in an engaging and accessible manner.Deliverables:Comprehensive report detailing the analysis findings, including statistical summaries, visualizations, and key insights with codes.Interactive dashboards using tools like Tableau or Power BI for dynamic data exploration.Recommendations for optimizing player roles and strategies based on the analysis.Identification of potential areas for performance improvement and strategic adjustments.Qualifications:Proven experience in sports analytics, particularly with cricket datasets.Strong understanding of cricket, including rules, player roles, and game dynamics.Proficiency in data analysis tools and programming languages such as R, Python, or SQL.Experience with data visualization tools like Tableau, Power BI, or similar platforms.Ability to communicate complex analytical findings in a clear and concise manner.Passion for sports analytics and a keen eye for detail.Hourly Range: $5.00-$40.00Posted On: May 13, 2024 08:46 UTCCategory: Data AnalyticsSkills:R, Data Visualization, Microsoft Excel, Google Analytics, Search Engine Optimization, Data Analysis, Machine Learning, Analytics Skills: R, Data Visualization, Microsoft Excel, Google Analytics, Search Engine Optimization, Data Analysis, Machine Learning, Analytics Country: United Kingdomclick to apply',
#  'write a scope of work that is focused on data consumer behavior and other important key metrics that will enable the dealership to sell smarter to its customers. Skills required are pyhthon, sql and powerbiDeliverables: Defined and prioritized KPIs for sales and marketing Customer segmentation insights and reports Recommendations for targeted marketing campaigns across various channels Data-driven strategies for optimizing the sales process Ongoing reporting dashboards Final report with actionable recommendationscommunication will be via email and Microsoft teamsBudget: $500Posted On: May 13, 2024 09:27 UTCCategory: Data AnalyticsSkills:SQL, Microsoft Power BI, Business Intelligence, Python Skills: SQL, Microsoft Power BI, Business Intelligence, Python Country: South Africaclick to apply',
#  'We are seeking a skilled data engineer and data scientist to create a comprehensive real estate database that tracks listings and transactions on a weekly basis. The goal of this project is to develop a tool that can predict real estate price movements and identify underpriced properties using Microsoft Azure Machine Learning.Responsibilities:1. Design and create an SQL database to store real estate listings and transactions.2. Develop scripts to collect real estate data from various sources and update the database weekly.3. Implement data cleaning and deduplication processes to ensure data integrity and accuracy.4. Track changes in listings on a weekly basis and store historical data for analysis.5. Connect the database to Power BI to create interactive dashboards and visualizations for data analysis.6. Utilize Microsoft Azure Machine Learning to develop models for predicting real estate price movements and identifying underpriced properties.7. Provide functionality to export data from the SQL database to Excel for further analysis.8. Provide documentation and support for the database, analytics tools, and machine learning models.Requirements:1. Experience with SQL database design and management.2. Proficiency in data collection and web scraping using Python or other relevant tools.3. Knowledge of data cleaning, deduplication, and data transformation techniques.4. Familiarity with Power BI or similar data visualization tools.5. Experience with Microsoft Azure Machine Learning or similar cloud-based machine learning platforms.6. Strong problem-solving and analytical skills.7. Good communication skills and ability to work independently.Deliverables:1. A functional SQL database populated with real estate listings and transactions.2. Scripts to collect and update data weekly.3. Data cleaning and deduplication processes implemented within the database.4. Power BI dashboards and reports for data visualization and analysis.5. Machine learning models developed using Azure Machine Learning for predicting real estate price movements and identifying underpriced properties.6. Functionality to export data from the SQL database to Excel.Documentation for the database, data collection scripts, analytics components, and machine learning models.Timeline:The project is expected to take approximately 4-6 weeks to complete, with regular progress updates throughout the duration of the project.Budget:The budget for this project is set at $1,500, which includes the development of the database, data collection scripts, data cleaning processes, Power BI integration, and machine learning models using Microsoft Azure Machine Learning.If you have the required skills and experience and can work within the specified budget and timeline, please submit your proposal, including a project plan and timeline. We look forward to working with a talented data engineer and data scientist to bring this project to life.Please note that the ability to export data from the SQL database to Excel is considered part of the core functionality and does not need to be separately mentioned in the job description. It is assumed that the data engineer will provide this capability as part of the database development process.Budget: $1,500Posted On: May 13, 2024 09:18 UTCCategory: Data AnalyticsSkills:SQL, Microsoft Power BI, Data Entry, Data Analysis, Data Scraping, Data Mining, Python, Microsoft Excel, Microsoft Azure SQL Database, Machine Learning Algorithm Skills: SQL, Microsoft Power BI, Data Entry, Data Analysis, Data Scraping, Data Mining, Python, Microsoft Excel, Microsoft Azure SQL Database, Machine Learning Algorithm Country: United Arab Emiratesclick to apply',
#  'Need ad-hoc PowerBI support to develop visual reports.Datasource is MS Dataverse.Requirements typically involve connecting relationships between multiple tables and understand 1:N, different types of joins, etc.Hourly Range: $20.00-$25.00Posted On: May 13, 2024 08:56 UTCCategory: Data VisualizationSkills:Microsoft Power BI Skills: Microsoft Power BI Country: Singaporeclick to apply',
#  'Please refer to enclosed PDFDetails requirement is in PDFPlease let me can you handle it?If yes, what is the cost and need how many days to deliver?Posted On: May 13, 2024 08:42 UTCCategory: Scripting AutomationSkills:Microsoft Power BI, Data Analysis Expressions, Data Analysis, Microsoft Power BI Data Visualization, Laravel, PHP, HTML5, MQL 4, MetaTrader 4, Forex Trading, MQL 5, MetaTrader 5, Microsoft Power BI Development, Search Engine Optimization, Microsoft Visual C++ Skills: Microsoft Power BI, Data Analysis Expressions, Data Analysis, Microsoft Power BI Data Visualization, Laravel, PHP, HTML5, MQL 4, MetaTrader 4, Forex Trading, MQL 5, MetaTrader 5, Microsoft Power BI Development, Search Engine Optimization, Microsoft Visual C++ Country: Malaysiaclick to apply',
#  'We are seeking a skilled freelancer to develop a customer management solution and create PowerBI reports based on the datasets we provide on a weekly basis. The ideal candidate will have experience in both customer management systems and PowerBI reporting. This project requires the ability to integrate and manipulate data from Excel into a user-friendly customer management solution, as well as the creation of visually appealing PowerBI reports that provide valuable insights. Skills required:- Customer management system development- PowerBI reporting- Data integration and manipulation- Excel proficiencyThis is a medium-sized project expected to last between 1 to 3 months. We are looking for an intermediate-level freelancer who can confidently handle the requirements and deliver quality results within the given timeframe. Hourly Range: $5.00-$45.00Posted On: May 13, 2024 08:39 UTCCategory: Data VisualizationSkills:Microsoft Power BI, Business Intelligence, Data Analysis, Microsoft Excel Skills: Microsoft Power BI, Business Intelligence, Data Analysis, Microsoft Excel Country: Australiaclick to apply',
#  'Hi,We have a function stored on our Azure platform that is connected to a SQL Server table that holds a unique url that when entered into a browser changes another value on the same table to show that record has been seen and actioned by the user.We need to be able to trigger this url in a PowerBi table so we can update the tracking value in our table.The issue is that by default PowerBi opens a browser window.We need someone to help us overcome this so when the your is selected the value changes without opening a browser. We are happy to use Power Automate to achieve this, but need a detailed answer on what it requires us to do.We can send over the PBIX file upon initial messaging.We need someone immediately available and who has a feedback score of higher than 95%ThanksJonHourly Range: $20.00-$45.00Posted On: May 13, 2024 08:32 UTCCategory: Scripting AutomationSkills:API Integration, Microsoft Power BI, Power Query Skills: API Integration, Microsoft Power BI, Power Query Country: United Kingdomclick to apply',
#  'We need to automate salary/wages and costing sheets in Excel by our desire. Could you accomplish itPosted On: May 13, 2024 07:47 UTCCategory: Machine LearningSkills:Data Science, Computer Vision, Microsoft Excel, Python, SciPy, Data Visualization, Microsoft Power BI, SQL, Machine Learning, Deep Learning, Neural Network, Data Extraction, Cloud Architecture, Data Analysis, API Skills: Data Science, Computer Vision, Microsoft Excel, Python, SciPy, Data Visualization, Microsoft Power BI, SQL, Machine Learning, Deep Learning, Neural Network, Data Extraction, Cloud Architecture, Data Analysis, API Country: Indiaclick to apply',
#  'We are seeking a skilled PowerBI developer to create interactive dashboards for our organization. The ideal candidate will have a strong background in data visualization and be proficient in using PowerBI to provide meaningful insights. As a PowerBI developer, you will collaborate with our team to understand our data requirements and design visually appealing dashboards that effectively communicate key metrics and trends. This role requires excellent problem-solving skills and the ability to work independently. Responsibilities:- Develop interactive dashboards using PowerBI- Analyze and visualize data to identify trends and patterns- Collaborate with stakeholders to understand data requirements- Optimize dashboards for performance and user experience- Troubleshoot and resolve issues with existing dashboardsRequired Skills:- Minimum 3-4 years of experience in PowerBi Dashboard development- Proficiency in PowerBI and related tools- Strong data visualization skills- Experience in designing and developing interactive dashboards- Knowledge of data modeling and database concepts- Excellent problem-solving and analytical abilitiesWe are looking for a medium-sized team to work on this project, with a duration of 15 - 30 days. The ideal candidate should have an advanced level of expertise in PowerBI development.Posted On: May 13, 2024 07:45 UTCCategory: Data VisualizationSkills:Microsoft Power BI, Data Visualization, Data Analysis, Business Intelligence Skills: Microsoft Power BI, Data Visualization, Data Analysis, Business Intelligence Country: Indiaclick to apply',
#  'We are seeking an experienced Power BI Developer to join our team. As a Power BI Developer, you will be responsible for designing, developing, and implementing Power BI solutions. You will work closely with stakeholders to gather requirements, analyze data, and create visualizations and reports. The ideal candidate should have a strong background in data analysis and visualization, with proficiency in Power BI and SQL. Excellent problem-solving and communication skills are essential. Custom Financial amp; KPI reports for 2 organisations. Mainly information from Xero but there will be additional data sources to track KPIs from Google My Business, Streak. I have an idea on the reports required but need to outsource the expertise in getting these developed.Responsibilities:- Design, develop, and maintain Power BI dashboards and reports- Collaborate with stakeholders to gather requirements and identify data sources- Analyze complex datasets to create meaningful visualizations and insights- Optimize Power BI solutions for performance and usability- Troubleshoot and resolve issues with existing Power BI models and reportsRequirements:- Proven experience as a Power BI Developer or similar role- Proficiency in Power BI, SQL, and data modeling- Strong analytical and problem-solving skills- Excellent communication and collaboration abilities- Attention to detail and ability to meet deadlinesPosted On: May 13, 2024 05:53 UTCCategory: Data VisualizationSkills:Microsoft Power BI, Data Visualization, Data Analysis, Business Intelligence Skills: Microsoft Power BI, Data Visualization, Data Analysis, Business Intelligence Country: Australiaclick to apply',
#  'We are seeking a skilled Marketing Data Analyst to support our marketing team with data analysis and reporting. The ideal candidate will have experience using Google Looker Studio and Power BI to extract, analyze, and visualize data related to marketing campaigns. As a Marketing Data Analyst, your responsibilities will include interpreting data, identifying trends and patterns, and providing actionable insights to improve marketing strategies. This role requires strong analytical skills, attention to detail, and the ability to work independently. Key Skills:- Proficient in Google Looker Studio and Power BI- Strong analytical and problem-solving skills- Ability to interpret and communicate data findings effectively- Experience with marketing analytics and reporting- Familiarity with data visualization techniquesWe are a fast-paced marketing team looking for someone who can deliver high-quality work within tight deadlines. This is a great opportunity for a data-driven individual to contribute to our marketing success.Size: MediumDuration: 1 to 3 monthsExpertise: IntermediatePosted On: May 13, 2024 05:32 UTCCategory: Data AnalyticsSkills:Data Analysis, Google Analytics, Microsoft Excel, Marketing Analytics, Data Entry Skills: Data Analysis, Google Analytics, Microsoft Excel, Marketing Analytics, Data Entry Country: United Kingdomclick to apply',
#  '- Develop amp; deliver tailored data science amp; ML curriculum.- Create engaging learning materials amp; conduct training sessions.- Provide individual support amp; integrate concepts into our projects.Requirements:- Proven expertise in data science amp; machine learning.- Strong communication amp; teaching skills.- Experience in curriculum development.- Proficiency in Python, R, or Julia.- Startup experience preferred.Hourly Range: $5.00-$8.00Posted On: May 13, 2024 05:17 UTCCategory: Data AnalyticsSkills:SQL, Python, Tableau, Microsoft Power BI Data Visualization, Machine Learning, Statistics, Linear Regression, Data Science, Data Analytics Visualization Software, Deep Learning, Data Analysis, Supervised Learning, Unsupervised Learning, Data Modeling, NLP Tokenization Skills: SQL, Python, Tableau, Microsoft Power BI Data Visualization, Machine Learning, Statistics, Linear Regression, Data Science, Data Analytics Visualization Software, Deep Learning, Data Analysis, Supervised Learning, Unsupervised Learning, Data Modeling, NLP Tokenization Country: Indiaclick to apply',
#  'Data Visualization and KPI Dashboard for Tyre Retailer and Mechanical Service business.Looking to create a data visualization dashboard to easily glean a quick overview of important business KPIs using charts and pivot tables.Looking for a Data Analysist who can help transform lots of data points into useful data visualization and so my client can quickly understandand interpret important business KPIs. Ideally you would have done this before with a similar business.What I have in mind is a combination of charts and pivot table to give a quick overview of how the business is tracking in terms of sales revenue. Understand what is currently in demand and identify top sellers as well as keeping track of COGS, Source of business, Gross Profit, marketing channels, Average Transaction Value (ATV) and Customer Lifetime Value (CLV).We receive an email with a CSV file from our CRM and the end of each business day, which has all the details of the transactions for that business day. The CSV files are then transferred and stored in a Dropbox folder rather than using Googles platform.Wondering if all this can be done just using Excel or it is better to use Power BI for a more user-friendly experience for my client.Also wondering if it can collect phone tracking CSVs from our Google Ads account and correlate phone numbers from Google Ads tracking with phone numbers from our CRM so we can see which customers actually ended up buying and how much they spent. Point of sale is via phone calls and Google Phone tracking CSVs from each campaign are also downloaded to a Dropbox FolderFetching data from Dropbox data sources containing CSV files . Can Excel or Power BI be setup to automatically fetch data on a daily basis whenever a new CSV file enters the folder? Wondering if all this can be done just using Excel or it is better to use Power BI for a more user friendly experience.Here is some Business Background.This business is a tyre and wheels retailer as well as offering all aspects of mechanical service and repairs.4 Main Departments within the business1. All aspects of Mechanical Service and Repairs2. Tyre amp; Wheel sales and Fitting3. Wheel Alignments4. Wheel Repair amp; RestorationSales Revenue Breakdown into Daily, Weekly, Monthly and Yearly.Showing Daily, Weekly, Monthly and Yearly Sales target vs achieved results. Track revenue streams from retail customers. Track revenue streams from wholesale clients. Track revenue streams from Existing Customers Track revenue streams from New Customers Track revenue streams from Google Ads campaigns. Track revenue streams from Facebook Ads campaigns. Track revenue streams from Referrals.Segment revenue by service type:1. All aspects of Mechanical Service and Repairs2. Tyre amp; Wheel Sales and Fitting3. Wheel Alignments4. Wheel Repair amp; RestorationCost of Goods Sold (COGS). Monitor the direct costs associated with providing services: Please note, all Cost of Goods Sold pricing provided is Excl 10% GST from the CRM source Labour Parts Materials.Differentiate Between Cost of Goods Sold (COGS)We are yet to implement a system to get details around this data, although we have overall COGS available for:1. All aspects of Mechanical Service and Repairs2. Tyre amp; Wheel Fitting3. Wheel Alignments4. Wheel Repair amp; RestorationGross Profit Margin: Calculate and display profitability of each service category by subtracting COGS from revenue. Analyse trends to identify which services contribute the most to gross profit margin.Labour Efficiency and Utilization: Measure the productivity of technicians by tracking billable hours versus non-billable hours. Evaluate utilization rates to identify opportunities for increasing efficiency without sacrificing quality.Marketing and Advertising ROI: Evaluate the effectiveness of marketing campaigns by measuring their impact on sales and customer acquisition. Calculate the return on investment (ROI) for various advertising channels, such as digital marketing, print m ...
#  'Herbal Goodness is seeking a skilled and experienced Business Intelligence (BI) Analyst to join our team on a short-term contract basis, with the possibility of a long-term engagement. The BI Analyst will play a crucial role in gathering, organizing, and analyzing data to support business decision-making processes and enhance our strategic initiatives.Job Responsibilities:Data Collection and Gathering:Collect and compile sales data from the past 5 years across various platforms, including QuickBooks and other sales channels.Gather product, inventory, and competitor data from diverse sources such as company databases, industry reports, public information, and field reports.Data Cleaning and Analysis:Clean and prepare data sets to ensure accuracy and consistency.Analyze data related to revenue, sales, market information, and customer engagement metrics to derive actionable insights.Data Visualization and Reporting:Utilize data visualization tools and reporting platforms to create intuitive and informative dashboards.Develop templates and generate comprehensive reports to support business forecasting, trend analysis, and decision-making processes.Trend Identification and Opportunity Analysis:Identify trends, patterns, and opportunities within the data to support strategic planning and operational improvements.Provide insights and recommendations to address business challenges and capitalize on market opportunities.Collaboration and Communication:Collaborate with cross-functional teams to understand data needs and business objectives.Communicate findings and insights effectively to stakeholders through reports, presentations, and dashboards.Qualifications:Education: Bachelors degree in Business, Data Science, Statistics, or a related field.Experience:Proven experience as a Business Intelligence Analyst or similar role.Proficiency in data analysis, data cleaning, and data visualization.Skills:Strong proficiency in data visualization tools (e.g., Tableau, Power BI) and reporting platforms.Experience with data analysis software and tools (e.g., Excel, SQL, R).Excellent analytical and problem-solving skills.Strong attention to detail and accuracy.Effective communication skills, both written and verbal.Ability to work independently and manage multiple tasks efficiently.Strong organizational skills and ability to prioritize tasks.Commitment to delivering high-quality work within tight deadlines.Type: Short-term contract with potential for long-term engagement.Work Hours: Flexible remote work arrangement.Please submit your resume, a cover letter outlining your experience as a BI Analyst, and examples of previous work, such as dashboards, reports, or data analysis projects. We also encourage you to include any relevant certifications and case studies demonstrating your ability to drive business insights and decision-making through data analysis.Join Herbal Goodness and contribute to our mission by leveraging your data expertise to drive informed business decisions and support our growth. We look forward to working with a talented and dedicated BI Analyst to enhance our data-driven strategies!Budget: $800Posted On: May 13, 2024 02:57 UTCCategory: Business Analysis StrategySkills:Business Process Modeling, Business Analysis, Operational Planning, Business Intelligence, Data Visualization, Data Analysis, Microsoft Excel, Tableau, Microsoft Power BI, Data Modeling Skills: Business Process Modeling, Business Analysis, Operational Planning, Business Intelligence, Data Visualization, Data Analysis, Microsoft Excel, Tableau, Microsoft Power BI, Data Modeling Country: United Statesclick to apply',
#  'Need some in the US timezone to monitor and provide the level 1 and L2 support to monitor and troubleshoot the DWH operations. The person should be having experience and knowledge about DWH basic concepts , ETL using DBt and hands on Expereince with Amazon Redshift . Familiar with POWER BI and can develop dashboards for operations and provide weekly status updates. Hourly Range: $5.00-$9.00Posted On: May 13, 2024 01:50 UTCCategory: Data EngineeringSkills:Amazon Redshift, ETL, ETL Pipeline, Python, Amazon Web Services, Amazon S3 Select Skills: Amazon Redshift, ETL, ETL Pipeline, Python, Amazon Web Services, Amazon S3 Select Country: United Statesclick to apply',
#  'I attached two examples illustrative of the model that I am looking for but not exhaustive completely. 1. the revenue build should be exhaustive where it considers all factors related to Graves and its current treatment landscape (antithyroid, betablocker, surgery, possibility of FcRn approval, etc), so that we have the most accurate disease population.2. using the company of your choosing with highest rate of growth, develop the income statement, unlevered free cash flow, and DCF analysis so that it predicts the expected price per share of the company.3. create one or two sensitivity analyses.4. provide the source or explanation for any statistic or assumption that you use.No need for any diagrams or visualizations.I want the main takeaway to be a lesson to how a professional like yourself develops a model. I would like to learn what factors you consider are important and how I can set myself apart as an outstanding biotech analyst. Willing to negotiate price.Budget: $100Posted On: May 13, 2024 01:18 UTCCategory: Data AnalyticsSkills:Biotechnology, Data Analysis, Critical Thinking Skills, Pharmaceutical Industry, Pharmacology, Strategy, Infographic, Secondary Research, SWOT Analysis, Data Mining, Neuroscience, PowerPoint Presentation, Microsoft Power BI, Power Query, Biotechnology Regulation Skills: Biotechnology, Data Analysis, Critical Thinking Skills, Pharmaceutical Industry, Pharmacology, Strategy, Infographic, Secondary Research, SWOT Analysis, Data Mining, Neuroscience, PowerPoint Presentation, Microsoft Power BI, Power Query, Biotechnology Regulation Country: United Statesclick to apply',
#  'We are an antique car repair and restoration business. This opportunity requires Philosophical Creativity in combination with a desire to dive deep into the theory behind our vision, to help us to reason through and design complex formulas.The ideal candidate will become a long- term consultant, helping us define and build the reports necessary to provide transparency on the health of the progression of each of our projects, as well as the individual (and collective) contribution performance of the staff, including technicians and administrative team members, to ultimately visualize these and other organizational KPIs.We have been developing on the Microsoft Power Platform for several years. Consequently, we have created many fields/ columns of custom data that we need to turn into performance visualizations. This will require initially gaining an understanding of what we currently have, and what the intention is/was behind each customization. We will then work together on defining, articulating and refining our theory, formulas and business processes. Ww have already developed both SSRS reports and Power BI reports, but still need to dive much deeper into the weeds to achieve our vision. We will continue to identify and add new data points as we see fit. Dont let not being experienced with Power BI or SSRS deter you from responding, providing you really feel a connection to this opportunity.We are on EST, and I am typically available to meet/collaborate between 9am and 3pm EST, both on weekdays and weekends. Hourly Range: $20.00-$150.00Posted On: May 12, 2024 22:04 UTCCategory: MathematicsSkills:Mathematics, Data Analysis, Data Visualization Skills: Mathematics, Data Analysis, Data Visualization Country: United Statesclick to apply',
#  'We are seeking a skilled developer to implement a solution for automatically pulling real-time data from a set of APIs and storing it in an Azure Data Lake. The successful candidate will set up a cron job to automate data retrieval at scheduled intervals. The stored data will be utilized in Power BI for analytics and reporting purposes. Applicants with innovative ideas on how to streamline or enhance this process are highly encouraged to share alternative approaches or more efficient solutions.Budget: $250Posted On: May 12, 2024 21:30 UTCCategory: Back-End DevelopmentSkills:Python, Linux System Administration, Data Lake, Azure App Service, API, Linux Skills: Python, Linux System Administration, Data Lake, Azure App Service, API, Linux Country: South Africaclick to apply',
#  'Anthonys Villa is seeking a skilled EHR Form Builder/Report Writer to join our team. This role is critical in developing and maintaining electronic health records (EHR) forms and generating insightful reports to support the operational and clinical needs of our facility. The ideal candidate will be proficient in EchoVantage EHR Form Designer, SSRS (SQL Server Reporting Services), and Power BI.**Key Responsibilities:**- Design, build, and maintain forms within the EchoVantage EHR Form Designer to ensure accurate and efficient data capture.- Develop and manage reports using SSRS and Power BI to support decision-making across clinical and administrative functions.- Work closely with clinical and administrative staff to understand and translate business requirements into functional EHR forms and reports.- Ensure all forms and reports adhere to compliance and regulatory standards.- Troubleshoot and resolve issues related to EHR forms and reports.- Provide training and support to staff on new forms and reporting tools.- Maintain up-to-date knowledge of trends and developments in EHR technology and reporting standards.**Qualifications:**- Bachelors degree in Computer Science, Information Technology, Healthcare Administration, or a related field.- Proven experience with EchoVantage EHR Form Designer, SSRS, and Power BI.- Strong understanding of database management and data analysis.- Excellent problem-solving skills and attention to detail.- Ability to communicate technical information to non-technical staff.- Experience in a healthcare setting is preferred.**Skills:**- Proficiency in SQL and database management.- Strong analytical and reporting skills.- Excellent interpersonal and communication skills.- Ability to manage multiple projects simultaneously and meet deadlines.Hourly Range: $20.00-$50.00Posted On: May 12, 2024 20:11 UTCCategory: Database AdministrationSkills:Microsoft SQL Server, SQL Server Reporting Services, ETL, SQL Server Integration Services, Database Design, Database Administration, Database Optimization, Electronic Health Record, Healthcare IT Skills: Microsoft SQL Server, SQL Server Reporting Services, ETL, SQL Server Integration Services, Database Design, Database Administration, Database Optimization, Electronic Health Record, Healthcare IT Country: United Statesclick to apply',
#  'We need to have multiple Microsft Power BI dashboard for our customers, each dashboard should have a separate link. and we need to remove the Microsoft power BI logo from the dashboard. We need to create a perfect mobile view for each dashboard for the customer also can we connect google sheet as a data source for the power BI. Posted On: May 12, 2024 19:31 UTCCategory: Data AnalyticsSkills:Data Analysis, Microsoft Power BI, Microsoft Excel, System Administration, System Analysis, Content Management System, SAP, SAP MM Consultant, SAP ERP Skills: Data Analysis, Microsoft Power BI, Microsoft Excel, System Administration, System Analysis, Content Management System, SAP, SAP MM Consultant, SAP ERP Country: Saudi Arabiaclick to apply',
#  'Job Title: Senior Data ScientistIntroduction:We are looking for a seasoned Data Scientist to join our dynamic team. The ideal candidate will be able to use their extensive knowledge of data science and analysis to provide insights and to improve our decision-making. The candidate will be responsible for designing, developing, and implementing predictive models and algorithms to analyze large amounts of data and provide meaningful business solutions.Overview of the Role:The Senior Data Scientist will work closely with various teams within the organization, including executive leadership, product development, and marketing to understand business challenges and develop data-driven solutions. This role requires a deep understanding of data analysis, data mining, machine learning, and statistical modeling techniques. The successful candidate will be able to translate complex findings and results into a compelling narrative that drives strategic decision-making.Key Responsibilities:1. Utilizing advanced analytics and machine learning to identify trends and patterns in complex data sets.2. Designing and implementing predictive models and algorithms.3. Collaborating with cross-functional teams to understand business needs and develop solutions.4. Presenting complex findings in a clear and compelling manner to non-technical stakeholders.5. Ensuring data quality and integrity in all deliverables.6. Staying on top of the latest industry trends and technologies to continually improve our data science capabilities.Skills and Qualifications:1. Masters degree in Data Science, Statistics, Computer Science, or a related field.2. At least five years of experience in a data science role.3. Extensive knowledge of machine learning techniques and algorithms.4. Proficiency in programming languages such as Python or R.5. Strong knowledge of SQL and database structures.6. Experience with data visualization tools such as Tableau or PowerBI.7. Excellent problem-solving skills and attention to detail.8. Strong communication skills, both written and verbal.Benefits:The successful candidate will enjoy a competitive salary package, comprehensive health benefits, a flexible work schedule, continuous learning opportunities, and a collaborative work environment.Call to Action:If you are passionate about data science and want to use your skills to make a tangible impact on our business, apply today. Join us in shaping the future of our industry with data-driven solutions. Apply now to be considered for this exciting opportunity.Please note that only shortlisted candidates will be contacted. We look forward to receiving your applications!Hourly Range: $15.00-$75.00Posted On: May 12, 2024 18:27 UTCCategory: Data AnalyticsSkills:Machine Learning, Data Modeling, Apache Hive, Big Data, Business Intelligence, Computer Vision, NumPy, Microsoft Excel, BigQuery Skills: Machine Learning, Data Modeling, Apache Hive, Big Data, Business Intelligence, Computer Vision, NumPy, Microsoft Excel, BigQuery Country: Netherlandsclick to apply',
#  'HiHope youre doing well. Im reaching out from My Profit Company. Were currently in the process of migrating from AWS to Google Cloud and facing some hurdles, particularly with dataset migration and certificate management. Given your expertise, wed like to book around 3-10 hours of consultation to help us navigate these challenges. Could we schedule a session soon?Best,LucjanPosted On: May 12, 2024 17:12 UTCCategory: Data AnalyticsSkills:SQL, Data Analysis, Dashboard, Data Visualization, Report, Microsoft Power BI, Microsoft Excel, Business Intelligence, Power Query, Microsoft Power BI Development, Microsoft Power Automate, Microsoft SharePoint, Microsoft Power BI Data Visualization, Microsoft SharePoint Administration, API Skills: SQL, Data Analysis, Dashboard, Data Visualization, Report, Microsoft Power BI, Microsoft Excel, Business Intelligence, Power Query, Microsoft Power BI Development, Microsoft Power Automate, Microsoft SharePoint, Microsoft Power BI Data Visualization, Microsoft SharePoint Administration, API Country: Spainclick to apply',
#  '### Data Analysis Project Post:**Title:** Urgent Need for Power BI and SQL Expert to Resolve Data Transition Issues**Description:**We are seeking an experienced Power BI and SQL expert to assist in a critical project transitioning data from Tableau to Power BI. Our project has faced multiple rejections from stakeholders, and we urgently require a specialist to refine our deliverables to meet high standards.**Requirements:**- Proficient in Power BI, with an excellent track record of developing complex visualizations and dashboards.- Expertise in SQL and experience with Dremio or similar data query environments.- Ability to troubleshoot and resolve data issues, specifically relating to duplicate data entries affecting outputs.- Must be available for immediate start and flexible for Zoom meetings to review current setups and provide actionable insights.**Responsibilities:**- Review and analyze current Tableau to Power BI transition setups.- Write and optimize SQL queries to clean up and organize data effectively, especially to resolve duplications.- Collaborate with our team to enhance the overall data presentation and ensure deliverables meet stakeholder expectations.- Provide expert advice and strategic recommendations to improve data handling and visualization.Posted On: May 12, 2024 16:58 UTCCategory: Presentation DesignSkills:Microsoft Power BI, Tableau, SQL, Query Debugging Skills: Microsoft Power BI, Tableau, SQL, Query Debugging Country: United Statesclick to apply',
#  'Looking for a Power BI and SAP SAC expert to support pre-sales activities on a remote, as-needed basis. The role involves preparing presentations, system demos, and providing expert insights to prospective customers.Responsibilities:- Create and present PowerPoint presentations.- Conduct system and capability demos.- Serve as a subject matter expert during customer interactions.Requirements:- Proven experience with Power BI and SAP SAC.- Strong presentation and demonstration skills.- Excellent communication abilities.Job Type: Remote, freelanceHourly Range: $5.00-$20.00Posted On: May 12, 2024 15:55 UTCCategory: Data VisualizationSkills:Microsoft Power BI, SAP, Data Visualization, Business Intelligence, Data Modeling, Data Analysis, Microsoft Excel, ETL Skills: Microsoft Power BI, SAP, Data Visualization, Business Intelligence, Data Modeling, Data Analysis, Microsoft Excel, ETL Country: United Arab Emiratesclick to apply',
#  'We are seeking a skilled Data Analyst with a strong command of English for our business. As a Data Analyst, you will be responsible for collecting, analyzing, and interpreting complex data sets to provide valuable insights and recommendations. The ideal candidate should have a solid understanding of statistical methodologies, data visualization, and data mining techniques. Responsibilities:- Collect and clean data from various sources- Perform statistical analysis and generate reports- Develop and maintain databases- Create data visualizations and dashboards- Identify trends and patterns in dataRequirements:- Proven experience as a Data Analyst or in a similar role- Strong analytical skills and attention to detail- Proficient in SQL and data visualization tools (e.g., Tableau, Power BI)- Excellent English communication skillsThis is a medium-sized project with a duration of 1 to 3 months. We are looking for an intermediate-level Data Analyst who can work independently and deliver high-quality results. If you are passionate about data analysis and have a strong business acumen, we would love to hear from you!Hourly Range: $17.00-$50.00Posted On: May 12, 2024 12:41 UTCCategory: Data AnalyticsSkills:Microsoft Excel, English, Data Entry Skills: Microsoft Excel, English, Data Entry Country: Franceclick to apply',
#  'We are seeking someone who would be able to generate some statistics for us. We are looking for a sports statistician that we could hire for this this, ideally with knowledge of the NFL, although we could also do baseball/MLB too. We need someone to crunch the data and identify and rank the teams in different sports that peak too soon and also maybe the ones that stay strong and/or finish strong. We could define peaking too soon to mean either consistently peaking too early in the game or peaking too soon in a season or some combination of both. Let me know if this is something you could help us with! Posted On: May 12, 2024 11:13 UTCCategory: Data AnalyticsSkills:Data Science, Visualization, Microsoft Power BI Data Visualization, Data Analytics, Analytics, Analytical Presentation, Data Analysis, R, Microsoft Excel, Microsoft Power BI, Microsoft PowerPoint, Python Skills: Data Science, Visualization, Microsoft Power BI Data Visualization, Data Analytics, Analytics, Analytical Presentation, Data Analysis, R, Microsoft Excel, Microsoft Power BI, Microsoft PowerPoint, Python Country: United Kingdomclick to apply',
#  'Extract Specific contact information (name, address, phone number amp; email address) from a power BI website. Create a Dynamic Excel Spreadsheet that can be refreshed when needed.I created a ppt that explains in more detail the objective and were to get the infomation. For someone profecient with Power BI, it should be easy to quot;Get Dataquot; then clean up the spreadsheet to meet minimum requirements. Budget: $50Posted On: May 12, 2024 09:16 UTCCategory: Data ExtractionSkills:Microsoft Power BI, Microsoft Excel, Data Scraping, Data Mining Skills: Microsoft Power BI, Microsoft Excel, Data Scraping, Data Mining Country: United Statesclick to apply',
#  'Hi, I work as a recruiter for a tech company and looking for someone to help me build a good excel tracker with analytics I can use to track recruitment activity at the company. I have already created a draft version on excel to give you an idea of the information I need captured. I need someone to take the draft and create a better version that is easily customisable, where all the data flows through seamlessly across each tabs with a main dashboard that summarises the key recruitment KPIs.The purpose of the tracker is capture information such as the below (these are some of them)- Total open vacancies - Total offers made in March 2024 - Total offers made in Q1 2024- Offer acceptance %- Time to hire %- Average source of hire (did hires come through Linkedin, careers page, job advert etc)- Total hires made in each global office by month, by quarter, by yearPosted On: May 12, 2024 09:16 UTCCategory: Recruiting Talent SourcingSkills:Microsoft Excel, Data Visualization, Analytics, Microsoft Power BI, Tableau Skills: Microsoft Excel, Data Visualization, Analytics, Microsoft Power BI, Tableau Country: United Kingdomclick to apply']

# %%
#Data extraction + Transformation to get only clean + relevant data

#MAIN

#CLEANING 1 FILE ONLY

#for file in files:
output = {}
id = 0
#file_name = file + "processed"
output["title"] = json_file1["rss"]['channel']["title"]
output["link"] = json_file1["rss"]['channel']["link"]
output["language"] = json_file1["rss"]['channel']["language"]
output["pubDate"] = json_file1["rss"]['channel']["pubDate"]
descriptions = json_file1["rss"]['channel']['item']
output["jobs"]=[] #Jobs list innitialisation

for description in descriptions: #list of descriptions
    #to delete #output["jobs"][n][""] = json_file1["rss"]['channel']['item'][n] # should i use append? .append() # I need specific things here
    job = {}
    job["id"] = id
    job["title"] = description["title"]
    job["link"] = description["link"]
    job["description"] = cleanhtml(description["content:encoded"]) #clean the descriptions (html and /n etc...)
    job["pubDate"] = description["pubDate"]
    output["jobs"].append(job) # should i use append? .append() # Ineed specific things here
    id = id + 1

output
# Out:
# {'title': 'All jobs | upwork.com',
#  'link': 'https://www.upwork.com/ab/feed/jobs/rss?api_params=1&amp;orgUid=1729067928257851393&amp;paging=0-10&amp;q=Power%20Bi&amp;securityToken=d17308910f66b74d222ca66c907efa56c942739d41db7bba3da3ca225a9584b2edcab156ed12fcd81a0f94e952ea29d611248991196927c716632e2284293c57&amp;sort=recency&amp;userUid=1729067928257851392',
#  'language': 'en-us',
#  'pubDate': 'Mon, 13 May 2024 12:22:38 +0000',
#  'jobs': [{'id': 0,
#    'title': 'Professional dashboard built in MicroStrategy - Upwork',
#    'link': 'https://www.upwork.com/jobs/Professional-dashboard-built-MicroStrategy_%7E01ec8934d454ff0ef3?source=rss',
#    'description': 'Hi I am looking for a professional dashboard built in MicroStrategy, using advanced visualizations and automation. The dataset is small(about 107 rows)and straight forward. Also please indicate how long will it take for you to do the job?ThanksCharuPosted On: May 13, 2024 09:46 UTCCategory: Data VisualizationSkills:Microsoft Power BI Data Visualization, Microsoft Power BI, Dashboard, Business Intelligence, SQL, Microsoft Power BI Development, Database, Microsoft Excel, Data Mining, BigQuery, Data Visualization, Analytics Dashboard, Data Modeling, Data Analytics Skills: Microsoft Power BI Data Visualization, Microsoft Power BI, Dashboard, Business Intelligence, SQL, Microsoft Power BI Development, Database, Microsoft Excel, Data Mining, BigQuery, Data Visualization, Analytics Dashboard, Data Modeling, Data Analytics Country: United Kingdomclick to apply',
#    'pubDate': 'Mon, 13 May 2024 09:46:45 +0000'},
#   {'id': 1,
#    'title': 'Power BI Developer - Upwork',
#    'link': 'https://www.upwork.com/jobs/Power-Developer_%7E01c839d932d942a650?source=rss',
#    'description': 'We are seeking a Power BI Developer to assist with our data visualization and reporting needs. The ideal candidate will have experience in creating interactive dashboards and reports using Power BI tools. Key responsibilities include: - Creating visually appealing and informative dashboards.- Building data models and establishing connections to various data sources.- Generating reports and insights that meet business requirements. Qualifications:- Proficiency in Power BI Desktop, Power Query, DAX, and M languages- Familiarity with SQL, data warehousing concepts, and ETL processes is a plus.- Experience in data visualization principles and best practices.Hourly Range: $25.00-$60.00Posted On: May 13, 2024 09:44 UTCCategory: Data VisualizationSkills:Data Analysis Expressions, Microsoft Power BI, Data Visualization, Business Intelligence, Microsoft Power BI Development, Power Query, Microsoft SharePoint Skills: Data Analysis Expressions, Microsoft Power BI, Data Visualization, Business Intelligence, Microsoft Power BI Development, Power Query, Microsoft SharePoint Country: Philippinesclick to apply',
#    'pubDate': 'Mon, 13 May 2024 09:44:11 +0000'},
#   {'id': 2,
#    'title': 'Sports Analytics Expert Needed - Upwork',
#    'link': 'https://www.upwork.com/jobs/Sports-Analytics-Expert-Needed_%7E01eee8d1e717ced124?source=rss',
#    'description': 'We are seeking a skilled sports analytics expert to analyze a comprehensive dataset of cricket player statistics. The goal is to derive actionable insights and identify the impact of various factors on the game, enabling data-driven decision-making to enhance team performance.Responsibilities:Conduct detailed analysis of key performance indicators (KPIs) such as batting average, strike rate, bowling economy, and fielding effectiveness.Identify performance trends and patterns over time, including player career progression and consistency.Perform comparative analysis of player performance against different teams, in various formats (Test, ODI, T20), and under different conditions (home/away, pitch types, weather).Analyze player strengths and weaknesses, including performance against specific opponents and in high-pressure situations.Assess match-winning performances and overall contribution to team success.Use advanced analytical techniques such as cluster analysis, predictive modeling to uncover deeper insights.Create interactive dashboards and visualizations to present findings in an engaging and accessible manner.Deliverables:Comprehensive report detailing the analysis findings, including statistical summaries, visualizations, and key insights with codes.Interactive dashboards using tools like Tableau or Power BI for dynamic data exploration.Recommendations for optimizing player roles and strategies based on the analysis.Identification of potential areas for performance improvement and strategic adjustments.Qualifications:Proven experience in sports analytics, particularly with cricket datasets.Strong understanding of cricket, including rules, player roles, and game dynamics.Proficiency in data analysis tools and programming languages such as R, Python, or SQL.Experience with data visualization tools like Tableau, Power BI, or similar platforms.Ability to communicate complex analytical findings in a clear and concise manner.Passion for sports analytics and a keen eye for detail.Hourly Range: $5.00-$40.00Posted On: May 13, 2024 08:46 UTCCategory: Data AnalyticsSkills:R, Data Visualization, Microsoft Excel, Google Analytics, Search Engine Optimization, Data Analysis, Machine Learning, Analytics Skills: R, Data Visualization, Microsoft Excel, Google Analytics, Search Engine Optimization, Data Analysis, Machine Learning, Analytics Country: United Kingdomclick to apply',
#    'pubDate': 'Mon, 13 May 2024 08:46:15 +0000'},
#   {'id': 3,
#    'title': 'Data analyst/BI expert to help automate a series of analytics reports - Upwork',
#    'link': 'https://www.upwork.com/jobs/Data-analyst-expert-help-automate-series-analytics-reports_%7E017e99068e70711d6b?source=rss',
#    'description': 'write a scope of work that is focused on data consumer behavior and other important key metrics that will enable the dealership to sell smarter to its customers. Skills required are pyhthon, sql and powerbiDeliverables: Defined and prioritized KPIs for sales and marketing Customer segmentation insights and reports Recommendations for targeted marketing campaigns across various channels Data-driven strategies for optimizing the sales process Ongoing reporting dashboards Final report with actionable recommendationscommunication will be via email and Microsoft teamsBudget: $500Posted On: May 13, 2024 09:27 UTCCategory: Data AnalyticsSkills:SQL, Microsoft Power BI, Business Intelligence, Python Skills: SQL, Microsoft Power BI, Business Intelligence, Python Country: South Africaclick to apply',
#    'pubDate': 'Mon, 13 May 2024 09:27:40 +0000'},
#   {'id': 4,
#    'title': 'Real Estate Listing and Transaction Database with Predictive Analytics - Upwork',
#    'link': 'https://www.upwork.com/jobs/Real-Estate-Listing-and-Transaction-Database-with-Predictive-Analytics_%7E01b4961d51a60e9f07?source=rss',
#    'description': 'We are seeking a skilled data engineer and data scientist to create a comprehensive real estate database that tracks listings and transactions on a weekly basis. The goal of this project is to develop a tool that can predict real estate price movements and identify underpriced properties using Microsoft Azure Machine Learning.Responsibilities:1. Design and create an SQL database to store real estate listings and transactions.2. Develop scripts to collect real estate data from various sources and update the database weekly.3. Implement data cleaning and deduplication processes to ensure data integrity and accuracy.4. Track changes in listings on a weekly basis and store historical data for analysis.5. Connect the database to Power BI to create interactive dashboards and visualizations for data analysis.6. Utilize Microsoft Azure Machine Learning to develop models for predicting real estate price movements and identifying underpriced properties.7. Provide functionality to export data from the SQL database to Excel for further analysis.8. Provide documentation and support for the database, analytics tools, and machine learning models.Requirements:1. Experience with SQL database design and management.2. Proficiency in data collection and web scraping using Python or other relevant tools.3. Knowledge of data cleaning, deduplication, and data transformation techniques.4. Familiarity with Power BI or similar data visualization tools.5. Experience with Microsoft Azure Machine Learning or similar cloud-based machine learning platforms.6. Strong problem-solving and analytical skills.7. Good communication skills and ability to work independently.Deliverables:1. A functional SQL database populated with real estate listings and transactions.2. Scripts to collect and update data weekly.3. Data cleaning and deduplication processes implemented within the database.4. Power BI dashboards and reports for data visualization and analysis.5. Machine learning models developed using Azure Machine Learning for predicting real estate price movements and identifying underpriced properties.6. Functionality to export data from the SQL database to Excel.Documentation for the database, data collection scripts, analytics components, and machine learning models.Timeline:The project is expected to take approximately 4-6 weeks to complete, with regular progress updates throughout the duration of the project.Budget:The budget for this project is set at $1,500, which includes the development of the database, data collection scripts, data cleaning processes, Power BI integration, and machine learning models using Microsoft Azure Machine Learning.If you have the required skills and experience and can work within the specified budget and timeline, please submit your proposal, including a project plan and timeline. We look forward to working with a talented data engineer and data scientist to bring this project to life.Please note that the ability to export data from the SQL database to Excel is considered part of the core functionality and does not need to be separately mentioned in the job description. It is assumed that the data engineer will provide this capability as part of the database development process.Budget: $1,500Posted On: May 13, 2024 09:18 UTCCategory: Data AnalyticsSkills:SQL, Microsoft Power BI, Data Entry, Data Analysis, Data Scraping, Data Mining, Python, Microsoft Excel, Microsoft Azure SQL Database, Machine Learning Algorithm Skills: SQL, Microsoft Power BI, Data Entry, Data Analysis, Data Scraping, Data Mining, Python, Microsoft Excel, Microsoft Azure SQL Database, Machine Learning Algorithm Country: United Arab Emiratesclick to apply',
#    'pubDate': 'Mon, 13 May 2024 09:18:18 +0000'},
#   {'id': 5,
#    'title': 'Ad-hoc PowerBI Support - Upwork',
#    'link': 'https://www.upwork.com/jobs/hoc-PowerBI-Support_%7E015ce72d94b930088d?source=rss',
#    'description': 'Need ad-hoc PowerBI support to develop visual reports.Datasource is MS Dataverse.Requirements typically involve connecting relationships between multiple tables and understand 1:N, different types of joins, etc.Hourly Range: $20.00-$25.00Posted On: May 13, 2024 08:56 UTCCategory: Data VisualizationSkills:Microsoft Power BI Skills: Microsoft Power BI Country: Singaporeclick to apply',
#    'pubDate': 'Mon, 13 May 2024 08:56:54 +0000'},
#   {'id': 6,
#    'title': 'Ema - Upwork',
#    'link': 'https://www.upwork.com/jobs/Ema_%7E018ea49528c5bb0933?source=rss',
#    'description': 'Please refer to enclosed PDFDetails requirement is in PDFPlease let me can you handle it?If yes, what is the cost and need how many days to deliver?Posted On: May 13, 2024 08:42 UTCCategory: Scripting AutomationSkills:Microsoft Power BI, Data Analysis Expressions, Data Analysis, Microsoft Power BI Data Visualization, Laravel, PHP, HTML5, MQL 4, MetaTrader 4, Forex Trading, MQL 5, MetaTrader 5, Microsoft Power BI Development, Search Engine Optimization, Microsoft Visual C++ Skills: Microsoft Power BI, Data Analysis Expressions, Data Analysis, Microsoft Power BI Data Visualization, Laravel, PHP, HTML5, MQL 4, MetaTrader 4, Forex Trading, MQL 5, MetaTrader 5, Microsoft Power BI Development, Search Engine Optimization, Microsoft Visual C++ Country: Malaysiaclick to apply',
#    'pubDate': 'Mon, 13 May 2024 08:42:05 +0000'},
#   {'id': 7,
#    'title': 'Customer Management Solution and PowerBI Reporting - Upwork',
#    'link': 'https://www.upwork.com/jobs/Customer-Management-Solution-and-PowerBI-Reporting_%7E014e5020598d3d582b?source=rss',
#    'description': 'We are seeking a skilled freelancer to develop a customer management solution and create PowerBI reports based on the datasets we provide on a weekly basis. The ideal candidate will have experience in both customer management systems and PowerBI reporting. This project requires the ability to integrate and manipulate data from Excel into a user-friendly customer management solution, as well as the creation of visually appealing PowerBI reports that provide valuable insights. Skills required:- Customer management system development- PowerBI reporting- Data integration and manipulation- Excel proficiencyThis is a medium-sized project expected to last between 1 to 3 months. We are looking for an intermediate-level freelancer who can confidently handle the requirements and deliver quality results within the given timeframe. Hourly Range: $5.00-$45.00Posted On: May 13, 2024 08:39 UTCCategory: Data VisualizationSkills:Microsoft Power BI, Business Intelligence, Data Analysis, Microsoft Excel Skills: Microsoft Power BI, Business Intelligence, Data Analysis, Microsoft Excel Country: Australiaclick to apply',
#    'pubDate': 'Mon, 13 May 2024 08:39:10 +0000'},
#   {'id': 8,
#    'title': 'Trigger URL in PowerBi - Upwork',
#    'link': 'https://www.upwork.com/jobs/Trigger-URL-PowerBi_%7E0112add0c6294cb28a?source=rss',
#    'description': 'Hi,We have a function stored on our Azure platform that is connected to a SQL Server table that holds a unique url that when entered into a browser changes another value on the same table to show that record has been seen and actioned by the user.We need to be able to trigger this url in a PowerBi table so we can update the tracking value in our table.The issue is that by default PowerBi opens a browser window.We need someone to help us overcome this so when the your is selected the value changes without opening a browser. We are happy to use Power Automate to achieve this, but need a detailed answer on what it requires us to do.We can send over the PBIX file upon initial messaging.We need someone immediately available and who has a feedback score of higher than 95%ThanksJonHourly Range: $20.00-$45.00Posted On: May 13, 2024 08:32 UTCCategory: Scripting AutomationSkills:API Integration, Microsoft Power BI, Power Query Skills: API Integration, Microsoft Power BI, Power Query Country: United Kingdomclick to apply',
#    'pubDate': 'Mon, 13 May 2024 08:32:14 +0000'},
#   {'id': 9,
#    'title': 'Automate salary/wages and costing sheets - Upwork',
#    'link': 'https://www.upwork.com/jobs/Automate-salary-wages-and-costing-sheets_%7E01261e12a504f06051?source=rss',
#    'description': 'We need to automate salary/wages and costing sheets in Excel by our desire. Could you accomplish itPosted On: May 13, 2024 07:47 UTCCategory: Machine LearningSkills:Data Science, Computer Vision, Microsoft Excel, Python, SciPy, Data Visualization, Microsoft Power BI, SQL, Machine Learning, Deep Learning, Neural Network, Data Extraction, Cloud Architecture, Data Analysis, API Skills: Data Science, Computer Vision, Microsoft Excel, Python, SciPy, Data Visualization, Microsoft Power BI, SQL, Machine Learning, Deep Learning, Neural Network, Data Extraction, Cloud Architecture, Data Analysis, API Country: Indiaclick to apply',
#    'pubDate': 'Mon, 13 May 2024 07:47:37 +0000'},
#   {'id': 10,
#    'title': 'PowerBI Developer for Dashboards - Upwork',
#    'link': 'https://www.upwork.com/jobs/PowerBI-Developer-for-Dashboards_%7E01db52a9ad0587d3ad?source=rss',
#    'description': 'We are seeking a skilled PowerBI developer to create interactive dashboards for our organization. The ideal candidate will have a strong background in data visualization and be proficient in using PowerBI to provide meaningful insights. As a PowerBI developer, you will collaborate with our team to understand our data requirements and design visually appealing dashboards that effectively communicate key metrics and trends. This role requires excellent problem-solving skills and the ability to work independently. Responsibilities:- Develop interactive dashboards using PowerBI- Analyze and visualize data to identify trends and patterns- Collaborate with stakeholders to understand data requirements- Optimize dashboards for performance and user experience- Troubleshoot and resolve issues with existing dashboardsRequired Skills:- Minimum 3-4 years of experience in PowerBi Dashboard development- Proficiency in PowerBI and related tools- Strong data visualization skills- Experience in designing and developing interactive dashboards- Knowledge of data modeling and database concepts- Excellent problem-solving and analytical abilitiesWe are looking for a medium-sized team to work on this project, with a duration of 15 - 30 days. The ideal candidate should have an advanced level of expertise in PowerBI development.Posted On: May 13, 2024 07:45 UTCCategory: Data VisualizationSkills:Microsoft Power BI, Data Visualization, Data Analysis, Business Intelligence Skills: Microsoft Power BI, Data Visualization, Data Analysis, Business Intelligence Country: Indiaclick to apply',
#    'pubDate': 'Mon, 13 May 2024 07:45:42 +0000'},
#   {'id': 11,
#    'title': 'Power BI Developer - Upwork',
#    'link': 'https://www.upwork.com/jobs/Power-Developer_%7E01ca09bd805598add1?source=rss',
#    'description': 'We are seeking an experienced Power BI Developer to join our team. As a Power BI Developer, you will be responsible for designing, developing, and implementing Power BI solutions. You will work closely with stakeholders to gather requirements, analyze data, and create visualizations and reports. The ideal candidate should have a strong background in data analysis and visualization, with proficiency in Power BI and SQL. Excellent problem-solving and communication skills are essential. Custom Financial amp; KPI reports for 2 organisations. Mainly information from Xero but there will be additional data sources to track KPIs from Google My Business, Streak. I have an idea on the reports required but need to outsource the expertise in getting these developed.Responsibilities:- Design, develop, and maintain Power BI dashboards and reports- Collaborate with stakeholders to gather requirements and identify data sources- Analyze complex datasets to create meaningful visualizations and insights- Optimize Power BI solutions for performance and usability- Troubleshoot and resolve issues with existing Power BI models and reportsRequirements:- Proven experience as a Power BI Developer or similar role- Proficiency in Power BI, SQL, and data modeling- Strong analytical and problem-solving skills- Excellent communication and collaboration abilities- Attention to detail and ability to meet deadlinesPosted On: May 13, 2024 05:53 UTCCategory: Data VisualizationSkills:Microsoft Power BI, Data Visualization, Data Analysis, Business Intelligence Skills: Microsoft Power BI, Data Visualization, Data Analysis, Business Intelligence Country: Australiaclick to apply',
#    'pubDate': 'Mon, 13 May 2024 05:53:52 +0000'},
#   {'id': 12,
#    'title': 'Marketing Data Analyst - Upwork',
#    'link': 'https://www.upwork.com/jobs/Marketing-Data-Analyst_%7E01ff56ea744ff0cee4?source=rss',
#    'description': 'We are seeking a skilled Marketing Data Analyst to support our marketing team with data analysis and reporting. The ideal candidate will have experience using Google Looker Studio and Power BI to extract, analyze, and visualize data related to marketing campaigns. As a Marketing Data Analyst, your responsibilities will include interpreting data, identifying trends and patterns, and providing actionable insights to improve marketing strategies. This role requires strong analytical skills, attention to detail, and the ability to work independently. Key Skills:- Proficient in Google Looker Studio and Power BI- Strong analytical and problem-solving skills- Ability to interpret and communicate data findings effectively- Experience with marketing analytics and reporting- Familiarity with data visualization techniquesWe are a fast-paced marketing team looking for someone who can deliver high-quality work within tight deadlines. This is a great opportunity for a data-driven individual to contribute to our marketing success.Size: MediumDuration: 1 to 3 monthsExpertise: IntermediatePosted On: May 13, 2024 05:32 UTCCategory: Data AnalyticsSkills:Data Analysis, Google Analytics, Microsoft Excel, Marketing Analytics, Data Entry Skills: Data Analysis, Google Analytics, Microsoft Excel, Marketing Analytics, Data Entry Country: United Kingdomclick to apply',
#    'pubDate': 'Mon, 13 May 2024 05:32:42 +0000'},
#   {'id': 13,
#    'title': 'Data Science and Machine Learning Instructor - Upwork',
#    'link': 'https://www.upwork.com/jobs/Data-Science-and-Machine-Learning-Instructor_%7E019f6cf40b250a1bb1?source=rss',
#    'description': '- Develop amp; deliver tailored data science amp; ML curriculum.- Create engaging learning materials amp; conduct training sessions.- Provide individual support amp; integrate concepts into our projects.Requirements:- Proven expertise in data science amp; machine learning.- Strong communication amp; teaching skills.- Experience in curriculum development.- Proficiency in Python, R, or Julia.- Startup experience preferred.Hourly Range: $5.00-$8.00Posted On: May 13, 2024 05:17 UTCCategory: Data AnalyticsSkills:SQL, Python, Tableau, Microsoft Power BI Data Visualization, Machine Learning, Statistics, Linear Regression, Data Science, Data Analytics Visualization Software, Deep Learning, Data Analysis, Supervised Learning, Unsupervised Learning, Data Modeling, NLP Tokenization Skills: SQL, Python, Tableau, Microsoft Power BI Data Visualization, Machine Learning, Statistics, Linear Regression, Data Science, Data Analytics Visualization Software, Deep Learning, Data Analysis, Supervised Learning, Unsupervised Learning, Data Modeling, NLP Tokenization Country: Indiaclick to apply',
#    'pubDate': 'Mon, 13 May 2024 05:17:44 +0000'},
#   {'id': 14,
#    'title': 'Create Data Visualization and KPI Dashboard - Upwork',
#    'link': 'https://www.upwork.com/jobs/Create-Data-Visualization-and-KPI-Dashboard_%7E012f165d5fe698847e?source=rss',
#    'description': 'Data Visualization and KPI Dashboard for Tyre Retailer and Mechanical Service business.Looking to create a data visualization dashboard to easily glean a quick overview of important business KPIs using charts and pivot tables.Looking for a Data Analysist who can help transform lots of data points into useful data visualization and so my client can quickly understandand interpret important business KPIs. Ideally you would have done this before with a similar business.What I have in mind is a combination of charts and pivot table to give a quick overview of how the business is tracking in terms of sales revenue. Understand what is currently in demand and identify top sellers as well as keeping track of COGS, Source of business, Gross Profit, marketing channels, Average Transaction Value (ATV) and Customer Lifetime Value (CLV).We receive an email with a CSV file from our CRM and the end of each business day, which has all the details of the transactions for that business day. The CSV files are then transferred and stored in a Dropbox folder rather than using Googles platform.Wondering if all this can be done just using Excel or it is better to use Power BI for a more user-friendly experience for my client.Also wondering if it can collect phone tracking CSVs from our Google Ads account and correlate phone numbers from Google Ads tracking with phone numbers from our CRM so we can see which customers actually ended up buying and how much they spent. Point of sale is via phone calls and Google Phone tracking CSVs from each campaign are also downloaded to a Dropbox FolderFetching data from Dropbox data sources containing CSV files . Can Excel or Power BI be setup to automatically fetch data on a daily basis whenever a new CSV file enters the folder? Wondering if all this can be done just using Excel or it is better to use Power BI for a more user friendly experience.Here is some Business Background.This business is a tyre and wheels retailer as well as offering all aspects of mechanical service and repairs.4 Main Departments within the business1. All aspects of Mechanical Service and Repairs2. Tyre amp; Wheel sales and Fitting3. Wheel Alignments4. Wheel Repair amp; RestorationSales Revenue Breakdown into Daily, Weekly, Monthly and Yearly.Showing Daily, Weekly, Monthly and Yearly Sales target vs achieved results. Track revenue streams from retail customers. Track revenue streams from wholesale clients. Track revenue streams from Existing Customers Track revenue streams from New Customers Track revenue streams from Google Ads campaigns. Track revenue streams from Facebook Ads campaigns. Track revenue streams from Referrals.Segment revenue by service type:1. All aspects of Mechanical Service and Repairs2. Tyre amp; Wheel Sales and Fitting3. Wheel Alignments4. Wheel Repair amp; RestorationCost of Goods Sold (COGS). Monitor the direct costs associated with providing services: Please note, all Cost of Goods Sold pricing provided is Excl 10% GST from the CRM source Labour Parts Materials.Differentiate Between Cost of Goods Sold (COGS)We are yet to implement a system to get details around this data, although we have overall COGS available for:1. All aspects of Mechanical Service and Repairs2. Tyre amp; Wheel Fitting3. Wheel Alignments4. Wheel Repair amp; RestorationGross Profit Margin: Calculate and display profitability of each service category by subtracting COGS from revenue. Analyse trends to identify which services contribute the most to gross profit margin.Labour Efficiency and Utilization: Measure the productivity of technicians by tracking billable hours versus non-billable hours. Evaluate utilization rates to identify opportunities for increasing efficiency without sacrificing quality.Marketing and Advertising ROI: Evaluate the effectiveness of marketing campaigns by measuring their impact on sales and customer acquisition. Calculate the return on investment (ROI) for various advertising channels, such as digital m ...
#    'pubDate': 'Mon, 13 May 2024 03:09:39 +0000'},
#   {'id': 15,
#    'title': 'Business Intelligence (BI) Analyst - Upwork',
#    'link': 'https://www.upwork.com/jobs/Business-Intelligence-Analyst_%7E0143d78fbdb8195d56?source=rss',
#    'description': 'Herbal Goodness is seeking a skilled and experienced Business Intelligence (BI) Analyst to join our team on a short-term contract basis, with the possibility of a long-term engagement. The BI Analyst will play a crucial role in gathering, organizing, and analyzing data to support business decision-making processes and enhance our strategic initiatives.Job Responsibilities:Data Collection and Gathering:Collect and compile sales data from the past 5 years across various platforms, including QuickBooks and other sales channels.Gather product, inventory, and competitor data from diverse sources such as company databases, industry reports, public information, and field reports.Data Cleaning and Analysis:Clean and prepare data sets to ensure accuracy and consistency.Analyze data related to revenue, sales, market information, and customer engagement metrics to derive actionable insights.Data Visualization and Reporting:Utilize data visualization tools and reporting platforms to create intuitive and informative dashboards.Develop templates and generate comprehensive reports to support business forecasting, trend analysis, and decision-making processes.Trend Identification and Opportunity Analysis:Identify trends, patterns, and opportunities within the data to support strategic planning and operational improvements.Provide insights and recommendations to address business challenges and capitalize on market opportunities.Collaboration and Communication:Collaborate with cross-functional teams to understand data needs and business objectives.Communicate findings and insights effectively to stakeholders through reports, presentations, and dashboards.Qualifications:Education: Bachelors degree in Business, Data Science, Statistics, or a related field.Experience:Proven experience as a Business Intelligence Analyst or similar role.Proficiency in data analysis, data cleaning, and data visualization.Skills:Strong proficiency in data visualization tools (e.g., Tableau, Power BI) and reporting platforms.Experience with data analysis software and tools (e.g., Excel, SQL, R).Excellent analytical and problem-solving skills.Strong attention to detail and accuracy.Effective communication skills, both written and verbal.Ability to work independently and manage multiple tasks efficiently.Strong organizational skills and ability to prioritize tasks.Commitment to delivering high-quality work within tight deadlines.Type: Short-term contract with potential for long-term engagement.Work Hours: Flexible remote work arrangement.Please submit your resume, a cover letter outlining your experience as a BI Analyst, and examples of previous work, such as dashboards, reports, or data analysis projects. We also encourage you to include any relevant certifications and case studies demonstrating your ability to drive business insights and decision-making through data analysis.Join Herbal Goodness and contribute to our mission by leveraging your data expertise to drive informed business decisions and support our growth. We look forward to working with a talented and dedicated BI Analyst to enhance our data-driven strategies!Budget: $800Posted On: May 13, 2024 02:57 UTCCategory: Business Analysis StrategySkills:Business Process Modeling, Business Analysis, Operational Planning, Business Intelligence, Data Visualization, Data Analysis, Microsoft Excel, Tableau, Microsoft Power BI, Data Modeling Skills: Business Process Modeling, Business Analysis, Operational Planning, Business Intelligence, Data Visualization, Data Analysis, Microsoft Excel, Tableau, Microsoft Power BI, Data Modeling Country: United Statesclick to apply',
#    'pubDate': 'Mon, 13 May 2024 02:57:17 +0000'},
#   {'id': 16,
#    'title': 'Production support L1 L2 for Datawarehouse operations Amazon Redshift and Dbt - Upwork',
#    'link': 'https://www.upwork.com/jobs/Production-support-for-Datawarehouse-operations-Amazon-Redshift-and-Dbt_%7E012f64e33d49fff183?source=rss',
#    'description': 'Need some in the US timezone to monitor and provide the level 1 and L2 support to monitor and troubleshoot the DWH operations. The person should be having experience and knowledge about DWH basic concepts , ETL using DBt and hands on Expereince with Amazon Redshift . Familiar with POWER BI and can develop dashboards for operations and provide weekly status updates. Hourly Range: $5.00-$9.00Posted On: May 13, 2024 01:50 UTCCategory: Data EngineeringSkills:Amazon Redshift, ETL, ETL Pipeline, Python, Amazon Web Services, Amazon S3 Select Skills: Amazon Redshift, ETL, ETL Pipeline, Python, Amazon Web Services, Amazon S3 Select Country: United Statesclick to apply',
#    'pubDate': 'Mon, 13 May 2024 01:50:13 +0000'},
#   {'id': 17,
#    'title': "US Graves' disease valuation model - Upwork",
#    'link': 'https://www.upwork.com/jobs/Graves-disease-valuation-model_%7E011ed668f38d9d20b8?source=rss',
#    'description': 'I attached two examples illustrative of the model that I am looking for but not exhaustive completely. 1. the revenue build should be exhaustive where it considers all factors related to Graves and its current treatment landscape (antithyroid, betablocker, surgery, possibility of FcRn approval, etc), so that we have the most accurate disease population.2. using the company of your choosing with highest rate of growth, develop the income statement, unlevered free cash flow, and DCF analysis so that it predicts the expected price per share of the company.3. create one or two sensitivity analyses.4. provide the source or explanation for any statistic or assumption that you use.No need for any diagrams or visualizations.I want the main takeaway to be a lesson to how a professional like yourself develops a model. I would like to learn what factors you consider are important and how I can set myself apart as an outstanding biotech analyst. Willing to negotiate price.Budget: $100Posted On: May 13, 2024 01:18 UTCCategory: Data AnalyticsSkills:Biotechnology, Data Analysis, Critical Thinking Skills, Pharmaceutical Industry, Pharmacology, Strategy, Infographic, Secondary Research, SWOT Analysis, Data Mining, Neuroscience, PowerPoint Presentation, Microsoft Power BI, Power Query, Biotechnology Regulation Skills: Biotechnology, Data Analysis, Critical Thinking Skills, Pharmaceutical Industry, Pharmacology, Strategy, Infographic, Secondary Research, SWOT Analysis, Data Mining, Neuroscience, PowerPoint Presentation, Microsoft Power BI, Power Query, Biotechnology Regulation Country: United Statesclick to apply',
#    'pubDate': 'Mon, 13 May 2024 01:18:04 +0000'},
#   {'id': 18,
#    'title': 'Data Analyst Mathematician Data Visualization - Upwork',
#    'link': 'https://www.upwork.com/jobs/Data-Analyst-Mathematician-Data-Visualization_%7E01b5d45b1704f68364?source=rss',
#    'description': 'We are an antique car repair and restoration business. This opportunity requires Philosophical Creativity in combination with a desire to dive deep into the theory behind our vision, to help us to reason through and design complex formulas.The ideal candidate will become a long- term consultant, helping us define and build the reports necessary to provide transparency on the health of the progression of each of our projects, as well as the individual (and collective) contribution performance of the staff, including technicians and administrative team members, to ultimately visualize these and other organizational KPIs.We have been developing on the Microsoft Power Platform for several years. Consequently, we have created many fields/ columns of custom data that we need to turn into performance visualizations. This will require initially gaining an understanding of what we currently have, and what the intention is/was behind each customization. We will then work together on defining, articulating and refining our theory, formulas and business processes. Ww have already developed both SSRS reports and Power BI reports, but still need to dive much deeper into the weeds to achieve our vision. We will continue to identify and add new data points as we see fit. Dont let not being experienced with Power BI or SSRS deter you from responding, providing you really feel a connection to this opportunity.We are on EST, and I am typically available to meet/collaborate between 9am and 3pm EST, both on weekdays and weekends. Hourly Range: $20.00-$150.00Posted On: May 12, 2024 22:04 UTCCategory: MathematicsSkills:Mathematics, Data Analysis, Data Visualization Skills: Mathematics, Data Analysis, Data Visualization Country: United Statesclick to apply',
#    'pubDate': 'Sun, 12 May 2024 22:04:47 +0000'},
#   {'id': 19,
#    'title': 'Data Integration Developer for API Management and Azure Data Lake Storage - Upwork',
#    'link': 'https://www.upwork.com/jobs/Data-Integration-Developer-for-API-Management-and-Azure-Data-Lake-Storage_%7E0134261e8435d3d482?source=rss',
#    'description': 'We are seeking a skilled developer to implement a solution for automatically pulling real-time data from a set of APIs and storing it in an Azure Data Lake. The successful candidate will set up a cron job to automate data retrieval at scheduled intervals. The stored data will be utilized in Power BI for analytics and reporting purposes. Applicants with innovative ideas on how to streamline or enhance this process are highly encouraged to share alternative approaches or more efficient solutions.Budget: $250Posted On: May 12, 2024 21:30 UTCCategory: Back-End DevelopmentSkills:Python, Linux System Administration, Data Lake, Azure App Service, API, Linux Skills: Python, Linux System Administration, Data Lake, Azure App Service, API, Linux Country: South Africaclick to apply',
#    'pubDate': 'Sun, 12 May 2024 21:30:57 +0000'},
#   {'id': 20,
#    'title': 'EHR Form Builder/Report Writer - Upwork',
#    'link': 'https://www.upwork.com/jobs/EHR-Form-Builder-Report-Writer_%7E01f7153b7a18641e98?source=rss',
#    'description': 'Anthonys Villa is seeking a skilled EHR Form Builder/Report Writer to join our team. This role is critical in developing and maintaining electronic health records (EHR) forms and generating insightful reports to support the operational and clinical needs of our facility. The ideal candidate will be proficient in EchoVantage EHR Form Designer, SSRS (SQL Server Reporting Services), and Power BI.**Key Responsibilities:**- Design, build, and maintain forms within the EchoVantage EHR Form Designer to ensure accurate and efficient data capture.- Develop and manage reports using SSRS and Power BI to support decision-making across clinical and administrative functions.- Work closely with clinical and administrative staff to understand and translate business requirements into functional EHR forms and reports.- Ensure all forms and reports adhere to compliance and regulatory standards.- Troubleshoot and resolve issues related to EHR forms and reports.- Provide training and support to staff on new forms and reporting tools.- Maintain up-to-date knowledge of trends and developments in EHR technology and reporting standards.**Qualifications:**- Bachelors degree in Computer Science, Information Technology, Healthcare Administration, or a related field.- Proven experience with EchoVantage EHR Form Designer, SSRS, and Power BI.- Strong understanding of database management and data analysis.- Excellent problem-solving skills and attention to detail.- Ability to communicate technical information to non-technical staff.- Experience in a healthcare setting is preferred.**Skills:**- Proficiency in SQL and database management.- Strong analytical and reporting skills.- Excellent interpersonal and communication skills.- Ability to manage multiple projects simultaneously and meet deadlines.Hourly Range: $20.00-$50.00Posted On: May 12, 2024 20:11 UTCCategory: Database AdministrationSkills:Microsoft SQL Server, SQL Server Reporting Services, ETL, SQL Server Integration Services, Database Design, Database Administration, Database Optimization, Electronic Health Record, Healthcare IT Skills: Microsoft SQL Server, SQL Server Reporting Services, ETL, SQL Server Integration Services, Database Design, Database Administration, Database Optimization, Electronic Health Record, Healthcare IT Country: United Statesclick to apply',
#    'pubDate': 'Sun, 12 May 2024 20:11:32 +0000'},
#   {'id': 21,
#    'title': 'Microsoft Power BI  - Upwork',
#    'link': 'https://www.upwork.com/jobs/Microsoft-Power_%7E011f03e9ee932e44a6?source=rss',
#    'description': 'We need to have multiple Microsft Power BI dashboard for our customers, each dashboard should have a separate link. and we need to remove the Microsoft power BI logo from the dashboard. We need to create a perfect mobile view for each dashboard for the customer also can we connect google sheet as a data source for the power BI. Posted On: May 12, 2024 19:31 UTCCategory: Data AnalyticsSkills:Data Analysis, Microsoft Power BI, Microsoft Excel, System Administration, System Analysis, Content Management System, SAP, SAP MM Consultant, SAP ERP Skills: Data Analysis, Microsoft Power BI, Microsoft Excel, System Administration, System Analysis, Content Management System, SAP, SAP MM Consultant, SAP ERP Country: Saudi Arabiaclick to apply',
#    'pubDate': 'Sun, 12 May 2024 19:31:54 +0000'},
#   {'id': 22,
#    'title': 'Data Scientist - Upwork',
#    'link': 'https://www.upwork.com/jobs/Data-Scientist_%7E011388202b9f0617ff?source=rss',
#    'description': 'Job Title: Senior Data ScientistIntroduction:We are looking for a seasoned Data Scientist to join our dynamic team. The ideal candidate will be able to use their extensive knowledge of data science and analysis to provide insights and to improve our decision-making. The candidate will be responsible for designing, developing, and implementing predictive models and algorithms to analyze large amounts of data and provide meaningful business solutions.Overview of the Role:The Senior Data Scientist will work closely with various teams within the organization, including executive leadership, product development, and marketing to understand business challenges and develop data-driven solutions. This role requires a deep understanding of data analysis, data mining, machine learning, and statistical modeling techniques. The successful candidate will be able to translate complex findings and results into a compelling narrative that drives strategic decision-making.Key Responsibilities:1. Utilizing advanced analytics and machine learning to identify trends and patterns in complex data sets.2. Designing and implementing predictive models and algorithms.3. Collaborating with cross-functional teams to understand business needs and develop solutions.4. Presenting complex findings in a clear and compelling manner to non-technical stakeholders.5. Ensuring data quality and integrity in all deliverables.6. Staying on top of the latest industry trends and technologies to continually improve our data science capabilities.Skills and Qualifications:1. Masters degree in Data Science, Statistics, Computer Science, or a related field.2. At least five years of experience in a data science role.3. Extensive knowledge of machine learning techniques and algorithms.4. Proficiency in programming languages such as Python or R.5. Strong knowledge of SQL and database structures.6. Experience with data visualization tools such as Tableau or PowerBI.7. Excellent problem-solving skills and attention to detail.8. Strong communication skills, both written and verbal.Benefits:The successful candidate will enjoy a competitive salary package, comprehensive health benefits, a flexible work schedule, continuous learning opportunities, and a collaborative work environment.Call to Action:If you are passionate about data science and want to use your skills to make a tangible impact on our business, apply today. Join us in shaping the future of our industry with data-driven solutions. Apply now to be considered for this exciting opportunity.Please note that only shortlisted candidates will be contacted. We look forward to receiving your applications!Hourly Range: $15.00-$75.00Posted On: May 12, 2024 18:27 UTCCategory: Data AnalyticsSkills:Machine Learning, Data Modeling, Apache Hive, Big Data, Business Intelligence, Computer Vision, NumPy, Microsoft Excel, BigQuery Skills: Machine Learning, Data Modeling, Apache Hive, Big Data, Business Intelligence, Computer Vision, NumPy, Microsoft Excel, BigQuery Country: Netherlandsclick to apply',
#    'pubDate': 'Sun, 12 May 2024 18:27:45 +0000'},
#   {'id': 23,
#    'title': 'My Real Profit - Upwork',
#    'link': 'https://www.upwork.com/jobs/Real-Profit_%7E0181ab615d64a9d6a8?source=rss',
#    'description': 'HiHope youre doing well. Im reaching out from My Profit Company. Were currently in the process of migrating from AWS to Google Cloud and facing some hurdles, particularly with dataset migration and certificate management. Given your expertise, wed like to book around 3-10 hours of consultation to help us navigate these challenges. Could we schedule a session soon?Best,LucjanPosted On: May 12, 2024 17:12 UTCCategory: Data AnalyticsSkills:SQL, Data Analysis, Dashboard, Data Visualization, Report, Microsoft Power BI, Microsoft Excel, Business Intelligence, Power Query, Microsoft Power BI Development, Microsoft Power Automate, Microsoft SharePoint, Microsoft Power BI Data Visualization, Microsoft SharePoint Administration, API Skills: SQL, Data Analysis, Dashboard, Data Visualization, Report, Microsoft Power BI, Microsoft Excel, Business Intelligence, Power Query, Microsoft Power BI Development, Microsoft Power Automate, Microsoft SharePoint, Microsoft Power BI Data Visualization, Microsoft SharePoint Administration, API Country: Spainclick to apply',
#    'pubDate': 'Sun, 12 May 2024 17:12:12 +0000'},
#   {'id': 24,
#    'title': 'Urgent need for Power BI and SQL expert to resolve data transition Issues - Upwork',
#    'link': 'https://www.upwork.com/jobs/Urgent-need-for-Power-and-SQL-expert-resolve-data-transition-Issues_%7E016fc8874ff567d0cc?source=rss',
#    'description': '### Data Analysis Project Post:**Title:** Urgent Need for Power BI and SQL Expert to Resolve Data Transition Issues**Description:**We are seeking an experienced Power BI and SQL expert to assist in a critical project transitioning data from Tableau to Power BI. Our project has faced multiple rejections from stakeholders, and we urgently require a specialist to refine our deliverables to meet high standards.**Requirements:**- Proficient in Power BI, with an excellent track record of developing complex visualizations and dashboards.- Expertise in SQL and experience with Dremio or similar data query environments.- Ability to troubleshoot and resolve data issues, specifically relating to duplicate data entries affecting outputs.- Must be available for immediate start and flexible for Zoom meetings to review current setups and provide actionable insights.**Responsibilities:**- Review and analyze current Tableau to Power BI transition setups.- Write and optimize SQL queries to clean up and organize data effectively, especially to resolve duplications.- Collaborate with our team to enhance the overall data presentation and ensure deliverables meet stakeholder expectations.- Provide expert advice and strategic recommendations to improve data handling and visualization.Posted On: May 12, 2024 16:58 UTCCategory: Presentation DesignSkills:Microsoft Power BI, Tableau, SQL, Query Debugging Skills: Microsoft Power BI, Tableau, SQL, Query Debugging Country: United Statesclick to apply',
#    'pubDate': 'Sun, 12 May 2024 16:58:02 +0000'},
#   {'id': 25,
#    'title': 'Remote Power BI &amp; SAP SAC Expert - Upwork',
#    'link': 'https://www.upwork.com/jobs/Remote-Power-amp-SAP-SAC-Expert_%7E0154f93ba5573aeaaa?source=rss',
#    'description': 'Looking for a Power BI and SAP SAC expert to support pre-sales activities on a remote, as-needed basis. The role involves preparing presentations, system demos, and providing expert insights to prospective customers.Responsibilities:- Create and present PowerPoint presentations.- Conduct system and capability demos.- Serve as a subject matter expert during customer interactions.Requirements:- Proven experience with Power BI and SAP SAC.- Strong presentation and demonstration skills.- Excellent communication abilities.Job Type: Remote, freelanceHourly Range: $5.00-$20.00Posted On: May 12, 2024 15:55 UTCCategory: Data VisualizationSkills:Microsoft Power BI, SAP, Data Visualization, Business Intelligence, Data Modeling, Data Analysis, Microsoft Excel, ETL Skills: Microsoft Power BI, SAP, Data Visualization, Business Intelligence, Data Modeling, Data Analysis, Microsoft Excel, ETL Country: United Arab Emiratesclick to apply',
#    'pubDate': 'Sun, 12 May 2024 15:55:05 +0000'},
#   {'id': 26,
#    'title': 'Data Analyst/English Business - Upwork',
#    'link': 'https://www.upwork.com/jobs/Data-Analyst-English-Business_%7E01e739a8f4ebd29158?source=rss',
#    'description': 'We are seeking a skilled Data Analyst with a strong command of English for our business. As a Data Analyst, you will be responsible for collecting, analyzing, and interpreting complex data sets to provide valuable insights and recommendations. The ideal candidate should have a solid understanding of statistical methodologies, data visualization, and data mining techniques. Responsibilities:- Collect and clean data from various sources- Perform statistical analysis and generate reports- Develop and maintain databases- Create data visualizations and dashboards- Identify trends and patterns in dataRequirements:- Proven experience as a Data Analyst or in a similar role- Strong analytical skills and attention to detail- Proficient in SQL and data visualization tools (e.g., Tableau, Power BI)- Excellent English communication skillsThis is a medium-sized project with a duration of 1 to 3 months. We are looking for an intermediate-level Data Analyst who can work independently and deliver high-quality results. If you are passionate about data analysis and have a strong business acumen, we would love to hear from you!Hourly Range: $17.00-$50.00Posted On: May 12, 2024 12:41 UTCCategory: Data AnalyticsSkills:Microsoft Excel, English, Data Entry Skills: Microsoft Excel, English, Data Entry Country: Franceclick to apply',
#    'pubDate': 'Sun, 12 May 2024 12:41:52 +0000'},
#   {'id': 27,
#    'title': 'Seeking freelance sports statistician, ideally with knowledge of NFL/MLB  - Upwork',
#    'link': 'https://www.upwork.com/jobs/Seeking-freelance-sports-statistician-ideally-with-knowledge-NFL-MLB_%7E01e15b42ace6635baa?source=rss',
#    'description': 'We are seeking someone who would be able to generate some statistics for us. We are looking for a sports statistician that we could hire for this this, ideally with knowledge of the NFL, although we could also do baseball/MLB too. We need someone to crunch the data and identify and rank the teams in different sports that peak too soon and also maybe the ones that stay strong and/or finish strong. We could define peaking too soon to mean either consistently peaking too early in the game or peaking too soon in a season or some combination of both. Let me know if this is something you could help us with! Posted On: May 12, 2024 11:13 UTCCategory: Data AnalyticsSkills:Data Science, Visualization, Microsoft Power BI Data Visualization, Data Analytics, Analytics, Analytical Presentation, Data Analysis, R, Microsoft Excel, Microsoft Power BI, Microsoft PowerPoint, Python Skills: Data Science, Visualization, Microsoft Power BI Data Visualization, Data Analytics, Analytics, Analytical Presentation, Data Analysis, R, Microsoft Excel, Microsoft Power BI, Microsoft PowerPoint, Python Country: United Kingdomclick to apply',
#    'pubDate': 'Sun, 12 May 2024 11:13:35 +0000'},
#   {'id': 28,
#    'title': 'Power BI Expert Needed for Data Scraping - Upwork',
#    'link': 'https://www.upwork.com/jobs/Power-Expert-Needed-for-Data-Scraping_%7E01e0a2091f6c4ac120?source=rss',
#    'description': 'Extract Specific contact information (name, address, phone number amp; email address) from a power BI website. Create a Dynamic Excel Spreadsheet that can be refreshed when needed.I created a ppt that explains in more detail the objective and were to get the infomation. For someone profecient with Power BI, it should be easy to quot;Get Dataquot; then clean up the spreadsheet to meet minimum requirements. Budget: $50Posted On: May 12, 2024 09:16 UTCCategory: Data ExtractionSkills:Microsoft Power BI, Microsoft Excel, Data Scraping, Data Mining Skills: Microsoft Power BI, Microsoft Excel, Data Scraping, Data Mining Country: United Statesclick to apply',
#    'pubDate': 'Sun, 12 May 2024 09:16:33 +0000'},
#   {'id': 29,
#    'title': 'Build a recruitment excel tracker and KPI analytics  - Upwork',
#    'link': 'https://www.upwork.com/jobs/Build-recruitment-excel-tracker-and-KPI-analytics_%7E01ec3a2a8d0d7cb198?source=rss',
#    'description': 'Hi, I work as a recruiter for a tech company and looking for someone to help me build a good excel tracker with analytics I can use to track recruitment activity at the company. I have already created a draft version on excel to give you an idea of the information I need captured. I need someone to take the draft and create a better version that is easily customisable, where all the data flows through seamlessly across each tabs with a main dashboard that summarises the key recruitment KPIs.The purpose of the tracker is capture information such as the below (these are some of them)- Total open vacancies - Total offers made in March 2024 - Total offers made in Q1 2024- Offer acceptance %- Time to hire %- Average source of hire (did hires come through Linkedin, careers page, job advert etc)- Total hires made in each global office by month, by quarter, by yearPosted On: May 12, 2024 09:16 UTCCategory: Recruiting Talent SourcingSkills:Microsoft Excel, Data Visualization, Analytics, Microsoft Power BI, Tableau Skills: Microsoft Excel, Data Visualization, Analytics, Microsoft Power BI, Tableau Country: United Kingdomclick to apply',
#    'pubDate': 'Sun, 12 May 2024 09:16:23 +0000'}]}

# %%
output["jobs"][3]['description']
# Out:
# 'write a scope of work that is focused on data consumer behavior and other important key metrics that will enable the dealership to sell smarter to its customers. Skills required are pyhthon, sql and powerbiDeliverables: Defined and prioritized KPIs for sales and marketing Customer segmentation insights and reports Recommendations for targeted marketing campaigns across various channels Data-driven strategies for optimizing the sales process Ongoing reporting dashboards Final report with actionable recommendationscommunication will be via email and Microsoft teamsBudget: $500Posted On: May 13, 2024 09:27 UTCCategory: Data AnalyticsSkills:SQL, Microsoft Power BI, Business Intelligence, Python Skills: SQL, Microsoft Power BI, Business Intelligence, Python Country: South Africaclick to apply'

# %% [markdown]
# ### kor hello world example

# %%
#kor hello world
person_schema = Object(
    #This what will appear in your output. It's what the fields below will be nested under.
    #It should be the paprent of the fields below. Usually it's singular (not plural)
    id="person",

    #Natural language description about your object
    description = "Personal information about a person",

    #Fields you'd like to capture from a piece of text about your object.
    attributes=[
        Text(
            id="first_name",
            description = "The first name of a person.",
        )
    ],

    # Examples help go a long way with telling the LLM what you need
    examples=[
        #(text input ,[{first output example} {second output example}])
        ("Alice and Bob are friends", [{"first_name": "Alice"}, {"first_name": "Bob"}])
    ]
)

# %% [markdown]
# create a chain that will extract the information and then parse it. This uses Langchain under the hood

# %%
#Openai Chatgpt Output
chain = create_extraction_chain(llm, person_schema)

with get_openai_callback() as cb:
    text = "My name is Bobby. My sister's name is Rachel. My brother's name is Joe. My dog's name is Spot"
    outputAI = chain.invoke(input=(text))["data"]

    printOutput(outputAI)

    print(f"Total Tokens: {cb.total_tokens}")
    print(f"Prompt Tokens: {cb.prompt_tokens}")
    print(f"Completion Tokens: {cb.completion_tokens}")
    print(f"Successful Requests: {cb.successful_requests}")
    print(f"Total Cost (USD): ${cb.total_cost}")
# Out:
# {
#    "person": [
#       {
#          "first_name": "Bobby"
#       },
#       {
#          "first_name": "Rachel"
#       },
#       {
#          "first_name": "Joe"
#       },
#       {
#          "first_name": "Spot"
#       }
#    ]
# }
# Total Tokens: 193
# Prompt Tokens: 182
# Completion Tokens: 11
# Successful Requests: 1
# Total Cost (USD): $0.000295

# %%
#Openai Chatgpt Output
chain = create_extraction_chain(llm_gpt4o, person_schema)

with get_openai_callback() as cb:
    text = "My name is Bobby. My sister's name is Rachel. My brother's name is Joe. My dog's name is Spot"
    outputAI = chain.invoke(input=(text))["data"]

    printOutput(outputAI)

    print(f"Total Tokens: {cb.total_tokens}")
    print(f"Prompt Tokens: {cb.prompt_tokens}")
    print(f"Completion Tokens: {cb.completion_tokens}")
    print(f"Successful Requests: {cb.successful_requests}")
    print(f"Total Cost (USD): ${cb.total_cost}")
# Out:
# {
#    "person": [
#       {
#          "first_name": "Bobby"
#       },
#       {
#          "first_name": "Rachel"
#       },
#       {
#          "first_name": "Joe"
#       }
#    ]
# }
# Total Tokens: 189
# Prompt Tokens: 180
# Completion Tokens: 9
# Successful Requests: 1
# Total Cost (USD): $0.001035

# %%
print(outputAI)
# Out:
# {'person': [{'first_name': 'Bobby'}, {'first_name': 'Rachel'}, {'first_name': 'Joe'}, {'first_name': 'Spot'}]}

# %%
job_schema = Object(
    description="Schema for extracting relevant details from a job description.",
    attributes=[
        Text(
            id="job_title",
            description="The title of the job role.",
            examples=["Power BI Developer", "Data Analyst", "Software Engineer"],
        ),
        List(
            id="responsibilities",
            description="List of key responsibilities for the job.",
            item_type=Text(
                id="responsibility",
                description="A specific responsibility.",
                examples=["Creating dashboards", "Building data models"]
            ),
        ),
        List(
            id="qualifications",
            description="List of required or preferred qualifications.",
            item_type=Text(
                id="qualification",
                description="A specific qualification or skill required.",
                examples=["Proficiency in Power BI Desktop, Power Query, DAX", "Experience with SQL and ETL processes"]
            ),
        ),
        List(
            id="technologies",
            description="List of technologies, tools, or methodologies mentioned.",
            item_type=Text(
                id="technology",
                description="A specific technology or tool.",
                examples=["Power BI", "SQL", "DAX", "Power Query", "Python"]
            ),
        ),
        Text(
            id="experience_level",
            description="The required or preferred experience level.",
            examples=["3+ years", "5+ years", "Entry-level", "Senior-level"]
        ),
        Text(
            id="location",
            description="The job location or country.",
            examples=["Philippines", "United Kingdom"]
        ),
        Number(
            id="hourly_rate",
            description="The hourly rate or salary range if mentioned.",
            examples=["25.00", "60.00"]
        ),
        Text(
            id="company",
            description="The name of the company, if mentioned.",
            examples=["XYZ Corp.", "Global Tech",]
        )
    ]
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[31], line 4
#       1 job_schema = Object(
#       2     description="Schema for extracting relevant details from a job description.",
#       3     attributes=[
# ----> 4         Text(
#       5             id="job_title",
#       6             description="The title of the job role.",
#       7             examples=["Power BI Developer", "Data Analyst", "Software Engineer"],
#       8         ),
#       9         List(
#      10             id="responsibilities",
#      11             description="List of key responsibilities for the job.",
#      12             item_type=Text(
#      13                 id="responsibility",
#      14                 description="A specific responsibility.",
#      15                 examples=["Creating dashboards", "Building data models"]
#      16             ),
#      17         ),
#      18         List(
#      19             id="qualifications",
#      20             description="List of required or preferred qualifications.",
#      21             item_type=Text(
#      22                 id="qualification",
#      23                 description="A specific qualification or skill required.",
#      24                 examples=["Proficiency in Power BI Desktop, Power Query, DAX", "Experience with SQL and ETL processes"]
#      25             ),
#      26         ),
#      27         List(
#      28             id="technologies",
#      29             description="List of technologies, tools, or methodologies mentioned.",
#      30             item_type=Text(
#      31                 id="technology",
#      32                 description="A specific technology or tool.",
#      33                 examples=["Power BI", "SQL", "DAX", "Power Query", "Python"]
#      34             ),
#      35         ),
#      36         Text(
#      37             id="experience_level",
#      38             description="The required or preferred experience level.",
#      39             examples=["3+ years", "5+ years", "Entry-level", "Senior-level"]
#      40         ),
#      41         Text(
#      42             id="location",
#      43             description="The job location or country.",
#      44             examples=["Philippines", "United Kingdom"]
#      45         ),
#      46         Number(
#      47             id="hourly_rate",
#      48             description="The hourly rate or salary range if mentioned.",
#      49             examples=["25.00", "60.00"]
#      50         ),
#      51         Text(
#      52             id="company",
#      53             description="The name of the company, if mentioned.",
#      54             examples=["XYZ Corp.", "Global Tech",]
#      55         )
#      56     ]
#      57 )
#
# File c:\Users\saadl\AppData\Local\Programs\Python\Python311\Lib\site-packages\kor\nodes.py:122, in ExtractionSchemaNode.__init__(self, **kwargs)
#     120 def __init__(self, **kwargs: Any) -> None:
#     121     """Initialize."""
# --> 122     super().__init__(**kwargs)
#     123     if PYDANTIC_MAJOR_VERSION == 1:
#     124         self.__dict__[TYPE_DISCRIMINATOR_FIELD] = type(self).__name__
#
# File c:\Users\saadl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\main.py:164, in BaseModel.__init__(__pydantic_self__, **data)
#     162 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     163 __tracebackhide__ = True
# --> 164 __pydantic_self__.__pydantic_validator__.validate_python(data, self_instance=__pydantic_self__)
#
# ValidationError: 3 validation errors for Text
# examples.0
#   Input should be a valid tuple [type=tuple_type, input_value='Power BI Developer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.5/v/tuple_type
# examples.1
#   Input should be a valid tuple [type=tuple_type, input_value='Data Analyst', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.5/v/tuple_type
# examples.2
#   Input should be a valid tuple [type=tuple_type, input_value='Software Engineer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.5/v/tuple_type

# %%
# Define the schema without 'List', using nested objects for lists
job_schema = Object(
    description="Schema for extracting relevant details from a job description.",
    attributes=[
        Text(
            id="job_title",
            description="The title of the job role.",
            examples=["Power BI Developer", "Data Analyst", "Software Engineer"],
        ),
        Object(
            id="responsibilities",
            description="Key responsibilities for the job (simulating a list).",
            attributes=[
                Text(
                    id="responsibility",
                    description="A specific responsibility.",
                    examples=["Creating dashboards", "Building data models"]
                )
            ]
        ),
        Object(
            id="qualifications",
            description="Required or preferred qualifications (simulating a list).",
            attributes=[
                Text(
                    id="qualification",
                    description="A specific qualification or skill required.",
                    examples=["Proficiency in Power BI Desktop, Power Query, DAX", "Experience with SQL and ETL processes"]
                )
            ]
        ),
        Object(
            id="technologies",
            description="Technologies, tools, or methodologies mentioned (simulating a list).",
            attributes=[
                Text(
                    id="technology",
                    description="A specific technology or tool.",
                    examples=["Power BI", "SQL", "DAX", "Power Query", "Python"]
                )
            ]
        ),
        Text(
            id="experience_level",
            description="The required or preferred experience level.",
            examples=["3+ years", "5+ years", "Entry-level", "Senior-level"]
        ),
        Text(
            id="location",
            description="The job location or country.",
            examples=["Philippines", "United Kingdom"]
        ),
        Number(
            id="hourly_rate",
            description="The hourly rate or salary range if mentioned.",
            examples=["25.00", "60.00"]
        ),
        Text(
            id="company",
            description="The name of the company, if mentioned.",
            examples=["XYZ Corp.", "Global Tech"]
        )
    ]
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[33], line 5
#       1 # Define the schema without 'List', using nested objects for lists
#       2 job_schema = Object(
#       3     description="Schema for extracting relevant details from a job description.",
#       4     attributes=[
# ----> 5         Text(
#       6             id="job_title",
#       7             description="The title of the job role.",
#       8             examples=["Power BI Developer", "Data Analyst", "Software Engineer"],
#       9         ),
#      10         Object(
#      11             id="responsibilities",
#      12             description="Key responsibilities for the job (simulating a list).",
#      13             attributes=[
#      14                 Text(
#      15                     id="responsibility",
#      16                     description="A specific responsibility.",
#      17                     examples=["Creating dashboards", "Building data models"]
#      18                 )
#      19             ]
#      20         ),
#      21         Object(
#      22             id="qualifications",
#      23             description="Required or preferred qualifications (simulating a list).",
#      24             attributes=[
#      25                 Text(
#      26                     id="qualification",
#      27                     description="A specific qualification or skill required.",
#      28                     examples=["Proficiency in Power BI Desktop, Power Query, DAX", "Experience with SQL and ETL processes"]
#      29                 )
#      30             ]
#      31         ),
#      32         Object(
#      33             id="technologies",
#      34             description="Technologies, tools, or methodologies mentioned (simulating a list).",
#      35             attributes=[
#      36                 Text(
#      37                     id="technology",
#      38                     description="A specific technology or tool.",
#      39                     examples=["Power BI", "SQL", "DAX", "Power Query", "Python"]
#      40                 )
#      41             ]
#      42         ),
#      43         Text(
#      44             id="experience_level",
#      45             description="The required or preferred experience level.",
#      46             examples=["3+ years", "5+ years", "Entry-level", "Senior-level"]
#      47         ),
#      48         Text(
#      49             id="location",
#      50             description="The job location or country.",
#      51             examples=["Philippines", "United Kingdom"]
#      52         ),
#      53         Number(
#      54             id="hourly_rate",
#      55             description="The hourly rate or salary range if mentioned.",
#      56             examples=["25.00", "60.00"]
#      57         ),
#      58         Text(
#      59             id="company",
#      60             description="The name of the company, if mentioned.",
#      61             examples=["XYZ Corp.", "Global Tech"]
#      62         )
#      63     ]
#      64 )
#
# File c:\Users\saadl\AppData\Local\Programs\Python\Python311\Lib\site-packages\kor\nodes.py:122, in ExtractionSchemaNode.__init__(self, **kwargs)
#     120 def __init__(self, **kwargs: Any) -> None:
#     121     """Initialize."""
# --> 122     super().__init__(**kwargs)
#     123     if PYDANTIC_MAJOR_VERSION == 1:
#     124         self.__dict__[TYPE_DISCRIMINATOR_FIELD] = type(self).__name__
#
# File c:\Users\saadl\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\main.py:164, in BaseModel.__init__(__pydantic_self__, **data)
#     162 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     163 __tracebackhide__ = True
# --> 164 __pydantic_self__.__pydantic_validator__.validate_python(data, self_instance=__pydantic_self__)
#
# ValidationError: 3 validation errors for Text
# examples.0
#   Input should be a valid tuple [type=tuple_type, input_value='Power BI Developer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.5/v/tuple_type
# examples.1
#   Input should be a valid tuple [type=tuple_type, input_value='Data Analyst', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.5/v/tuple_type
# examples.2
#   Input should be a valid tuple [type=tuple_type, input_value='Software Engineer', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.5/v/tuple_type

# %%
# Generate a response for the embedding task or any other LLM task
response = llm_ollama_llama31.generate(prompts=["Is the sky blue?"])
print(response)
# Out:
# generations=[[GenerationChunk(text=" Yes, the sky is perceived as blue. This appearance is due to Rayleigh scattering of sunlight in Earth'ser atmosphere. The shorter wavelengths of light (blue and violet) are scattered more than the longer wavelengths (red and yellow). However, our eyes are less sensitive to violet light and some of it gets absorbed by the upper atmosphere, which is why we perceive a blue sky most of the time.", generation_info={'model': 'nuextract', 'created_at': '2024-09-20T13:28:35.4393413Z', 'response': '', 'done': True, 'done_reason': 'stop', 'context': [32010, 29871, 13, 3624, 278, 14744, 7254, 29973, 32007, 29871, 13, 32001, 29871, 3869, 29892, 278, 14744, 338, 17189, 2347, 408, 7254, 29889, 910, 10097, 338, 2861, 304, 9596, 280, 1141, 14801, 292, 310, 6575, 4366, 297, 11563, 29915, 643, 25005, 29889, 450, 20511, 281, 6447, 1477, 29879, 310, 3578, 313, 9539, 322, 28008, 1026, 29897, 526, 29574, 901, 1135, 278, 5520, 281, 6447, 1477, 29879, 313, 1127, 322, 13328, 467, 2398, 29892, 1749, 5076, 526, 3109, 20502, 304, 28008, 1026, 3578, 322, 777, 310, 372, 4947, 17977, 2580, 491, 278, 7568, 25005, 29892, 607, 338, 2020, 591, 17189, 573, 263, 7254, 14744, 1556, 310, 278, 931, 29889], 'total_duration': 4359978200, 'load_duration': 2978021600, 'prompt_eval_count': 13, 'prompt_eval_duration': 55887000, 'eval_count': 96, 'eval_duration': 1318694000})]] llm_output=None run=[RunInfo(run_id=UUID('4c5c0369-6144-463b-ad2a-e2acc8b0d9ba'))]

# %%
schema = Object(
    id="person",
    description="Personal information",
    examples=[
        ("Alice and Bob are friends", [{"first_name": "Alice"}, {"first_name": "Bob"}])
    ],
    attributes=[
        Text(
            id="first_name",
            description="The first name of a person.",
        )
    ],
    many=True,
)

# %%
chain = create_extraction_chain(llm_ollama_llama31, schema)

# %%
text = "My name is Bobby. My sister's name is Rachel. My brother's name is Joe. My dog's name is Spot"
outputAI = chain.invoke(input=(text))["data"]

# %%
outputAI
# Out:
# {'person': [{'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   {'first_name': 'first_name', 'Alice': 'Spot'},
#   {'first_name': 'first_name', 'Alice': 'Alice'},
#   {'first_name': 'first_name', 'Alice': 'Bobby'},
#   {'first_name': 'first_name', 'Alice': 'Rachel'},
#   {'first_name': 'first_name', 'Alice': 'Joe'},
#   ...]}

# %%
#Show the prompt that KOR made for us
print(chain.get_prompts()[0].format_prompt(text="[user input]").to_string())
# Out:
# Your goal is to extract structured information from the user's input that matches the form described below. When extracting information please make sure it matches the type information exactly. Do not add any attributes that do not appear in the schema shown below.
#
# ```TypeScript
#
# person: { // Personal information about a person
#  first_name: string // The first name of a person.
# }
# ```
#
#
# Please output the extracted information in CSV format in Excel dialect. Please use a | as the delimiter.
#  Do NOT add any clarifying information. Output MUST follow the schema above. Do NOT add any additional columns that do not appear in the schema.
#
#
#
# Input: Alice and Bob are friends
# Output: first_name
# Alice
# Bob
#
# Input: [user input]
# Output:
